# %% [markdown]
# # PARTIE 1 : Nettoyage des données

# %% [markdown]
# ## Import librairies & création session Spark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## Lecture des données

# %%
filepath = "s3://full-stack-bigdata-datasets/Big_Data/Project_Steam/steam_game_output.json"
df = spark.read.format('json').load(filepath, multiline=True)
print(type(df))
print(df.count(), len(df.columns))
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# 55691 2

# %%
df.printSchema()
# Out:
# root
#  |-- data: struct (nullable = true)
#  |    |-- appid: long (nullable = true)
#  |    |-- categories: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ccu: long (nullable = true)
#  |    |-- developer: string (nullable = true)
#  |    |-- discount: string (nullable = true)
#  |    |-- genre: string (nullable = true)
#  |    |-- header_image: string (nullable = true)
#  |    |-- initialprice: string (nullable = true)
#  |    |-- languages: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- negative: long (nullable = true)
#  |    |-- owners: string (nullable = true)
#  |    |-- platforms: struct (nullable = true)
#  |    |    |-- linux: boolean (nullable = true)
#  |    |    |-- mac: boolean (nullable = true)
#  |    |    |-- windows: boolean (nullable = true)
#  |    |-- positive: long (nullable = true)
#  |    |-- price: string (nullable = true)
#  |    |-- publisher: string (nullable = true)
#  |    |-- release_date: string (nullable = true)
#  |    |-- required_age: string (nullable = true)
#  |    |-- short_description: string (nullable = true)
#  |    |-- tags: struct (nullable = true)
#  |    |    |-- 1980s: long (nullable = true)
#  |    |    |-- 1990's: long (nullable = true)
#  |    |    |-- 2.5D: long (nullable = true)
#  |    |    |-- 2D: long (nullable = true)
#  |    |    |-- 2D Fighter: long (nullable = true)
#  |    |    |-- 2D Platformer: long (nullable = true)
#  |    |    |-- 360 Video: long (nullable = true)
#  |    |    |-- 3D: long (nullable = true)
#  |    |    |-- 3D Fighter: long (nullable = true)
#  |    |    |-- 3D Platformer: long (nullable = true)
#  |    |    |-- 3D Vision: long (nullable = true)
#  |    |    |-- 4 Player Local: long (nullable = true)
#  |    |    |-- 4X: long (nullable = true)
#  |    |    |-- 6DOF: long (nullable = true)
#  |    |    |-- 8-bit Music: long (nullable = true)
#  |    |    |-- ATV: long (nullable = true)
#  |    |    |-- Abstract: long (nullable = true)
#  |    |    |-- Action: long (nullable = true)
#  |    |    |-- Action RPG: long (nullable = true)
#  |    |    |-- Action RTS: long (nullable = true)
#  |    |    |-- Action Roguelike: long (nullable = true)
#  |    |    |-- Action-Adventure: long (nullable = true)
#  |    |    |-- Addictive: long (nullable = true)
#  |    |    |-- Adventure: long (nullable = true)
#  |    |    |-- Agriculture: long (nullable = true)
#  |    |    |-- Aliens: long (nullable = true)
#  |    |    |-- Alternate History: long (nullable = true)
#  |    |    |-- Ambient: long (nullable = true)
#  |    |    |-- America: long (nullable = true)
#  |    |    |-- Animation & Modeling: long (nullable = true)
#  |    |    |-- Anime: long (nullable = true)
#  |    |    |-- Arcade: long (nullable = true)
#  |    |    |-- Archery: long (nullable = true)
#  |    |    |-- Arena Shooter: long (nullable = true)
#  |    |    |-- Artificial Intelligence: long (nullable = true)
#  |    |    |-- Assassin: long (nullable = true)
#  |    |    |-- Asymmetric VR: long (nullable = true)
#  |    |    |-- Asynchronous Multiplayer: long (nullable = true)
#  |    |    |-- Atmospheric: long (nullable = true)
#  |    |    |-- Audio Production: long (nullable = true)
#  |    |    |-- Auto Battler: long (nullable = true)
#  |    |    |-- Automation: long (nullable = true)
#  |    |    |-- Automobile Sim: long (nullable = true)
#  |    |    |-- BMX: long (nullable = true)
#  |    |    |-- Base-Building: long (nullable = true)
#  |    |    |-- Baseball: long (nullable = true)
#  |    |    |-- Based On A Novel: long (nullable = true)
#  |    |    |-- Basketball: long (nullable = true)
#  |    |    |-- Battle Royale: long (nullable = true)
#  |    |    |-- Beat 'em up: long (nullable = true)
#  |    |    |-- Beautiful: long (nullable = true)
#  |    |    |-- Benchmark: long (nullable = true)
#  |    |    |-- Bikes: long (nullable = true)
#  |    |    |-- Blood: long (nullable = true)
#  |    |    |-- Board Game: long (nullable = true)
#  |    |    |-- Boss Rush: long (nullable = true)
#  |    |    |-- Bowling: long (nullable = true)
#  |    |    |-- Boxing: long (nullable = true)
#  |    |    |-- Building: long (nullable = true)
#  |    |    |-- Bullet Hell: long (nullable = true)
#  |    |    |-- Bullet Time: long (nullable = true)
#  |    |    |-- CRPG: long (nullable = true)
#  |    |    |-- Capitalism: long (nullable = true)
#  |    |    |-- Card Battler: long (nullable = true)
#  |    |    |-- Card Game: long (nullable = true)
#  |    |    |-- Cartoon: long (nullable = true)
#  |    |    |-- Cartoony: long (nullable = true)
#  |    |    |-- Casual: long (nullable = true)
#  |    |    |-- Cats: long (nullable = true)
#  |    |    |-- Character Action Game: long (nullable = true)
#  |    |    |-- Character Customization: long (nullable = true)
#  |    |    |-- Chess: long (nullable = true)
#  |    |    |-- Choices Matter: long (nullable = true)
#  |    |    |-- Choose Your Own Adventure: long (nullable = true)
#  |    |    |-- Cinematic: long (nullable = true)
#  |    |    |-- City Builder: long (nullable = true)
#  |    |    |-- Class-Based: long (nullable = true)
#  |    |    |-- Classic: long (nullable = true)
#  |    |    |-- Clicker: long (nullable = true)
#  |    |    |-- Co-op: long (nullable = true)
#  |    |    |-- Co-op Campaign: long (nullable = true)
#  |    |    |-- Coding: long (nullable = true)
#  |    |    |-- Cold War: long (nullable = true)
#  |    |    |-- Collectathon: long (nullable = true)
#  |    |    |-- Colony Sim: long (nullable = true)
#  |    |    |-- Colorful: long (nullable = true)
#  |    |    |-- Combat: long (nullable = true)
#  |    |    |-- Combat Racing: long (nullable = true)
#  |    |    |-- Comedy: long (nullable = true)
#  |    |    |-- Comic Book: long (nullable = true)
#  |    |    |-- Competitive: long (nullable = true)
#  |    |    |-- Conspiracy: long (nullable = true)
#  |    |    |-- Controller: long (nullable = true)
#  |    |    |-- Conversation: long (nullable = true)
#  |    |    |-- Cooking: long (nullable = true)
#  |    |    |-- Cozy: long (nullable = true)
#  |    |    |-- Crafting: long (nullable = true)
#  |    |    |-- Creature Collector: long (nullable = true)
#  |    |    |-- Cricket: long (nullable = true)
#  |    |    |-- Crime: long (nullable = true)
#  |    |    |-- Crowdfunded: long (nullable = true)
#  |    |    |-- Cult Classic: long (nullable = true)
#  |    |    |-- Cute: long (nullable = true)
#  |    |    |-- Cyberpunk: long (nullable = true)
#  |    |    |-- Cycling: long (nullable = true)
#  |    |    |-- Dark: long (nullable = true)
#  |    |    |-- Dark Comedy: long (nullable = true)
#  |    |    |-- Dark Fantasy: long (nullable = true)
#  |    |    |-- Dark Humor: long (nullable = true)
#  |    |    |-- Dating Sim: long (nullable = true)
#  |    |    |-- Deckbuilding: long (nullable = true)
#  |    |    |-- Demons: long (nullable = true)
#  |    |    |-- Design & Illustration: long (nullable = true)
#  |    |    |-- Destruction: long (nullable = true)
#  |    |    |-- Detective: long (nullable = true)
#  |    |    |-- Difficult: long (nullable = true)
#  |    |    |-- Dinosaurs: long (nullable = true)
#  |    |    |-- Diplomacy: long (nullable = true)
#  |    |    |-- Documentary: long (nullable = true)
#  |    |    |-- Dog: long (nullable = true)
#  |    |    |-- Dragons: long (nullable = true)
#  |    |    |-- Drama: long (nullable = true)
#  |    |    |-- Driving: long (nullable = true)
#  |    |    |-- Dungeon Crawler: long (nullable = true)
#  |    |    |-- Dungeons & Dragons: long (nullable = true)
#  |    |    |-- Dynamic Narration: long (nullable = true)
#  |    |    |-- Dystopian : long (nullable = true)
#  |    |    |-- Early Access: long (nullable = true)
#  |    |    |-- Economy: long (nullable = true)
#  |    |    |-- Education: long (nullable = true)
#  |    |    |-- Electronic: long (nullable = true)
#  |    |    |-- Electronic Music: long (nullable = true)
#  |    |    |-- Emotional: long (nullable = true)
#  |    |    |-- Epic: long (nullable = true)
#  |    |    |-- Episodic: long (nullable = true)
#  |    |    |-- Escape Room: long (nullable = true)
#  |    |    |-- Experience: long (nullable = true)
#  |    |    |-- Experimental: long (nullable = true)
#  |    |    |-- Exploration: long (nullable = true)
#  |    |    |-- FMV: long (nullable = true)
#  |    |    |-- FPS: long (nullable = true)
#  |    |    |-- Faith: long (nullable = true)
#  |    |    |-- Family Friendly: long (nullable = true)
#  |    |    |-- Fantasy: long (nullable = true)
#  |    |    |-- Farming: long (nullable = true)
#  |    |    |-- Farming Sim: long (nullable = true)
#  |    |    |-- Fast-Paced: long (nullable = true)
#  |    |    |-- Feature Film: long (nullable = true)
#  |    |    |-- Female Protagonist: long (nullable = true)
#  |    |    |-- Fighting: long (nullable = true)
#  |    |    |-- First-Person: long (nullable = true)
#  |    |    |-- Fishing: long (nullable = true)
#  |    |    |-- Flight: long (nullable = true)
#  |    |    |-- Football: long (nullable = true)
#  |    |    |-- Foreign: long (nullable = true)
#  |    |    |-- Free to Play: long (nullable = true)
#  |    |    |-- Funny: long (nullable = true)
#  |    |    |-- Futuristic: long (nullable = true)
#  |    |    |-- Gambling: long (nullable = true)
#  |    |    |-- Game Development: long (nullable = true)
#  |    |    |-- GameMaker: long (nullable = true)
#  |    |    |-- Games Workshop: long (nullable = true)
#  |    |    |-- Gaming: long (nullable = true)
#  |    |    |-- God Game: long (nullable = true)
#  |    |    |-- Golf: long (nullable = true)
#  |    |    |-- Gore: long (nullable = true)
#  |    |    |-- Gothic: long (nullable = true)
#  |    |    |-- Grand Strategy: long (nullable = true)
#  |    |    |-- Great Soundtrack: long (nullable = true)
#  |    |    |-- Grid-Based Movement: long (nullable = true)
#  |    |    |-- Gun Customization: long (nullable = true)
#  |    |    |-- Hack and Slash: long (nullable = true)
#  |    |    |-- Hacking: long (nullable = true)
#  |    |    |-- Hand-drawn: long (nullable = true)
#  |    |    |-- Hardware: long (nullable = true)
#  |    |    |-- Heist: long (nullable = true)
#  |    |    |-- Hentai: long (nullable = true)
#  |    |    |-- Hero Shooter: long (nullable = true)
#  |    |    |-- Hex Grid: long (nullable = true)
#  |    |    |-- Hidden Object: long (nullable = true)
#  |    |    |-- Historical: long (nullable = true)
#  |    |    |-- Hockey: long (nullable = true)
#  |    |    |-- Horror: long (nullable = true)
#  |    |    |-- Horses: long (nullable = true)
#  |    |    |-- Hunting: long (nullable = true)
#  |    |    |-- Idler: long (nullable = true)
#  |    |    |-- Illuminati: long (nullable = true)
#  |    |    |-- Immersive: long (nullable = true)
#  |    |    |-- Immersive Sim: long (nullable = true)
#  |    |    |-- Indie: long (nullable = true)
#  |    |    |-- Instrumental Music: long (nullable = true)
#  |    |    |-- Intentionally Awkward Controls: long (nullable = true)
#  |    |    |-- Interactive Fiction: long (nullable = true)
#  |    |    |-- Inventory Management: long (nullable = true)
#  |    |    |-- Investigation: long (nullable = true)
#  |    |    |-- Isometric: long (nullable = true)
#  |    |    |-- JRPG: long (nullable = true)
#  |    |    |-- Jet: long (nullable = true)
#  |    |    |-- Job Simulator: long (nullable = true)
#  |    |    |-- Jump Scare: long (nullable = true)
#  |    |    |-- Kickstarter: long (nullable = true)
#  |    |    |-- LEGO: long (nullable = true)
#  |    |    |-- LGBTQ+: long (nullable = true)
#  |    |    |-- Lemmings: long (nullable = true)
#  |    |    |-- Level Editor: long (nullable = true)
#  |    |    |-- Life Sim: long (nullable = true)
#  |    |    |-- Linear: long (nullable = true)
#  |    |    |-- Local Co-Op: long (nullable = true)
#  |    |    |-- Local Multiplayer: long (nullable = true)
#  |    |    |-- Logic: long (nullable = true)
#  |    |    |-- Loot: long (nullable = true)
#  |    |    |-- Looter Shooter: long (nullable = true)
#  |    |    |-- Lore-Rich: long (nullable = true)
#  |    |    |-- Lovecraftian: long (nullable = true)
#  |    |    |-- MMORPG: long (nullable = true)
#  |    |    |-- MOBA: long (nullable = true)
#  |    |    |-- Magic: long (nullable = true)
#  |    |    |-- Mahjong: long (nullable = true)
#  |    |    |-- Management: long (nullable = true)
#  |    |    |-- Mars: long (nullable = true)
#  |    |    |-- Martial Arts: long (nullable = true)
#  |    |    |-- Massively Multiplayer: long (nullable = true)
#  |    |    |-- Masterpiece: long (nullable = true)
#  |    |    |-- Match 3: long (nullable = true)
#  |    |    |-- Mature: long (nullable = true)
#  |    |    |-- Mechs: long (nullable = true)
#  |    |    |-- Medical Sim: long (nullable = true)
#  |    |    |-- Medieval: long (nullable = true)
#  |    |    |-- Memes: long (nullable = true)
#  |    |    |-- Metroidvania: long (nullable = true)
#  |    |    |-- Military: long (nullable = true)
#  |    |    |-- Mini Golf: long (nullable = true)
#  |    |    |-- Minigames: long (nullable = true)
#  |    |    |-- Minimalist: long (nullable = true)
#  |    |    |-- Mining: long (nullable = true)
#  |    |    |-- Mod: long (nullable = true)
#  |    |    |-- Moddable: long (nullable = true)
#  |    |    |-- Modern: long (nullable = true)
#  |    |    |-- Motocross: long (nullable = true)
#  |    |    |-- Motorbike: long (nullable = true)
#  |    |    |-- Mouse only: long (nullable = true)
#  |    |    |-- Movie: long (nullable = true)
#  |    |    |-- Multiplayer: long (nullable = true)
#  |    |    |-- Multiple Endings: long (nullable = true)
#  |    |    |-- Music: long (nullable = true)
#  |    |    |-- Music-Based Procedural Generation: long (nullable = true)
#  |    |    |-- Musou: long (nullable = true)
#  |    |    |-- Mystery: long (nullable = true)
#  |    |    |-- Mystery Dungeon: long (nullable = true)
#  |    |    |-- Mythology: long (nullable = true)
#  |    |    |-- NSFW: long (nullable = true)
#  |    |    |-- Narration: long (nullable = true)
#  |    |    |-- Narrative: long (nullable = true)
#  |    |    |-- Nature: long (nullable = true)
#  |    |    |-- Naval: long (nullable = true)
#  |    |    |-- Naval Combat: long (nullable = true)
#  |    |    |-- Ninja: long (nullable = true)
#  |    |    |-- Noir: long (nullable = true)
#  |    |    |-- Nonlinear: long (nullable = true)
#  |    |    |-- Nostalgia: long (nullable = true)
#  |    |    |-- Nudity: long (nullable = true)
#  |    |    |-- Offroad: long (nullable = true)
#  |    |    |-- Old School: long (nullable = true)
#  |    |    |-- On-Rails Shooter: long (nullable = true)
#  |    |    |-- Online Co-Op: long (nullable = true)
#  |    |    |-- Open World: long (nullable = true)
#  |    |    |-- Open World Survival Craft: long (nullable = true)
#  |    |    |-- Otome: long (nullable = true)
#  |    |    |-- Outbreak Sim: long (nullable = true)
#  |    |    |-- Parkour: long (nullable = true)
#  |    |    |-- Parody : long (nullable = true)
#  |    |    |-- Party: long (nullable = true)
#  |    |    |-- Party Game: long (nullable = true)
#  |    |    |-- Party-Based RPG: long (nullable = true)
#  |    |    |-- Perma Death: long (nullable = true)
#  |    |    |-- Philosophical: long (nullable = true)
#  |    |    |-- Photo Editing: long (nullable = true)
#  |    |    |-- Physics: long (nullable = true)
#  |    |    |-- Pinball: long (nullable = true)
#  |    |    |-- Pirates: long (nullable = true)
#  |    |    |-- Pixel Graphics: long (nullable = true)
#  |    |    |-- Platformer: long (nullable = true)
#  |    |    |-- Point & Click: long (nullable = true)
#  |    |    |-- Political: long (nullable = true)
#  |    |    |-- Political Sim: long (nullable = true)
#  |    |    |-- Politics: long (nullable = true)
#  |    |    |-- Pool: long (nullable = true)
#  |    |    |-- Post-apocalyptic: long (nullable = true)
#  |    |    |-- Precision Platformer: long (nullable = true)
#  |    |    |-- Procedural Generation: long (nullable = true)
#  |    |    |-- Programming: long (nullable = true)
#  |    |    |-- Psychedelic: long (nullable = true)
#  |    |    |-- Psychological: long (nullable = true)
#  |    |    |-- Psychological Horror: long (nullable = true)
#  |    |    |-- Puzzle: long (nullable = true)
#  |    |    |-- Puzzle-Platformer: long (nullable = true)
#  |    |    |-- PvE: long (nullable = true)
#  |    |    |-- PvP: long (nullable = true)
#  |    |    |-- Quick-Time Events: long (nullable = true)
#  |    |    |-- RPG: long (nullable = true)
#  |    |    |-- RPGMaker: long (nullable = true)
#  |    |    |-- RTS: long (nullable = true)
#  |    |    |-- Racing: long (nullable = true)
#  |    |    |-- Real Time Tactics: long (nullable = true)
#  |    |    |-- Real-Time: long (nullable = true)
#  |    |    |-- Real-Time with Pause: long (nullable = true)
#  |    |    |-- Realistic: long (nullable = true)
#  |    |    |-- Reboot: long (nullable = true)
#  |    |    |-- Relaxing: long (nullable = true)
#  |    |    |-- Remake: long (nullable = true)
#  |    |    |-- Replay Value: long (nullable = true)
#  |    |    |-- Resource Management: long (nullable = true)
#  |    |    |-- Retro: long (nullable = true)
#  |    |    |-- Rhythm: long (nullable = true)
#  |    |    |-- Robots: long (nullable = true)
#  |    |    |-- Rock Music: long (nullable = true)
#  |    |    |-- Rogue-like: long (nullable = true)
#  |    |    |-- Rogue-lite: long (nullable = true)
#  |    |    |-- Roguelike Deckbuilder: long (nullable = true)
#  |    |    |-- Roguevania: long (nullable = true)
#  |    |    |-- Romance: long (nullable = true)
#  |    |    |-- Rome: long (nullable = true)
#  |    |    |-- Rugby: long (nullable = true)
#  |    |    |-- Runner: long (nullable = true)
#  |    |    |-- Sailing: long (nullable = true)
#  |    |    |-- Sandbox: long (nullable = true)
#  |    |    |-- Satire: long (nullable = true)
#  |    |    |-- Sci-fi: long (nullable = true)
#  |    |    |-- Science: long (nullable = true)
#  |    |    |-- Score Attack: long (nullable = true)
#  |    |    |-- Sequel: long (nullable = true)
#  |    |    |-- Sexual Content: long (nullable = true)
#  |    |    |-- Shoot 'Em Up: long (nullable = true)
#  |    |    |-- Shooter: long (nullable = true)
#  |    |    |-- Shop Keeper: long (nullable = true)
#  |    |    |-- Short: long (nullable = true)
#  |    |    |-- Side Scroller: long (nullable = true)
#  |    |    |-- Silent Protagonist: long (nullable = true)
#  |    |    |-- Simulation: long (nullable = true)
#  |    |    |-- Singleplayer: long (nullable = true)
#  |    |    |-- Skateboarding: long (nullable = true)
#  |    |    |-- Skating: long (nullable = true)
#  |    |    |-- Skiing: long (nullable = true)
#  |    |    |-- Sniper: long (nullable = true)
#  |    |    |-- Snooker: long (nullable = true)
#  |    |    |-- Snow: long (nullable = true)
#  |    |    |-- Snowboarding: long (nullable = true)
#  |    |    |-- Soccer: long (nullable = true)
#  |    |    |-- Social Deduction: long (nullable = true)
#  |    |    |-- Software: long (nullable = true)
#  |    |    |-- Software Training: long (nullable = true)
#  |    |    |-- Sokoban: long (nullable = true)
#  |    |    |-- Solitaire: long (nullable = true)
#  |    |    |-- Souls-like: long (nullable = true)
#  |    |    |-- Soundtrack: long (nullable = true)
#  |    |    |-- Space: long (nullable = true)
#  |    |    |-- Space Sim: long (nullable = true)
#  |    |    |-- Spaceships: long (nullable = true)
#  |    |    |-- Spectacle fighter: long (nullable = true)
#  |    |    |-- Spelling: long (nullable = true)
#  |    |    |-- Split Screen: long (nullable = true)
#  |    |    |-- Sports: long (nullable = true)
#  |    |    |-- Stealth: long (nullable = true)
#  |    |    |-- Steam Machine: long (nullable = true)
#  |    |    |-- Steampunk: long (nullable = true)
#  |    |    |-- Story Rich: long (nullable = true)
#  |    |    |-- Strategy: long (nullable = true)
#  |    |    |-- Strategy RPG: long (nullable = true)
#  |    |    |-- Stylized: long (nullable = true)
#  |    |    |-- Submarine: long (nullable = true)
#  |    |    |-- Superhero: long (nullable = true)
#  |    |    |-- Supernatural: long (nullable = true)
#  |    |    |-- Surreal: long (nullable = true)
#  |    |    |-- Survival: long (nullable = true)
#  |    |    |-- Survival Horror: long (nullable = true)
#  |    |    |-- Swordplay: long (nullable = true)
#  |    |    |-- Tabletop: long (nullable = true)
#  |    |    |-- Tactical: long (nullable = true)
#  |    |    |-- Tactical RPG: long (nullable = true)
#  |    |    |-- Tanks: long (nullable = true)
#  |    |    |-- Team-Based: long (nullable = true)
#  |    |    |-- Tennis: long (nullable = true)
#  |    |    |-- Text-Based: long (nullable = true)
#  |    |    |-- Third Person: long (nullable = true)
#  |    |    |-- Third-Person Shooter: long (nullable = true)
#  |    |    |-- Thriller: long (nullable = true)
#  |    |    |-- Tile-Matching: long (nullable = true)
#  |    |    |-- Time Attack: long (nullable = true)
#  |    |    |-- Time Management: long (nullable = true)
#  |    |    |-- Time Manipulation: long (nullable = true)
#  |    |    |-- Time Travel: long (nullable = true)
#  |    |    |-- Top-Down: long (nullable = true)
#  |    |    |-- Top-Down Shooter: long (nullable = true)
#  |    |    |-- Touch-Friendly: long (nullable = true)
#  |    |    |-- Tower Defense: long (nullable = true)
#  |    |    |-- TrackIR: long (nullable = true)
#  |    |    |-- Trading: long (nullable = true)
#  |    |    |-- Trading Card Game: long (nullable = true)
#  |    |    |-- Traditional Roguelike: long (nullable = true)
#  |    |    |-- Trains: long (nullable = true)
#  |    |    |-- Transhumanism: long (nullable = true)
#  |    |    |-- Transportation: long (nullable = true)
#  |    |    |-- Trivia: long (nullable = true)
#  |    |    |-- Turn-Based: long (nullable = true)
#  |    |    |-- Turn-Based Combat: long (nullable = true)
#  |    |    |-- Turn-Based Strategy: long (nullable = true)
#  |    |    |-- Turn-Based Tactics: long (nullable = true)
#  |    |    |-- Tutorial: long (nullable = true)
#  |    |    |-- Twin Stick Shooter: long (nullable = true)
#  |    |    |-- Typing: long (nullable = true)
#  |    |    |-- Underground: long (nullable = true)
#  |    |    |-- Underwater: long (nullable = true)
#  |    |    |-- Unforgiving: long (nullable = true)
#  |    |    |-- Utilities: long (nullable = true)
#  |    |    |-- VR: long (nullable = true)
#  |    |    |-- VR Only: long (nullable = true)
#  |    |    |-- Vampire: long (nullable = true)
#  |    |    |-- Vehicular Combat: long (nullable = true)
#  |    |    |-- Video Production: long (nullable = true)
#  |    |    |-- Vikings: long (nullable = true)
#  |    |    |-- Villain Protagonist: long (nullable = true)
#  |    |    |-- Violent: long (nullable = true)
#  |    |    |-- Visual Novel: long (nullable = true)
#  |    |    |-- Voice Control: long (nullable = true)
#  |    |    |-- Volleyball: long (nullable = true)
#  |    |    |-- Voxel: long (nullable = true)
#  |    |    |-- Walking Simulator: long (nullable = true)
#  |    |    |-- War: long (nullable = true)
#  |    |    |-- Wargame: long (nullable = true)
#  |    |    |-- Warhammer 40K: long (nullable = true)
#  |    |    |-- Web Publishing: long (nullable = true)
#  |    |    |-- Well-Written: long (nullable = true)
#  |    |    |-- Werewolves: long (nullable = true)
#  |    |    |-- Western: long (nullable = true)
#  |    |    |-- Wholesome: long (nullable = true)
#  |    |    |-- Word Game: long (nullable = true)
#  |    |    |-- World War I: long (nullable = true)
#  |    |    |-- World War II: long (nullable = true)
#  |    |    |-- Wrestling: long (nullable = true)
#  |    |    |-- Zombies: long (nullable = true)
#  |    |    |-- e-sports: long (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- website: string (nullable = true)
#  |-- id: string (nullable = true)

# %% [markdown]
# ## Nettoyage des champs
#
# Les caractères spéciaux sont remplacés par underscore "_"
# Les caractères "&" sont remplacés par "And"
# La structure des données ci-dessus montre l'existence de champs imbriqués dans d'autres champs.
# La fonction ci-dessous permet de descendre et parcourir tous les champs imbriqués pour les nettoyer.

# %% [markdown]
# #### Fonction de nettoyage

# %%
from pyspark.sql import DataFrame
from pyspark.sql.types import DataType, StructType, StructField, ArrayType
from copy import copy

def cleanDataFrame(df: DataFrame) -> DataFrame:
    ''' Fonction qui prend en paramètre un dataframe et retourne un dataframe nettoyé '''

    def sanitizeFieldName(s: str) -> str:
        ''' Fonction qui remplace les caractères spéciaux par underscore ou And '''
        return s.replace("&", "And").replace("-", "_").replace("\"", "_")\
            .replace("[", "_").replace("]", "_").replace(".", "_")\
            .replace(" ", "_").replace("'", "")
    
    def sanitizeField(field: StructField) -> StructField:
        ''' Fonction qui applique la fonction sanitizeFieldName() sur les champs '''
        field = copy(field)
        field.name = sanitizeFieldName(field.name)
        field.dataType = cleanSchema(field.dataType)
        return field
    
    def cleanSchema(dataType: [DataType]) -> [DataType]:
        ''' Fonction qui permet de descendre dans tous les champs imbriqués pour y appliquer la fonction de nettoyage '''
        dataType = copy(dataType)
        if isinstance(dataType, StructType):
            dataType.fields = [sanitizeField(f) for f in dataType.fields]
        elif isinstance(dataType, ArrayType):
            dataType.elementType = cleanSchema(dataType.elementType)
        return dataType

    # La fonction retourne un nouveau dataframe créé à partir du schéma nettoyé
    return spark.createDataFrame(df.rdd, cleanSchema(df.schema))

# %% [markdown]
# #### Application

# %%
df = cleanDataFrame(df)

# %% [markdown]
# Les noms des champs ont bien été nettoyées :

# %%
df.printSchema()
# Out:
# root
#  |-- data: struct (nullable = true)
#  |    |-- appid: long (nullable = true)
#  |    |-- categories: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- ccu: long (nullable = true)
#  |    |-- developer: string (nullable = true)
#  |    |-- discount: string (nullable = true)
#  |    |-- genre: string (nullable = true)
#  |    |-- header_image: string (nullable = true)
#  |    |-- initialprice: string (nullable = true)
#  |    |-- languages: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- negative: long (nullable = true)
#  |    |-- owners: string (nullable = true)
#  |    |-- platforms: struct (nullable = true)
#  |    |    |-- linux: boolean (nullable = true)
#  |    |    |-- mac: boolean (nullable = true)
#  |    |    |-- windows: boolean (nullable = true)
#  |    |-- positive: long (nullable = true)
#  |    |-- price: string (nullable = true)
#  |    |-- publisher: string (nullable = true)
#  |    |-- release_date: string (nullable = true)
#  |    |-- required_age: string (nullable = true)
#  |    |-- short_description: string (nullable = true)
#  |    |-- tags: struct (nullable = true)
#  |    |    |-- 1980s: long (nullable = true)
#  |    |    |-- 1990s: long (nullable = true)
#  |    |    |-- 2_5D: long (nullable = true)
#  |    |    |-- 2D: long (nullable = true)
#  |    |    |-- 2D_Fighter: long (nullable = true)
#  |    |    |-- 2D_Platformer: long (nullable = true)
#  |    |    |-- 360_Video: long (nullable = true)
#  |    |    |-- 3D: long (nullable = true)
#  |    |    |-- 3D_Fighter: long (nullable = true)
#  |    |    |-- 3D_Platformer: long (nullable = true)
#  |    |    |-- 3D_Vision: long (nullable = true)
#  |    |    |-- 4_Player_Local: long (nullable = true)
#  |    |    |-- 4X: long (nullable = true)
#  |    |    |-- 6DOF: long (nullable = true)
#  |    |    |-- 8_bit_Music: long (nullable = true)
#  |    |    |-- ATV: long (nullable = true)
#  |    |    |-- Abstract: long (nullable = true)
#  |    |    |-- Action: long (nullable = true)
#  |    |    |-- Action_RPG: long (nullable = true)
#  |    |    |-- Action_RTS: long (nullable = true)
#  |    |    |-- Action_Roguelike: long (nullable = true)
#  |    |    |-- Action_Adventure: long (nullable = true)
#  |    |    |-- Addictive: long (nullable = true)
#  |    |    |-- Adventure: long (nullable = true)
#  |    |    |-- Agriculture: long (nullable = true)
#  |    |    |-- Aliens: long (nullable = true)
#  |    |    |-- Alternate_History: long (nullable = true)
#  |    |    |-- Ambient: long (nullable = true)
#  |    |    |-- America: long (nullable = true)
#  |    |    |-- Animation_And_Modeling: long (nullable = true)
#  |    |    |-- Anime: long (nullable = true)
#  |    |    |-- Arcade: long (nullable = true)
#  |    |    |-- Archery: long (nullable = true)
#  |    |    |-- Arena_Shooter: long (nullable = true)
#  |    |    |-- Artificial_Intelligence: long (nullable = true)
#  |    |    |-- Assassin: long (nullable = true)
#  |    |    |-- Asymmetric_VR: long (nullable = true)
#  |    |    |-- Asynchronous_Multiplayer: long (nullable = true)
#  |    |    |-- Atmospheric: long (nullable = true)
#  |    |    |-- Audio_Production: long (nullable = true)
#  |    |    |-- Auto_Battler: long (nullable = true)
#  |    |    |-- Automation: long (nullable = true)
#  |    |    |-- Automobile_Sim: long (nullable = true)
#  |    |    |-- BMX: long (nullable = true)
#  |    |    |-- Base_Building: long (nullable = true)
#  |    |    |-- Baseball: long (nullable = true)
#  |    |    |-- Based_On_A_Novel: long (nullable = true)
#  |    |    |-- Basketball: long (nullable = true)
#  |    |    |-- Battle_Royale: long (nullable = true)
#  |    |    |-- Beat_em_up: long (nullable = true)
#  |    |    |-- Beautiful: long (nullable = true)
#  |    |    |-- Benchmark: long (nullable = true)
#  |    |    |-- Bikes: long (nullable = true)
#  |    |    |-- Blood: long (nullable = true)
#  |    |    |-- Board_Game: long (nullable = true)
#  |    |    |-- Boss_Rush: long (nullable = true)
#  |    |    |-- Bowling: long (nullable = true)
#  |    |    |-- Boxing: long (nullable = true)
#  |    |    |-- Building: long (nullable = true)
#  |    |    |-- Bullet_Hell: long (nullable = true)
#  |    |    |-- Bullet_Time: long (nullable = true)
#  |    |    |-- CRPG: long (nullable = true)
#  |    |    |-- Capitalism: long (nullable = true)
#  |    |    |-- Card_Battler: long (nullable = true)
#  |    |    |-- Card_Game: long (nullable = true)
#  |    |    |-- Cartoon: long (nullable = true)
#  |    |    |-- Cartoony: long (nullable = true)
#  |    |    |-- Casual: long (nullable = true)
#  |    |    |-- Cats: long (nullable = true)
#  |    |    |-- Character_Action_Game: long (nullable = true)
#  |    |    |-- Character_Customization: long (nullable = true)
#  |    |    |-- Chess: long (nullable = true)
#  |    |    |-- Choices_Matter: long (nullable = true)
#  |    |    |-- Choose_Your_Own_Adventure: long (nullable = true)
#  |    |    |-- Cinematic: long (nullable = true)
#  |    |    |-- City_Builder: long (nullable = true)
#  |    |    |-- Class_Based: long (nullable = true)
#  |    |    |-- Classic: long (nullable = true)
#  |    |    |-- Clicker: long (nullable = true)
#  |    |    |-- Co_op: long (nullable = true)
#  |    |    |-- Co_op_Campaign: long (nullable = true)
#  |    |    |-- Coding: long (nullable = true)
#  |    |    |-- Cold_War: long (nullable = true)
#  |    |    |-- Collectathon: long (nullable = true)
#  |    |    |-- Colony_Sim: long (nullable = true)
#  |    |    |-- Colorful: long (nullable = true)
#  |    |    |-- Combat: long (nullable = true)
#  |    |    |-- Combat_Racing: long (nullable = true)
#  |    |    |-- Comedy: long (nullable = true)
#  |    |    |-- Comic_Book: long (nullable = true)
#  |    |    |-- Competitive: long (nullable = true)
#  |    |    |-- Conspiracy: long (nullable = true)
#  |    |    |-- Controller: long (nullable = true)
#  |    |    |-- Conversation: long (nullable = true)
#  |    |    |-- Cooking: long (nullable = true)
#  |    |    |-- Cozy: long (nullable = true)
#  |    |    |-- Crafting: long (nullable = true)
#  |    |    |-- Creature_Collector: long (nullable = true)
#  |    |    |-- Cricket: long (nullable = true)
#  |    |    |-- Crime: long (nullable = true)
#  |    |    |-- Crowdfunded: long (nullable = true)
#  |    |    |-- Cult_Classic: long (nullable = true)
#  |    |    |-- Cute: long (nullable = true)
#  |    |    |-- Cyberpunk: long (nullable = true)
#  |    |    |-- Cycling: long (nullable = true)
#  |    |    |-- Dark: long (nullable = true)
#  |    |    |-- Dark_Comedy: long (nullable = true)
#  |    |    |-- Dark_Fantasy: long (nullable = true)
#  |    |    |-- Dark_Humor: long (nullable = true)
#  |    |    |-- Dating_Sim: long (nullable = true)
#  |    |    |-- Deckbuilding: long (nullable = true)
#  |    |    |-- Demons: long (nullable = true)
#  |    |    |-- Design_And_Illustration: long (nullable = true)
#  |    |    |-- Destruction: long (nullable = true)
#  |    |    |-- Detective: long (nullable = true)
#  |    |    |-- Difficult: long (nullable = true)
#  |    |    |-- Dinosaurs: long (nullable = true)
#  |    |    |-- Diplomacy: long (nullable = true)
#  |    |    |-- Documentary: long (nullable = true)
#  |    |    |-- Dog: long (nullable = true)
#  |    |    |-- Dragons: long (nullable = true)
#  |    |    |-- Drama: long (nullable = true)
#  |    |    |-- Driving: long (nullable = true)
#  |    |    |-- Dungeon_Crawler: long (nullable = true)
#  |    |    |-- Dungeons_And_Dragons: long (nullable = true)
#  |    |    |-- Dynamic_Narration: long (nullable = true)
#  |    |    |-- Dystopian_: long (nullable = true)
#  |    |    |-- Early_Access: long (nullable = true)
#  |    |    |-- Economy: long (nullable = true)
#  |    |    |-- Education: long (nullable = true)
#  |    |    |-- Electronic: long (nullable = true)
#  |    |    |-- Electronic_Music: long (nullable = true)
#  |    |    |-- Emotional: long (nullable = true)
#  |    |    |-- Epic: long (nullable = true)
#  |    |    |-- Episodic: long (nullable = true)
#  |    |    |-- Escape_Room: long (nullable = true)
#  |    |    |-- Experience: long (nullable = true)
#  |    |    |-- Experimental: long (nullable = true)
#  |    |    |-- Exploration: long (nullable = true)
#  |    |    |-- FMV: long (nullable = true)
#  |    |    |-- FPS: long (nullable = true)
#  |    |    |-- Faith: long (nullable = true)
#  |    |    |-- Family_Friendly: long (nullable = true)
#  |    |    |-- Fantasy: long (nullable = true)
#  |    |    |-- Farming: long (nullable = true)
#  |    |    |-- Farming_Sim: long (nullable = true)
#  |    |    |-- Fast_Paced: long (nullable = true)
#  |    |    |-- Feature_Film: long (nullable = true)
#  |    |    |-- Female_Protagonist: long (nullable = true)
#  |    |    |-- Fighting: long (nullable = true)
#  |    |    |-- First_Person: long (nullable = true)
#  |    |    |-- Fishing: long (nullable = true)
#  |    |    |-- Flight: long (nullable = true)
#  |    |    |-- Football: long (nullable = true)
#  |    |    |-- Foreign: long (nullable = true)
#  |    |    |-- Free_to_Play: long (nullable = true)
#  |    |    |-- Funny: long (nullable = true)
#  |    |    |-- Futuristic: long (nullable = true)
#  |    |    |-- Gambling: long (nullable = true)
#  |    |    |-- Game_Development: long (nullable = true)
#  |    |    |-- GameMaker: long (nullable = true)
#  |    |    |-- Games_Workshop: long (nullable = true)
#  |    |    |-- Gaming: long (nullable = true)
#  |    |    |-- God_Game: long (nullable = true)
#  |    |    |-- Golf: long (nullable = true)
#  |    |    |-- Gore: long (nullable = true)
#  |    |    |-- Gothic: long (nullable = true)
#  |    |    |-- Grand_Strategy: long (nullable = true)
#  |    |    |-- Great_Soundtrack: long (nullable = true)
#  |    |    |-- Grid_Based_Movement: long (nullable = true)
#  |    |    |-- Gun_Customization: long (nullable = true)
#  |    |    |-- Hack_and_Slash: long (nullable = true)
#  |    |    |-- Hacking: long (nullable = true)
#  |    |    |-- Hand_drawn: long (nullable = true)
#  |    |    |-- Hardware: long (nullable = true)
#  |    |    |-- Heist: long (nullable = true)
#  |    |    |-- Hentai: long (nullable = true)
#  |    |    |-- Hero_Shooter: long (nullable = true)
#  |    |    |-- Hex_Grid: long (nullable = true)
#  |    |    |-- Hidden_Object: long (nullable = true)
#  |    |    |-- Historical: long (nullable = true)
#  |    |    |-- Hockey: long (nullable = true)
#  |    |    |-- Horror: long (nullable = true)
#  |    |    |-- Horses: long (nullable = true)
#  |    |    |-- Hunting: long (nullable = true)
#  |    |    |-- Idler: long (nullable = true)
#  |    |    |-- Illuminati: long (nullable = true)
#  |    |    |-- Immersive: long (nullable = true)
#  |    |    |-- Immersive_Sim: long (nullable = true)
#  |    |    |-- Indie: long (nullable = true)
#  |    |    |-- Instrumental_Music: long (nullable = true)
#  |    |    |-- Intentionally_Awkward_Controls: long (nullable = true)
#  |    |    |-- Interactive_Fiction: long (nullable = true)
#  |    |    |-- Inventory_Management: long (nullable = true)
#  |    |    |-- Investigation: long (nullable = true)
#  |    |    |-- Isometric: long (nullable = true)
#  |    |    |-- JRPG: long (nullable = true)
#  |    |    |-- Jet: long (nullable = true)
#  |    |    |-- Job_Simulator: long (nullable = true)
#  |    |    |-- Jump_Scare: long (nullable = true)
#  |    |    |-- Kickstarter: long (nullable = true)
#  |    |    |-- LEGO: long (nullable = true)
#  |    |    |-- LGBTQ+: long (nullable = true)
#  |    |    |-- Lemmings: long (nullable = true)
#  |    |    |-- Level_Editor: long (nullable = true)
#  |    |    |-- Life_Sim: long (nullable = true)
#  |    |    |-- Linear: long (nullable = true)
#  |    |    |-- Local_Co_Op: long (nullable = true)
#  |    |    |-- Local_Multiplayer: long (nullable = true)
#  |    |    |-- Logic: long (nullable = true)
#  |    |    |-- Loot: long (nullable = true)
#  |    |    |-- Looter_Shooter: long (nullable = true)
#  |    |    |-- Lore_Rich: long (nullable = true)
#  |    |    |-- Lovecraftian: long (nullable = true)
#  |    |    |-- MMORPG: long (nullable = true)
#  |    |    |-- MOBA: long (nullable = true)
#  |    |    |-- Magic: long (nullable = true)
#  |    |    |-- Mahjong: long (nullable = true)
#  |    |    |-- Management: long (nullable = true)
#  |    |    |-- Mars: long (nullable = true)
#  |    |    |-- Martial_Arts: long (nullable = true)
#  |    |    |-- Massively_Multiplayer: long (nullable = true)
#  |    |    |-- Masterpiece: long (nullable = true)
#  |    |    |-- Match_3: long (nullable = true)
#  |    |    |-- Mature: long (nullable = true)
#  |    |    |-- Mechs: long (nullable = true)
#  |    |    |-- Medical_Sim: long (nullable = true)
#  |    |    |-- Medieval: long (nullable = true)
#  |    |    |-- Memes: long (nullable = true)
#  |    |    |-- Metroidvania: long (nullable = true)
#  |    |    |-- Military: long (nullable = true)
#  |    |    |-- Mini_Golf: long (nullable = true)
#  |    |    |-- Minigames: long (nullable = true)
#  |    |    |-- Minimalist: long (nullable = true)
#  |    |    |-- Mining: long (nullable = true)
#  |    |    |-- Mod: long (nullable = true)
#  |    |    |-- Moddable: long (nullable = true)
#  |    |    |-- Modern: long (nullable = true)
#  |    |    |-- Motocross: long (nullable = true)
#  |    |    |-- Motorbike: long (nullable = true)
#  |    |    |-- Mouse_only: long (nullable = true)
#  |    |    |-- Movie: long (nullable = true)
#  |    |    |-- Multiplayer: long (nullable = true)
#  |    |    |-- Multiple_Endings: long (nullable = true)
#  |    |    |-- Music: long (nullable = true)
#  |    |    |-- Music_Based_Procedural_Generation: long (nullable = true)
#  |    |    |-- Musou: long (nullable = true)
#  |    |    |-- Mystery: long (nullable = true)
#  |    |    |-- Mystery_Dungeon: long (nullable = true)
#  |    |    |-- Mythology: long (nullable = true)
#  |    |    |-- NSFW: long (nullable = true)
#  |    |    |-- Narration: long (nullable = true)
#  |    |    |-- Narrative: long (nullable = true)
#  |    |    |-- Nature: long (nullable = true)
#  |    |    |-- Naval: long (nullable = true)
#  |    |    |-- Naval_Combat: long (nullable = true)
#  |    |    |-- Ninja: long (nullable = true)
#  |    |    |-- Noir: long (nullable = true)
#  |    |    |-- Nonlinear: long (nullable = true)
#  |    |    |-- Nostalgia: long (nullable = true)
#  |    |    |-- Nudity: long (nullable = true)
#  |    |    |-- Offroad: long (nullable = true)
#  |    |    |-- Old_School: long (nullable = true)
#  |    |    |-- On_Rails_Shooter: long (nullable = true)
#  |    |    |-- Online_Co_Op: long (nullable = true)
#  |    |    |-- Open_World: long (nullable = true)
#  |    |    |-- Open_World_Survival_Craft: long (nullable = true)
#  |    |    |-- Otome: long (nullable = true)
#  |    |    |-- Outbreak_Sim: long (nullable = true)
#  |    |    |-- Parkour: long (nullable = true)
#  |    |    |-- Parody_: long (nullable = true)
#  |    |    |-- Party: long (nullable = true)
#  |    |    |-- Party_Game: long (nullable = true)
#  |    |    |-- Party_Based_RPG: long (nullable = true)
#  |    |    |-- Perma_Death: long (nullable = true)
#  |    |    |-- Philosophical: long (nullable = true)
#  |    |    |-- Photo_Editing: long (nullable = true)
#  |    |    |-- Physics: long (nullable = true)
#  |    |    |-- Pinball: long (nullable = true)
#  |    |    |-- Pirates: long (nullable = true)
#  |    |    |-- Pixel_Graphics: long (nullable = true)
#  |    |    |-- Platformer: long (nullable = true)
#  |    |    |-- Point_And_Click: long (nullable = true)
#  |    |    |-- Political: long (nullable = true)
#  |    |    |-- Political_Sim: long (nullable = true)
#  |    |    |-- Politics: long (nullable = true)
#  |    |    |-- Pool: long (nullable = true)
#  |    |    |-- Post_apocalyptic: long (nullable = true)
#  |    |    |-- Precision_Platformer: long (nullable = true)
#  |    |    |-- Procedural_Generation: long (nullable = true)
#  |    |    |-- Programming: long (nullable = true)
#  |    |    |-- Psychedelic: long (nullable = true)
#  |    |    |-- Psychological: long (nullable = true)
#  |    |    |-- Psychological_Horror: long (nullable = true)
#  |    |    |-- Puzzle: long (nullable = true)
#  |    |    |-- Puzzle_Platformer: long (nullable = true)
#  |    |    |-- PvE: long (nullable = true)
#  |    |    |-- PvP: long (nullable = true)
#  |    |    |-- Quick_Time_Events: long (nullable = true)
#  |    |    |-- RPG: long (nullable = true)
#  |    |    |-- RPGMaker: long (nullable = true)
#  |    |    |-- RTS: long (nullable = true)
#  |    |    |-- Racing: long (nullable = true)
#  |    |    |-- Real_Time_Tactics: long (nullable = true)
#  |    |    |-- Real_Time: long (nullable = true)
#  |    |    |-- Real_Time_with_Pause: long (nullable = true)
#  |    |    |-- Realistic: long (nullable = true)
#  |    |    |-- Reboot: long (nullable = true)
#  |    |    |-- Relaxing: long (nullable = true)
#  |    |    |-- Remake: long (nullable = true)
#  |    |    |-- Replay_Value: long (nullable = true)
#  |    |    |-- Resource_Management: long (nullable = true)
#  |    |    |-- Retro: long (nullable = true)
#  |    |    |-- Rhythm: long (nullable = true)
#  |    |    |-- Robots: long (nullable = true)
#  |    |    |-- Rock_Music: long (nullable = true)
#  |    |    |-- Rogue_like: long (nullable = true)
#  |    |    |-- Rogue_lite: long (nullable = true)
#  |    |    |-- Roguelike_Deckbuilder: long (nullable = true)
#  |    |    |-- Roguevania: long (nullable = true)
#  |    |    |-- Romance: long (nullable = true)
#  |    |    |-- Rome: long (nullable = true)
#  |    |    |-- Rugby: long (nullable = true)
#  |    |    |-- Runner: long (nullable = true)
#  |    |    |-- Sailing: long (nullable = true)
#  |    |    |-- Sandbox: long (nullable = true)
#  |    |    |-- Satire: long (nullable = true)
#  |    |    |-- Sci_fi: long (nullable = true)
#  |    |    |-- Science: long (nullable = true)
#  |    |    |-- Score_Attack: long (nullable = true)
#  |    |    |-- Sequel: long (nullable = true)
#  |    |    |-- Sexual_Content: long (nullable = true)
#  |    |    |-- Shoot_Em_Up: long (nullable = true)
#  |    |    |-- Shooter: long (nullable = true)
#  |    |    |-- Shop_Keeper: long (nullable = true)
#  |    |    |-- Short: long (nullable = true)
#  |    |    |-- Side_Scroller: long (nullable = true)
#  |    |    |-- Silent_Protagonist: long (nullable = true)
#  |    |    |-- Simulation: long (nullable = true)
#  |    |    |-- Singleplayer: long (nullable = true)
#  |    |    |-- Skateboarding: long (nullable = true)
#  |    |    |-- Skating: long (nullable = true)
#  |    |    |-- Skiing: long (nullable = true)
#  |    |    |-- Sniper: long (nullable = true)
#  |    |    |-- Snooker: long (nullable = true)
#  |    |    |-- Snow: long (nullable = true)
#  |    |    |-- Snowboarding: long (nullable = true)
#  |    |    |-- Soccer: long (nullable = true)
#  |    |    |-- Social_Deduction: long (nullable = true)
#  |    |    |-- Software: long (nullable = true)
#  |    |    |-- Software_Training: long (nullable = true)
#  |    |    |-- Sokoban: long (nullable = true)
#  |    |    |-- Solitaire: long (nullable = true)
#  |    |    |-- Souls_like: long (nullable = true)
#  |    |    |-- Soundtrack: long (nullable = true)
#  |    |    |-- Space: long (nullable = true)
#  |    |    |-- Space_Sim: long (nullable = true)
#  |    |    |-- Spaceships: long (nullable = true)
#  |    |    |-- Spectacle_fighter: long (nullable = true)
#  |    |    |-- Spelling: long (nullable = true)
#  |    |    |-- Split_Screen: long (nullable = true)
#  |    |    |-- Sports: long (nullable = true)
#  |    |    |-- Stealth: long (nullable = true)
#  |    |    |-- Steam_Machine: long (nullable = true)
#  |    |    |-- Steampunk: long (nullable = true)
#  |    |    |-- Story_Rich: long (nullable = true)
#  |    |    |-- Strategy: long (nullable = true)
#  |    |    |-- Strategy_RPG: long (nullable = true)
#  |    |    |-- Stylized: long (nullable = true)
#  |    |    |-- Submarine: long (nullable = true)
#  |    |    |-- Superhero: long (nullable = true)
#  |    |    |-- Supernatural: long (nullable = true)
#  |    |    |-- Surreal: long (nullable = true)
#  |    |    |-- Survival: long (nullable = true)
#  |    |    |-- Survival_Horror: long (nullable = true)
#  |    |    |-- Swordplay: long (nullable = true)
#  |    |    |-- Tabletop: long (nullable = true)
#  |    |    |-- Tactical: long (nullable = true)
#  |    |    |-- Tactical_RPG: long (nullable = true)
#  |    |    |-- Tanks: long (nullable = true)
#  |    |    |-- Team_Based: long (nullable = true)
#  |    |    |-- Tennis: long (nullable = true)
#  |    |    |-- Text_Based: long (nullable = true)
#  |    |    |-- Third_Person: long (nullable = true)
#  |    |    |-- Third_Person_Shooter: long (nullable = true)
#  |    |    |-- Thriller: long (nullable = true)
#  |    |    |-- Tile_Matching: long (nullable = true)
#  |    |    |-- Time_Attack: long (nullable = true)
#  |    |    |-- Time_Management: long (nullable = true)
#  |    |    |-- Time_Manipulation: long (nullable = true)
#  |    |    |-- Time_Travel: long (nullable = true)
#  |    |    |-- Top_Down: long (nullable = true)
#  |    |    |-- Top_Down_Shooter: long (nullable = true)
#  |    |    |-- Touch_Friendly: long (nullable = true)
#  |    |    |-- Tower_Defense: long (nullable = true)
#  |    |    |-- TrackIR: long (nullable = true)
#  |    |    |-- Trading: long (nullable = true)
#  |    |    |-- Trading_Card_Game: long (nullable = true)
#  |    |    |-- Traditional_Roguelike: long (nullable = true)
#  |    |    |-- Trains: long (nullable = true)
#  |    |    |-- Transhumanism: long (nullable = true)
#  |    |    |-- Transportation: long (nullable = true)
#  |    |    |-- Trivia: long (nullable = true)
#  |    |    |-- Turn_Based: long (nullable = true)
#  |    |    |-- Turn_Based_Combat: long (nullable = true)
#  |    |    |-- Turn_Based_Strategy: long (nullable = true)
#  |    |    |-- Turn_Based_Tactics: long (nullable = true)
#  |    |    |-- Tutorial: long (nullable = true)
#  |    |    |-- Twin_Stick_Shooter: long (nullable = true)
#  |    |    |-- Typing: long (nullable = true)
#  |    |    |-- Underground: long (nullable = true)
#  |    |    |-- Underwater: long (nullable = true)
#  |    |    |-- Unforgiving: long (nullable = true)
#  |    |    |-- Utilities: long (nullable = true)
#  |    |    |-- VR: long (nullable = true)
#  |    |    |-- VR_Only: long (nullable = true)
#  |    |    |-- Vampire: long (nullable = true)
#  |    |    |-- Vehicular_Combat: long (nullable = true)
#  |    |    |-- Video_Production: long (nullable = true)
#  |    |    |-- Vikings: long (nullable = true)
#  |    |    |-- Villain_Protagonist: long (nullable = true)
#  |    |    |-- Violent: long (nullable = true)
#  |    |    |-- Visual_Novel: long (nullable = true)
#  |    |    |-- Voice_Control: long (nullable = true)
#  |    |    |-- Volleyball: long (nullable = true)
#  |    |    |-- Voxel: long (nullable = true)
#  |    |    |-- Walking_Simulator: long (nullable = true)
#  |    |    |-- War: long (nullable = true)
#  |    |    |-- Wargame: long (nullable = true)
#  |    |    |-- Warhammer_40K: long (nullable = true)
#  |    |    |-- Web_Publishing: long (nullable = true)
#  |    |    |-- Well_Written: long (nullable = true)
#  |    |    |-- Werewolves: long (nullable = true)
#  |    |    |-- Western: long (nullable = true)
#  |    |    |-- Wholesome: long (nullable = true)
#  |    |    |-- Word_Game: long (nullable = true)
#  |    |    |-- World_War_I: long (nullable = true)
#  |    |    |-- World_War_II: long (nullable = true)
#  |    |    |-- Wrestling: long (nullable = true)
#  |    |    |-- Zombies: long (nullable = true)
#  |    |    |-- e_sports: long (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- website: string (nullable = true)
#  |-- id: string (nullable = true)

# %% [markdown]
# ## Récupération des champs

# %% [markdown]
# #### Fonction pour récupérer les champs

# %%
from pyspark.sql.types import StructType, StructField
from typing import List, Dict, Generator, Union, Callable

def walkSchema(schema: Union[StructType, StructField]) -> Generator[str, None, None]:
    """ Fonction qui parcourt le schéma pour retourner tous les champs et champs imbriqués """
    """ Elle prend en paramètre un schéma PySpark et retourne un Generator qui est un itérable """

    def _walk(schema_dct: Dict['str', Union['str', list, dict]],
              prefix: str = "") -> Generator[str, None, None]:
        assert isinstance(prefix, str), "prefix should be a string"
        
        fullName: Callable[str, str] = lambda name: ( 
            name if not prefix else f"{prefix}.{name}")
        
        name = schema_dct.get('name', '')

        if schema_dct['type'] == 'struct':
            assert 'fields' in schema_dct, (
                "It's a StructType, we should have some fields")
            for field in schema_dct['fields']:
                yield from _walk(field, prefix=prefix)
        elif isinstance(schema_dct['type'], dict):
            assert 'fields' not in schema_dct, (
                "We're missing some keys here")
            yield from _walk(schema_dct['type'], prefix=fullName(name))
        elif name:
            yield fullName(name)
    
    yield from _walk(schema.jsonValue())

# %% [markdown]
# #### Application

# %%
col_names = walkSchema(df.schema)

# %%
for col in col_names:
    print(col)
# Out:
# data.appid
# data.ccu
# data.developer
# data.discount
# data.genre
# data.header_image
# data.initialprice
# data.languages
# data.name
# data.negative
# data.owners
# data.platforms.linux
# data.platforms.mac
# data.platforms.windows
# data.positive
# data.price
# data.publisher
# data.release_date
# data.required_age
# data.short_description
# data.tags.1980s
# data.tags.1990s
# data.tags.2_5D
# data.tags.2D
# data.tags.2D_Fighter
# data.tags.2D_Platformer
# data.tags.360_Video
# data.tags.3D
# data.tags.3D_Fighter
# data.tags.3D_Platformer
# data.tags.3D_Vision
# data.tags.4_Player_Local
# data.tags.4X
# data.tags.6DOF
# data.tags.8_bit_Music
# data.tags.ATV
# data.tags.Abstract
# data.tags.Action
# data.tags.Action_RPG
# data.tags.Action_RTS
# data.tags.Action_Roguelike
# data.tags.Action_Adventure
# data.tags.Addictive
# data.tags.Adventure
# data.tags.Agriculture
# data.tags.Aliens
# data.tags.Alternate_History
# data.tags.Ambient
# data.tags.America
# data.tags.Animation_And_Modeling
# data.tags.Anime
# data.tags.Arcade
# data.tags.Archery
# data.tags.Arena_Shooter
# data.tags.Artificial_Intelligence
# data.tags.Assassin
# data.tags.Asymmetric_VR
# data.tags.Asynchronous_Multiplayer
# data.tags.Atmospheric
# data.tags.Audio_Production
# data.tags.Auto_Battler
# data.tags.Automation
# data.tags.Automobile_Sim
# data.tags.BMX
# data.tags.Base_Building
# data.tags.Baseball
# data.tags.Based_On_A_Novel
# data.tags.Basketball
# data.tags.Battle_Royale
# data.tags.Beat_em_up
# data.tags.Beautiful
# data.tags.Benchmark
# data.tags.Bikes
# data.tags.Blood
# data.tags.Board_Game
# data.tags.Boss_Rush
# data.tags.Bowling
# data.tags.Boxing
# data.tags.Building
# data.tags.Bullet_Hell
# data.tags.Bullet_Time
# data.tags.CRPG
# data.tags.Capitalism
# data.tags.Card_Battler
# data.tags.Card_Game
# data.tags.Cartoon
# data.tags.Cartoony
# data.tags.Casual
# data.tags.Cats
# data.tags.Character_Action_Game
# data.tags.Character_Customization
# data.tags.Chess
# data.tags.Choices_Matter
# data.tags.Choose_Your_Own_Adventure
# data.tags.Cinematic
# data.tags.City_Builder
# data.tags.Class_Based
# data.tags.Classic
# data.tags.Clicker
# data.tags.Co_op
# data.tags.Co_op_Campaign
# data.tags.Coding
# data.tags.Cold_War
# data.tags.Collectathon
# data.tags.Colony_Sim
# data.tags.Colorful
# data.tags.Combat
# data.tags.Combat_Racing
# data.tags.Comedy
# data.tags.Comic_Book
# data.tags.Competitive
# data.tags.Conspiracy
# data.tags.Controller
# data.tags.Conversation
# data.tags.Cooking
# data.tags.Cozy
# data.tags.Crafting
# data.tags.Creature_Collector
# data.tags.Cricket
# data.tags.Crime
# data.tags.Crowdfunded
# data.tags.Cult_Classic
# data.tags.Cute
# data.tags.Cyberpunk
# data.tags.Cycling
# data.tags.Dark
# data.tags.Dark_Comedy
# data.tags.Dark_Fantasy
# data.tags.Dark_Humor
# data.tags.Dating_Sim
# data.tags.Deckbuilding
# data.tags.Demons
# data.tags.Design_And_Illustration
# data.tags.Destruction
# data.tags.Detective
# data.tags.Difficult
# data.tags.Dinosaurs
# data.tags.Diplomacy
# data.tags.Documentary
# data.tags.Dog
# data.tags.Dragons
# data.tags.Drama
# data.tags.Driving
# data.tags.Dungeon_Crawler
# data.tags.Dungeons_And_Dragons
# data.tags.Dynamic_Narration
# data.tags.Dystopian_
# data.tags.Early_Access
# data.tags.Economy
# data.tags.Education
# data.tags.Electronic
# data.tags.Electronic_Music
# data.tags.Emotional
# data.tags.Epic
# data.tags.Episodic
# data.tags.Escape_Room
# data.tags.Experience
# data.tags.Experimental
# data.tags.Exploration
# data.tags.FMV
# data.tags.FPS
# data.tags.Faith
# data.tags.Family_Friendly
# data.tags.Fantasy
# data.tags.Farming
# data.tags.Farming_Sim
# data.tags.Fast_Paced
# data.tags.Feature_Film
# data.tags.Female_Protagonist
# data.tags.Fighting
# data.tags.First_Person
# data.tags.Fishing
# data.tags.Flight
# data.tags.Football
# data.tags.Foreign
# data.tags.Free_to_Play
# data.tags.Funny
# data.tags.Futuristic
# data.tags.Gambling
# data.tags.Game_Development
# data.tags.GameMaker
# data.tags.Games_Workshop
# data.tags.Gaming
# data.tags.God_Game
# data.tags.Golf
# data.tags.Gore
# data.tags.Gothic
# data.tags.Grand_Strategy
# data.tags.Great_Soundtrack
# data.tags.Grid_Based_Movement
# data.tags.Gun_Customization
# data.tags.Hack_and_Slash
# data.tags.Hacking
# data.tags.Hand_drawn
# data.tags.Hardware
# data.tags.Heist
# data.tags.Hentai
# data.tags.Hero_Shooter
# data.tags.Hex_Grid
# data.tags.Hidden_Object
# data.tags.Historical
# data.tags.Hockey
# data.tags.Horror
# data.tags.Horses
# data.tags.Hunting
# data.tags.Idler
# data.tags.Illuminati
# data.tags.Immersive
# data.tags.Immersive_Sim
# data.tags.Indie
# data.tags.Instrumental_Music
# data.tags.Intentionally_Awkward_Controls
# data.tags.Interactive_Fiction
# data.tags.Inventory_Management
# data.tags.Investigation
# data.tags.Isometric
# data.tags.JRPG
# data.tags.Jet
# data.tags.Job_Simulator
# data.tags.Jump_Scare
# data.tags.Kickstarter
# data.tags.LEGO
# data.tags.LGBTQ+
# data.tags.Lemmings
# data.tags.Level_Editor
# data.tags.Life_Sim
# data.tags.Linear
# data.tags.Local_Co_Op
# data.tags.Local_Multiplayer
# data.tags.Logic
# data.tags.Loot
# data.tags.Looter_Shooter
# data.tags.Lore_Rich
# data.tags.Lovecraftian
# data.tags.MMORPG
# data.tags.MOBA
# data.tags.Magic
# data.tags.Mahjong
# data.tags.Management
# data.tags.Mars
# data.tags.Martial_Arts
# data.tags.Massively_Multiplayer
# data.tags.Masterpiece
# data.tags.Match_3
# data.tags.Mature
# data.tags.Mechs
# data.tags.Medical_Sim
# data.tags.Medieval
# data.tags.Memes
# data.tags.Metroidvania
# data.tags.Military
# data.tags.Mini_Golf
# data.tags.Minigames
# data.tags.Minimalist
# data.tags.Mining
# data.tags.Mod
# data.tags.Moddable
# data.tags.Modern
# data.tags.Motocross
# data.tags.Motorbike
# data.tags.Mouse_only
# data.tags.Movie
# data.tags.Multiplayer
# data.tags.Multiple_Endings
# data.tags.Music
# data.tags.Music_Based_Procedural_Generation
# data.tags.Musou
# data.tags.Mystery
# data.tags.Mystery_Dungeon
# data.tags.Mythology
# data.tags.NSFW
# data.tags.Narration
# data.tags.Narrative
# data.tags.Nature
# data.tags.Naval
# data.tags.Naval_Combat
# data.tags.Ninja
# data.tags.Noir
# data.tags.Nonlinear
# data.tags.Nostalgia
# data.tags.Nudity
# data.tags.Offroad
# data.tags.Old_School
# data.tags.On_Rails_Shooter
# data.tags.Online_Co_Op
# data.tags.Open_World
# data.tags.Open_World_Survival_Craft
# data.tags.Otome
# data.tags.Outbreak_Sim
# data.tags.Parkour
# data.tags.Parody_
# data.tags.Party
# data.tags.Party_Game
# data.tags.Party_Based_RPG
# data.tags.Perma_Death
# data.tags.Philosophical
# data.tags.Photo_Editing
# data.tags.Physics
# data.tags.Pinball
# data.tags.Pirates
# data.tags.Pixel_Graphics
# data.tags.Platformer
# data.tags.Point_And_Click
# data.tags.Political
# data.tags.Political_Sim
# data.tags.Politics
# data.tags.Pool
# data.tags.Post_apocalyptic
# data.tags.Precision_Platformer
# data.tags.Procedural_Generation
# data.tags.Programming
# data.tags.Psychedelic
# data.tags.Psychological
# data.tags.Psychological_Horror
# data.tags.Puzzle
# data.tags.Puzzle_Platformer
# data.tags.PvE
# data.tags.PvP
# data.tags.Quick_Time_Events
# data.tags.RPG
# data.tags.RPGMaker
# data.tags.RTS
# data.tags.Racing
# data.tags.Real_Time_Tactics
# data.tags.Real_Time
# data.tags.Real_Time_with_Pause
# data.tags.Realistic
# data.tags.Reboot
# data.tags.Relaxing
# data.tags.Remake
# data.tags.Replay_Value
# data.tags.Resource_Management
# data.tags.Retro
# data.tags.Rhythm
# data.tags.Robots
# data.tags.Rock_Music
# data.tags.Rogue_like
# data.tags.Rogue_lite
# data.tags.Roguelike_Deckbuilder
# data.tags.Roguevania
# data.tags.Romance
# data.tags.Rome
# data.tags.Rugby
# data.tags.Runner
# data.tags.Sailing
# data.tags.Sandbox
# data.tags.Satire
# data.tags.Sci_fi
# data.tags.Science
# data.tags.Score_Attack
# data.tags.Sequel
# data.tags.Sexual_Content
# data.tags.Shoot_Em_Up
# data.tags.Shooter
# data.tags.Shop_Keeper
# data.tags.Short
# data.tags.Side_Scroller
# data.tags.Silent_Protagonist
# data.tags.Simulation
# data.tags.Singleplayer
# data.tags.Skateboarding
# data.tags.Skating
# data.tags.Skiing
# data.tags.Sniper
# data.tags.Snooker
# data.tags.Snow
# data.tags.Snowboarding
# data.tags.Soccer
# data.tags.Social_Deduction
# data.tags.Software
# data.tags.Software_Training
# data.tags.Sokoban
# data.tags.Solitaire
# data.tags.Souls_like
# data.tags.Soundtrack
# data.tags.Space
# data.tags.Space_Sim
# data.tags.Spaceships
# data.tags.Spectacle_fighter
# data.tags.Spelling
# data.tags.Split_Screen
# data.tags.Sports
# data.tags.Stealth
# data.tags.Steam_Machine
# data.tags.Steampunk
# data.tags.Story_Rich
# data.tags.Strategy
# data.tags.Strategy_RPG
# data.tags.Stylized
# data.tags.Submarine
# data.tags.Superhero
# data.tags.Supernatural
# data.tags.Surreal
# data.tags.Survival
# data.tags.Survival_Horror
# data.tags.Swordplay
# data.tags.Tabletop
# data.tags.Tactical
# data.tags.Tactical_RPG
# data.tags.Tanks
# data.tags.Team_Based
# data.tags.Tennis
# data.tags.Text_Based
# data.tags.Third_Person
# data.tags.Third_Person_Shooter
# data.tags.Thriller
# data.tags.Tile_Matching
# data.tags.Time_Attack
# data.tags.Time_Management
# data.tags.Time_Manipulation
# data.tags.Time_Travel
# data.tags.Top_Down
# data.tags.Top_Down_Shooter
# data.tags.Touch_Friendly
# data.tags.Tower_Defense
# data.tags.TrackIR
# data.tags.Trading
# data.tags.Trading_Card_Game
# data.tags.Traditional_Roguelike
# data.tags.Trains
# data.tags.Transhumanism
# data.tags.Transportation
# data.tags.Trivia
# data.tags.Turn_Based
# data.tags.Turn_Based_Combat
# data.tags.Turn_Based_Strategy
# data.tags.Turn_Based_Tactics
# data.tags.Tutorial
# data.tags.Twin_Stick_Shooter
# data.tags.Typing
# data.tags.Underground
# data.tags.Underwater
# data.tags.Unforgiving
# data.tags.Utilities
# data.tags.VR
# data.tags.VR_Only
# data.tags.Vampire
# data.tags.Vehicular_Combat
# data.tags.Video_Production
# data.tags.Vikings
# data.tags.Villain_Protagonist
# data.tags.Violent
# data.tags.Visual_Novel
# data.tags.Voice_Control
# data.tags.Volleyball
# data.tags.Voxel
# data.tags.Walking_Simulator
# data.tags.War
# data.tags.Wargame
# data.tags.Warhammer_40K
# data.tags.Web_Publishing
# data.tags.Well_Written
# data.tags.Werewolves
# data.tags.Western
# data.tags.Wholesome
# data.tags.Word_Game
# data.tags.World_War_I
# data.tags.World_War_II
# data.tags.Wrestling
# data.tags.Zombies
# data.tags.e_sports
# data.type
# data.website
# id

# %% [markdown]
# ## Éclatement en plusieurs colonnes
#
# Nous utilisons la méthode reduce() pour éclater les champs en plusieurs colonnes.
# La colonne *data* devient inutile, nous la retirons. Nous retirons aussi la colonne *id* qui est un doublon de *appid*

# %%
from functools import reduce
from pyspark.sql import functions as F

exploded_df = reduce(
  lambda memo_df, col_name: memo_df.withColumn(col_name, F.col(col_name)),
  walkSchema(df.schema), df
).drop('data', 'id')

# %%
exploded_df.printSchema()
# Out:
# root
#  |-- data.appid: long (nullable = true)
#  |-- data.ccu: long (nullable = true)
#  |-- data.developer: string (nullable = true)
#  |-- data.discount: string (nullable = true)
#  |-- data.genre: string (nullable = true)
#  |-- data.header_image: string (nullable = true)
#  |-- data.initialprice: string (nullable = true)
#  |-- data.languages: string (nullable = true)
#  |-- data.name: string (nullable = true)
#  |-- data.negative: long (nullable = true)
#  |-- data.owners: string (nullable = true)
#  |-- data.platforms.linux: boolean (nullable = true)
#  |-- data.platforms.mac: boolean (nullable = true)
#  |-- data.platforms.windows: boolean (nullable = true)
#  |-- data.positive: long (nullable = true)
#  |-- data.price: string (nullable = true)
#  |-- data.publisher: string (nullable = true)
#  |-- data.release_date: string (nullable = true)
#  |-- data.required_age: string (nullable = true)
#  |-- data.short_description: string (nullable = true)
#  |-- data.tags.1980s: long (nullable = true)
#  |-- data.tags.1990s: long (nullable = true)
#  |-- data.tags.2_5D: long (nullable = true)
#  |-- data.tags.2D: long (nullable = true)
#  |-- data.tags.2D_Fighter: long (nullable = true)
#  |-- data.tags.2D_Platformer: long (nullable = true)
#  |-- data.tags.360_Video: long (nullable = true)
#  |-- data.tags.3D: long (nullable = true)
#  |-- data.tags.3D_Fighter: long (nullable = true)
#  |-- data.tags.3D_Platformer: long (nullable = true)
#  |-- data.tags.3D_Vision: long (nullable = true)
#  |-- data.tags.4_Player_Local: long (nullable = true)
#  |-- data.tags.4X: long (nullable = true)
#  |-- data.tags.6DOF: long (nullable = true)
#  |-- data.tags.8_bit_Music: long (nullable = true)
#  |-- data.tags.ATV: long (nullable = true)
#  |-- data.tags.Abstract: long (nullable = true)
#  |-- data.tags.Action: long (nullable = true)
#  |-- data.tags.Action_RPG: long (nullable = true)
#  |-- data.tags.Action_RTS: long (nullable = true)
#  |-- data.tags.Action_Roguelike: long (nullable = true)
#  |-- data.tags.Action_Adventure: long (nullable = true)
#  |-- data.tags.Addictive: long (nullable = true)
#  |-- data.tags.Adventure: long (nullable = true)
#  |-- data.tags.Agriculture: long (nullable = true)
#  |-- data.tags.Aliens: long (nullable = true)
#  |-- data.tags.Alternate_History: long (nullable = true)
#  |-- data.tags.Ambient: long (nullable = true)
#  |-- data.tags.America: long (nullable = true)
#  |-- data.tags.Animation_And_Modeling: long (nullable = true)
#  |-- data.tags.Anime: long (nullable = true)
#  |-- data.tags.Arcade: long (nullable = true)
#  |-- data.tags.Archery: long (nullable = true)
#  |-- data.tags.Arena_Shooter: long (nullable = true)
#  |-- data.tags.Artificial_Intelligence: long (nullable = true)
#  |-- data.tags.Assassin: long (nullable = true)
#  |-- data.tags.Asymmetric_VR: long (nullable = true)
#  |-- data.tags.Asynchronous_Multiplayer: long (nullable = true)
#  |-- data.tags.Atmospheric: long (nullable = true)
#  |-- data.tags.Audio_Production: long (nullable = true)
#  |-- data.tags.Auto_Battler: long (nullable = true)
#  |-- data.tags.Automation: long (nullable = true)
#  |-- data.tags.Automobile_Sim: long (nullable = true)
#  |-- data.tags.BMX: long (nullable = true)
#  |-- data.tags.Base_Building: long (nullable = true)
#  |-- data.tags.Baseball: long (nullable = true)
#  |-- data.tags.Based_On_A_Novel: long (nullable = true)
#  |-- data.tags.Basketball: long (nullable = true)
#  |-- data.tags.Battle_Royale: long (nullable = true)
#  |-- data.tags.Beat_em_up: long (nullable = true)
#  |-- data.tags.Beautiful: long (nullable = true)
#  |-- data.tags.Benchmark: long (nullable = true)
#  |-- data.tags.Bikes: long (nullable = true)
#  |-- data.tags.Blood: long (nullable = true)
#  |-- data.tags.Board_Game: long (nullable = true)
#  |-- data.tags.Boss_Rush: long (nullable = true)
#  |-- data.tags.Bowling: long (nullable = true)
#  |-- data.tags.Boxing: long (nullable = true)
#  |-- data.tags.Building: long (nullable = true)
#  |-- data.tags.Bullet_Hell: long (nullable = true)
#  |-- data.tags.Bullet_Time: long (nullable = true)
#  |-- data.tags.CRPG: long (nullable = true)
#  |-- data.tags.Capitalism: long (nullable = true)
#  |-- data.tags.Card_Battler: long (nullable = true)
#  |-- data.tags.Card_Game: long (nullable = true)
#  |-- data.tags.Cartoon: long (nullable = true)
#  |-- data.tags.Cartoony: long (nullable = true)
#  |-- data.tags.Casual: long (nullable = true)
#  |-- data.tags.Cats: long (nullable = true)
#  |-- data.tags.Character_Action_Game: long (nullable = true)
#  |-- data.tags.Character_Customization: long (nullable = true)
#  |-- data.tags.Chess: long (nullable = true)
#  |-- data.tags.Choices_Matter: long (nullable = true)
#  |-- data.tags.Choose_Your_Own_Adventure: long (nullable = true)
#  |-- data.tags.Cinematic: long (nullable = true)
#  |-- data.tags.City_Builder: long (nullable = true)
#  |-- data.tags.Class_Based: long (nullable = true)
#  |-- data.tags.Classic: long (nullable = true)
#  |-- data.tags.Clicker: long (nullable = true)
#  |-- data.tags.Co_op: long (nullable = true)
#  |-- data.tags.Co_op_Campaign: long (nullable = true)
#  |-- data.tags.Coding: long (nullable = true)
#  |-- data.tags.Cold_War: long (nullable = true)
#  |-- data.tags.Collectathon: long (nullable = true)
#  |-- data.tags.Colony_Sim: long (nullable = true)
#  |-- data.tags.Colorful: long (nullable = true)
#  |-- data.tags.Combat: long (nullable = true)
#  |-- data.tags.Combat_Racing: long (nullable = true)
#  |-- data.tags.Comedy: long (nullable = true)
#  |-- data.tags.Comic_Book: long (nullable = true)
#  |-- data.tags.Competitive: long (nullable = true)
#  |-- data.tags.Conspiracy: long (nullable = true)
#  |-- data.tags.Controller: long (nullable = true)
#  |-- data.tags.Conversation: long (nullable = true)
#  |-- data.tags.Cooking: long (nullable = true)
#  |-- data.tags.Cozy: long (nullable = true)
#  |-- data.tags.Crafting: long (nullable = true)
#  |-- data.tags.Creature_Collector: long (nullable = true)
#  |-- data.tags.Cricket: long (nullable = true)
#  |-- data.tags.Crime: long (nullable = true)
#  |-- data.tags.Crowdfunded: long (nullable = true)
#  |-- data.tags.Cult_Classic: long (nullable = true)
#  |-- data.tags.Cute: long (nullable = true)
#  |-- data.tags.Cyberpunk: long (nullable = true)
#  |-- data.tags.Cycling: long (nullable = true)
#  |-- data.tags.Dark: long (nullable = true)
#  |-- data.tags.Dark_Comedy: long (nullable = true)
#  |-- data.tags.Dark_Fantasy: long (nullable = true)
#  |-- data.tags.Dark_Humor: long (nullable = true)
#  |-- data.tags.Dating_Sim: long (nullable = true)
#  |-- data.tags.Deckbuilding: long (nullable = true)
#  |-- data.tags.Demons: long (nullable = true)
#  |-- data.tags.Design_And_Illustration: long (nullable = true)
#  |-- data.tags.Destruction: long (nullable = true)
#  |-- data.tags.Detective: long (nullable = true)
#  |-- data.tags.Difficult: long (nullable = true)
#  |-- data.tags.Dinosaurs: long (nullable = true)
#  |-- data.tags.Diplomacy: long (nullable = true)
#  |-- data.tags.Documentary: long (nullable = true)
#  |-- data.tags.Dog: long (nullable = true)
#  |-- data.tags.Dragons: long (nullable = true)
#  |-- data.tags.Drama: long (nullable = true)
#  |-- data.tags.Driving: long (nullable = true)
#  |-- data.tags.Dungeon_Crawler: long (nullable = true)
#  |-- data.tags.Dungeons_And_Dragons: long (nullable = true)
#  |-- data.tags.Dynamic_Narration: long (nullable = true)
#  |-- data.tags.Dystopian_: long (nullable = true)
#  |-- data.tags.Early_Access: long (nullable = true)
#  |-- data.tags.Economy: long (nullable = true)
#  |-- data.tags.Education: long (nullable = true)
#  |-- data.tags.Electronic: long (nullable = true)
#  |-- data.tags.Electronic_Music: long (nullable = true)
#  |-- data.tags.Emotional: long (nullable = true)
#  |-- data.tags.Epic: long (nullable = true)
#  |-- data.tags.Episodic: long (nullable = true)
#  |-- data.tags.Escape_Room: long (nullable = true)
#  |-- data.tags.Experience: long (nullable = true)
#  |-- data.tags.Experimental: long (nullable = true)
#  |-- data.tags.Exploration: long (nullable = true)
#  |-- data.tags.FMV: long (nullable = true)
#  |-- data.tags.FPS: long (nullable = true)
#  |-- data.tags.Faith: long (nullable = true)
#  |-- data.tags.Family_Friendly: long (nullable = true)
#  |-- data.tags.Fantasy: long (nullable = true)
#  |-- data.tags.Farming: long (nullable = true)
#  |-- data.tags.Farming_Sim: long (nullable = true)
#  |-- data.tags.Fast_Paced: long (nullable = true)
#  |-- data.tags.Feature_Film: long (nullable = true)
#  |-- data.tags.Female_Protagonist: long (nullable = true)
#  |-- data.tags.Fighting: long (nullable = true)
#  |-- data.tags.First_Person: long (nullable = true)
#  |-- data.tags.Fishing: long (nullable = true)
#  |-- data.tags.Flight: long (nullable = true)
#  |-- data.tags.Football: long (nullable = true)
#  |-- data.tags.Foreign: long (nullable = true)
#  |-- data.tags.Free_to_Play: long (nullable = true)
#  |-- data.tags.Funny: long (nullable = true)
#  |-- data.tags.Futuristic: long (nullable = true)
#  |-- data.tags.Gambling: long (nullable = true)
#  |-- data.tags.Game_Development: long (nullable = true)
#  |-- data.tags.GameMaker: long (nullable = true)
#  |-- data.tags.Games_Workshop: long (nullable = true)
#  |-- data.tags.Gaming: long (nullable = true)
#  |-- data.tags.God_Game: long (nullable = true)
#  |-- data.tags.Golf: long (nullable = true)
#  |-- data.tags.Gore: long (nullable = true)
#  |-- data.tags.Gothic: long (nullable = true)
#  |-- data.tags.Grand_Strategy: long (nullable = true)
#  |-- data.tags.Great_Soundtrack: long (nullable = true)
#  |-- data.tags.Grid_Based_Movement: long (nullable = true)
#  |-- data.tags.Gun_Customization: long (nullable = true)
#  |-- data.tags.Hack_and_Slash: long (nullable = true)
#  |-- data.tags.Hacking: long (nullable = true)
#  |-- data.tags.Hand_drawn: long (nullable = true)
#  |-- data.tags.Hardware: long (nullable = true)
#  |-- data.tags.Heist: long (nullable = true)
#  |-- data.tags.Hentai: long (nullable = true)
#  |-- data.tags.Hero_Shooter: long (nullable = true)
#  |-- data.tags.Hex_Grid: long (nullable = true)
#  |-- data.tags.Hidden_Object: long (nullable = true)
#  |-- data.tags.Historical: long (nullable = true)
#  |-- data.tags.Hockey: long (nullable = true)
#  |-- data.tags.Horror: long (nullable = true)
#  |-- data.tags.Horses: long (nullable = true)
#  |-- data.tags.Hunting: long (nullable = true)
#  |-- data.tags.Idler: long (nullable = true)
#  |-- data.tags.Illuminati: long (nullable = true)
#  |-- data.tags.Immersive: long (nullable = true)
#  |-- data.tags.Immersive_Sim: long (nullable = true)
#  |-- data.tags.Indie: long (nullable = true)
#  |-- data.tags.Instrumental_Music: long (nullable = true)
#  |-- data.tags.Intentionally_Awkward_Controls: long (nullable = true)
#  |-- data.tags.Interactive_Fiction: long (nullable = true)
#  |-- data.tags.Inventory_Management: long (nullable = true)
#  |-- data.tags.Investigation: long (nullable = true)
#  |-- data.tags.Isometric: long (nullable = true)
#  |-- data.tags.JRPG: long (nullable = true)
#  |-- data.tags.Jet: long (nullable = true)
#  |-- data.tags.Job_Simulator: long (nullable = true)
#  |-- data.tags.Jump_Scare: long (nullable = true)
#  |-- data.tags.Kickstarter: long (nullable = true)
#  |-- data.tags.LEGO: long (nullable = true)
#  |-- data.tags.LGBTQ+: long (nullable = true)
#  |-- data.tags.Lemmings: long (nullable = true)
#  |-- data.tags.Level_Editor: long (nullable = true)
#  |-- data.tags.Life_Sim: long (nullable = true)
#  |-- data.tags.Linear: long (nullable = true)
#  |-- data.tags.Local_Co_Op: long (nullable = true)
#  |-- data.tags.Local_Multiplayer: long (nullable = true)
#  |-- data.tags.Logic: long (nullable = true)
#  |-- data.tags.Loot: long (nullable = true)
#  |-- data.tags.Looter_Shooter: long (nullable = true)
#  |-- data.tags.Lore_Rich: long (nullable = true)
#  |-- data.tags.Lovecraftian: long (nullable = true)
#  |-- data.tags.MMORPG: long (nullable = true)
#  |-- data.tags.MOBA: long (nullable = true)
#  |-- data.tags.Magic: long (nullable = true)
#  |-- data.tags.Mahjong: long (nullable = true)
#  |-- data.tags.Management: long (nullable = true)
#  |-- data.tags.Mars: long (nullable = true)
#  |-- data.tags.Martial_Arts: long (nullable = true)
#  |-- data.tags.Massively_Multiplayer: long (nullable = true)
#  |-- data.tags.Masterpiece: long (nullable = true)
#  |-- data.tags.Match_3: long (nullable = true)
#  |-- data.tags.Mature: long (nullable = true)
#  |-- data.tags.Mechs: long (nullable = true)
#  |-- data.tags.Medical_Sim: long (nullable = true)
#  |-- data.tags.Medieval: long (nullable = true)
#  |-- data.tags.Memes: long (nullable = true)
#  |-- data.tags.Metroidvania: long (nullable = true)
#  |-- data.tags.Military: long (nullable = true)
#  |-- data.tags.Mini_Golf: long (nullable = true)
#  |-- data.tags.Minigames: long (nullable = true)
#  |-- data.tags.Minimalist: long (nullable = true)
#  |-- data.tags.Mining: long (nullable = true)
#  |-- data.tags.Mod: long (nullable = true)
#  |-- data.tags.Moddable: long (nullable = true)
#  |-- data.tags.Modern: long (nullable = true)
#  |-- data.tags.Motocross: long (nullable = true)
#  |-- data.tags.Motorbike: long (nullable = true)
#  |-- data.tags.Mouse_only: long (nullable = true)
#  |-- data.tags.Movie: long (nullable = true)
#  |-- data.tags.Multiplayer: long (nullable = true)
#  |-- data.tags.Multiple_Endings: long (nullable = true)
#  |-- data.tags.Music: long (nullable = true)
#  |-- data.tags.Music_Based_Procedural_Generation: long (nullable = true)
#  |-- data.tags.Musou: long (nullable = true)
#  |-- data.tags.Mystery: long (nullable = true)
#  |-- data.tags.Mystery_Dungeon: long (nullable = true)
#  |-- data.tags.Mythology: long (nullable = true)
#  |-- data.tags.NSFW: long (nullable = true)
#  |-- data.tags.Narration: long (nullable = true)
#  |-- data.tags.Narrative: long (nullable = true)
#  |-- data.tags.Nature: long (nullable = true)
#  |-- data.tags.Naval: long (nullable = true)
#  |-- data.tags.Naval_Combat: long (nullable = true)
#  |-- data.tags.Ninja: long (nullable = true)
#  |-- data.tags.Noir: long (nullable = true)
#  |-- data.tags.Nonlinear: long (nullable = true)
#  |-- data.tags.Nostalgia: long (nullable = true)
#  |-- data.tags.Nudity: long (nullable = true)
#  |-- data.tags.Offroad: long (nullable = true)
#  |-- data.tags.Old_School: long (nullable = true)
#  |-- data.tags.On_Rails_Shooter: long (nullable = true)
#  |-- data.tags.Online_Co_Op: long (nullable = true)
#  |-- data.tags.Open_World: long (nullable = true)
#  |-- data.tags.Open_World_Survival_Craft: long (nullable = true)
#  |-- data.tags.Otome: long (nullable = true)
#  |-- data.tags.Outbreak_Sim: long (nullable = true)
#  |-- data.tags.Parkour: long (nullable = true)
#  |-- data.tags.Parody_: long (nullable = true)
#  |-- data.tags.Party: long (nullable = true)
#  |-- data.tags.Party_Game: long (nullable = true)
#  |-- data.tags.Party_Based_RPG: long (nullable = true)
#  |-- data.tags.Perma_Death: long (nullable = true)
#  |-- data.tags.Philosophical: long (nullable = true)
#  |-- data.tags.Photo_Editing: long (nullable = true)
#  |-- data.tags.Physics: long (nullable = true)
#  |-- data.tags.Pinball: long (nullable = true)
#  |-- data.tags.Pirates: long (nullable = true)
#  |-- data.tags.Pixel_Graphics: long (nullable = true)
#  |-- data.tags.Platformer: long (nullable = true)
#  |-- data.tags.Point_And_Click: long (nullable = true)
#  |-- data.tags.Political: long (nullable = true)
#  |-- data.tags.Political_Sim: long (nullable = true)
#  |-- data.tags.Politics: long (nullable = true)
#  |-- data.tags.Pool: long (nullable = true)
#  |-- data.tags.Post_apocalyptic: long (nullable = true)
#  |-- data.tags.Precision_Platformer: long (nullable = true)
#  |-- data.tags.Procedural_Generation: long (nullable = true)
#  |-- data.tags.Programming: long (nullable = true)
#  |-- data.tags.Psychedelic: long (nullable = true)
#  |-- data.tags.Psychological: long (nullable = true)
#  |-- data.tags.Psychological_Horror: long (nullable = true)
#  |-- data.tags.Puzzle: long (nullable = true)
#  |-- data.tags.Puzzle_Platformer: long (nullable = true)
#  |-- data.tags.PvE: long (nullable = true)
#  |-- data.tags.PvP: long (nullable = true)
#  |-- data.tags.Quick_Time_Events: long (nullable = true)
#  |-- data.tags.RPG: long (nullable = true)
#  |-- data.tags.RPGMaker: long (nullable = true)
#  |-- data.tags.RTS: long (nullable = true)
#  |-- data.tags.Racing: long (nullable = true)
#  |-- data.tags.Real_Time_Tactics: long (nullable = true)
#  |-- data.tags.Real_Time: long (nullable = true)
#  |-- data.tags.Real_Time_with_Pause: long (nullable = true)
#  |-- data.tags.Realistic: long (nullable = true)
#  |-- data.tags.Reboot: long (nullable = true)
#  |-- data.tags.Relaxing: long (nullable = true)
#  |-- data.tags.Remake: long (nullable = true)
#  |-- data.tags.Replay_Value: long (nullable = true)
#  |-- data.tags.Resource_Management: long (nullable = true)
#  |-- data.tags.Retro: long (nullable = true)
#  |-- data.tags.Rhythm: long (nullable = true)
#  |-- data.tags.Robots: long (nullable = true)
#  |-- data.tags.Rock_Music: long (nullable = true)
#  |-- data.tags.Rogue_like: long (nullable = true)
#  |-- data.tags.Rogue_lite: long (nullable = true)
#  |-- data.tags.Roguelike_Deckbuilder: long (nullable = true)
#  |-- data.tags.Roguevania: long (nullable = true)
#  |-- data.tags.Romance: long (nullable = true)
#  |-- data.tags.Rome: long (nullable = true)
#  |-- data.tags.Rugby: long (nullable = true)
#  |-- data.tags.Runner: long (nullable = true)
#  |-- data.tags.Sailing: long (nullable = true)
#  |-- data.tags.Sandbox: long (nullable = true)
#  |-- data.tags.Satire: long (nullable = true)
#  |-- data.tags.Sci_fi: long (nullable = true)
#  |-- data.tags.Science: long (nullable = true)
#  |-- data.tags.Score_Attack: long (nullable = true)
#  |-- data.tags.Sequel: long (nullable = true)
#  |-- data.tags.Sexual_Content: long (nullable = true)
#  |-- data.tags.Shoot_Em_Up: long (nullable = true)
#  |-- data.tags.Shooter: long (nullable = true)
#  |-- data.tags.Shop_Keeper: long (nullable = true)
#  |-- data.tags.Short: long (nullable = true)
#  |-- data.tags.Side_Scroller: long (nullable = true)
#  |-- data.tags.Silent_Protagonist: long (nullable = true)
#  |-- data.tags.Simulation: long (nullable = true)
#  |-- data.tags.Singleplayer: long (nullable = true)
#  |-- data.tags.Skateboarding: long (nullable = true)
#  |-- data.tags.Skating: long (nullable = true)
#  |-- data.tags.Skiing: long (nullable = true)
#  |-- data.tags.Sniper: long (nullable = true)
#  |-- data.tags.Snooker: long (nullable = true)
#  |-- data.tags.Snow: long (nullable = true)
#  |-- data.tags.Snowboarding: long (nullable = true)
#  |-- data.tags.Soccer: long (nullable = true)
#  |-- data.tags.Social_Deduction: long (nullable = true)
#  |-- data.tags.Software: long (nullable = true)
#  |-- data.tags.Software_Training: long (nullable = true)
#  |-- data.tags.Sokoban: long (nullable = true)
#  |-- data.tags.Solitaire: long (nullable = true)
#  |-- data.tags.Souls_like: long (nullable = true)
#  |-- data.tags.Soundtrack: long (nullable = true)
#  |-- data.tags.Space: long (nullable = true)
#  |-- data.tags.Space_Sim: long (nullable = true)
#  |-- data.tags.Spaceships: long (nullable = true)
#  |-- data.tags.Spectacle_fighter: long (nullable = true)
#  |-- data.tags.Spelling: long (nullable = true)
#  |-- data.tags.Split_Screen: long (nullable = true)
#  |-- data.tags.Sports: long (nullable = true)
#  |-- data.tags.Stealth: long (nullable = true)
#  |-- data.tags.Steam_Machine: long (nullable = true)
#  |-- data.tags.Steampunk: long (nullable = true)
#  |-- data.tags.Story_Rich: long (nullable = true)
#  |-- data.tags.Strategy: long (nullable = true)
#  |-- data.tags.Strategy_RPG: long (nullable = true)
#  |-- data.tags.Stylized: long (nullable = true)
#  |-- data.tags.Submarine: long (nullable = true)
#  |-- data.tags.Superhero: long (nullable = true)
#  |-- data.tags.Supernatural: long (nullable = true)
#  |-- data.tags.Surreal: long (nullable = true)
#  |-- data.tags.Survival: long (nullable = true)
#  |-- data.tags.Survival_Horror: long (nullable = true)
#  |-- data.tags.Swordplay: long (nullable = true)
#  |-- data.tags.Tabletop: long (nullable = true)
#  |-- data.tags.Tactical: long (nullable = true)
#  |-- data.tags.Tactical_RPG: long (nullable = true)
#  |-- data.tags.Tanks: long (nullable = true)
#  |-- data.tags.Team_Based: long (nullable = true)
#  |-- data.tags.Tennis: long (nullable = true)
#  |-- data.tags.Text_Based: long (nullable = true)
#  |-- data.tags.Third_Person: long (nullable = true)
#  |-- data.tags.Third_Person_Shooter: long (nullable = true)
#  |-- data.tags.Thriller: long (nullable = true)
#  |-- data.tags.Tile_Matching: long (nullable = true)
#  |-- data.tags.Time_Attack: long (nullable = true)
#  |-- data.tags.Time_Management: long (nullable = true)
#  |-- data.tags.Time_Manipulation: long (nullable = true)
#  |-- data.tags.Time_Travel: long (nullable = true)
#  |-- data.tags.Top_Down: long (nullable = true)
#  |-- data.tags.Top_Down_Shooter: long (nullable = true)
#  |-- data.tags.Touch_Friendly: long (nullable = true)
#  |-- data.tags.Tower_Defense: long (nullable = true)
#  |-- data.tags.TrackIR: long (nullable = true)
#  |-- data.tags.Trading: long (nullable = true)
#  |-- data.tags.Trading_Card_Game: long (nullable = true)
#  |-- data.tags.Traditional_Roguelike: long (nullable = true)
#  |-- data.tags.Trains: long (nullable = true)
#  |-- data.tags.Transhumanism: long (nullable = true)
#  |-- data.tags.Transportation: long (nullable = true)
#  |-- data.tags.Trivia: long (nullable = true)
#  |-- data.tags.Turn_Based: long (nullable = true)
#  |-- data.tags.Turn_Based_Combat: long (nullable = true)
#  |-- data.tags.Turn_Based_Strategy: long (nullable = true)
#  |-- data.tags.Turn_Based_Tactics: long (nullable = true)
#  |-- data.tags.Tutorial: long (nullable = true)
#  |-- data.tags.Twin_Stick_Shooter: long (nullable = true)
#  |-- data.tags.Typing: long (nullable = true)
#  |-- data.tags.Underground: long (nullable = true)
#  |-- data.tags.Underwater: long (nullable = true)
#  |-- data.tags.Unforgiving: long (nullable = true)
#  |-- data.tags.Utilities: long (nullable = true)
#  |-- data.tags.VR: long (nullable = true)
#  |-- data.tags.VR_Only: long (nullable = true)
#  |-- data.tags.Vampire: long (nullable = true)
#  |-- data.tags.Vehicular_Combat: long (nullable = true)
#  |-- data.tags.Video_Production: long (nullable = true)
#  |-- data.tags.Vikings: long (nullable = true)
#  |-- data.tags.Villain_Protagonist: long (nullable = true)
#  |-- data.tags.Violent: long (nullable = true)
#  |-- data.tags.Visual_Novel: long (nullable = true)
#  |-- data.tags.Voice_Control: long (nullable = true)
#  |-- data.tags.Volleyball: long (nullable = true)
#  |-- data.tags.Voxel: long (nullable = true)
#  |-- data.tags.Walking_Simulator: long (nullable = true)
#  |-- data.tags.War: long (nullable = true)
#  |-- data.tags.Wargame: long (nullable = true)
#  |-- data.tags.Warhammer_40K: long (nullable = true)
#  |-- data.tags.Web_Publishing: long (nullable = true)
#  |-- data.tags.Well_Written: long (nullable = true)
#  |-- data.tags.Werewolves: long (nullable = true)
#  |-- data.tags.Western: long (nullable = true)
#  |-- data.tags.Wholesome: long (nullable = true)
#  |-- data.tags.Word_Game: long (nullable = true)
#  |-- data.tags.World_War_I: long (nullable = true)
#  |-- data.tags.World_War_II: long (nullable = true)
#  |-- data.tags.Wrestling: long (nullable = true)
#  |-- data.tags.Zombies: long (nullable = true)
#  |-- data.tags.e_sports: long (nullable = true)
#  |-- data.type: string (nullable = true)
#  |-- data.website: string (nullable = true)

# %% [markdown]
# ## Suppression du mot "data" et des points
#
# Nous pouvons supprimer le mot "data" pour simplifier le nom des colonnes.
# Les noms des colonnes contiennent des points.
# Nous devons les enlever car ils génèrent de l'ambiguité quand il s'agit de les sélectionner une colonne dans un dataframe.

# %% [markdown]
# #### Fonction pour enlever le mot "data" et les points

# %%
def sanitize_column_name(col_name): 
  """ Fonction qui ne garde que la partie après le premier point """
  """ Et qui remplace les points suivants par underscore """
  return '_'.join(col_name.split(".")[1:])

# %% [markdown]
# #### Application

# %%
from pyspark.sql import functions as F 
from functools import reduce

df_renamed = reduce(
  lambda memo_df, col_name: memo_df.withColumnRenamed(
    col_name, sanitize_column_name(col_name)),
  exploded_df.columns, exploded_df
)

# %%
df_renamed.printSchema()
# Out:
# root
#  |-- appid: long (nullable = true)
#  |-- ccu: long (nullable = true)
#  |-- developer: string (nullable = true)
#  |-- discount: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- header_image: string (nullable = true)
#  |-- initialprice: string (nullable = true)
#  |-- languages: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- owners: string (nullable = true)
#  |-- platforms_linux: boolean (nullable = true)
#  |-- platforms_mac: boolean (nullable = true)
#  |-- platforms_windows: boolean (nullable = true)
#  |-- positive: long (nullable = true)
#  |-- price: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- required_age: string (nullable = true)
#  |-- short_description: string (nullable = true)
#  |-- tags_1980s: long (nullable = true)
#  |-- tags_1990s: long (nullable = true)
#  |-- tags_2_5D: long (nullable = true)
#  |-- tags_2D: long (nullable = true)
#  |-- tags_2D_Fighter: long (nullable = true)
#  |-- tags_2D_Platformer: long (nullable = true)
#  |-- tags_360_Video: long (nullable = true)
#  |-- tags_3D: long (nullable = true)
#  |-- tags_3D_Fighter: long (nullable = true)
#  |-- tags_3D_Platformer: long (nullable = true)
#  |-- tags_3D_Vision: long (nullable = true)
#  |-- tags_4_Player_Local: long (nullable = true)
#  |-- tags_4X: long (nullable = true)
#  |-- tags_6DOF: long (nullable = true)
#  |-- tags_8_bit_Music: long (nullable = true)
#  |-- tags_ATV: long (nullable = true)
#  |-- tags_Abstract: long (nullable = true)
#  |-- tags_Action: long (nullable = true)
#  |-- tags_Action_RPG: long (nullable = true)
#  |-- tags_Action_RTS: long (nullable = true)
#  |-- tags_Action_Roguelike: long (nullable = true)
#  |-- tags_Action_Adventure: long (nullable = true)
#  |-- tags_Addictive: long (nullable = true)
#  |-- tags_Adventure: long (nullable = true)
#  |-- tags_Agriculture: long (nullable = true)
#  |-- tags_Aliens: long (nullable = true)
#  |-- tags_Alternate_History: long (nullable = true)
#  |-- tags_Ambient: long (nullable = true)
#  |-- tags_America: long (nullable = true)
#  |-- tags_Animation_And_Modeling: long (nullable = true)
#  |-- tags_Anime: long (nullable = true)
#  |-- tags_Arcade: long (nullable = true)
#  |-- tags_Archery: long (nullable = true)
#  |-- tags_Arena_Shooter: long (nullable = true)
#  |-- tags_Artificial_Intelligence: long (nullable = true)
#  |-- tags_Assassin: long (nullable = true)
#  |-- tags_Asymmetric_VR: long (nullable = true)
#  |-- tags_Asynchronous_Multiplayer: long (nullable = true)
#  |-- tags_Atmospheric: long (nullable = true)
#  |-- tags_Audio_Production: long (nullable = true)
#  |-- tags_Auto_Battler: long (nullable = true)
#  |-- tags_Automation: long (nullable = true)
#  |-- tags_Automobile_Sim: long (nullable = true)
#  |-- tags_BMX: long (nullable = true)
#  |-- tags_Base_Building: long (nullable = true)
#  |-- tags_Baseball: long (nullable = true)
#  |-- tags_Based_On_A_Novel: long (nullable = true)
#  |-- tags_Basketball: long (nullable = true)
#  |-- tags_Battle_Royale: long (nullable = true)
#  |-- tags_Beat_em_up: long (nullable = true)
#  |-- tags_Beautiful: long (nullable = true)
#  |-- tags_Benchmark: long (nullable = true)
#  |-- tags_Bikes: long (nullable = true)
#  |-- tags_Blood: long (nullable = true)
#  |-- tags_Board_Game: long (nullable = true)
#  |-- tags_Boss_Rush: long (nullable = true)
#  |-- tags_Bowling: long (nullable = true)
#  |-- tags_Boxing: long (nullable = true)
#  |-- tags_Building: long (nullable = true)
#  |-- tags_Bullet_Hell: long (nullable = true)
#  |-- tags_Bullet_Time: long (nullable = true)
#  |-- tags_CRPG: long (nullable = true)
#  |-- tags_Capitalism: long (nullable = true)
#  |-- tags_Card_Battler: long (nullable = true)
#  |-- tags_Card_Game: long (nullable = true)
#  |-- tags_Cartoon: long (nullable = true)
#  |-- tags_Cartoony: long (nullable = true)
#  |-- tags_Casual: long (nullable = true)
#  |-- tags_Cats: long (nullable = true)
#  |-- tags_Character_Action_Game: long (nullable = true)
#  |-- tags_Character_Customization: long (nullable = true)
#  |-- tags_Chess: long (nullable = true)
#  |-- tags_Choices_Matter: long (nullable = true)
#  |-- tags_Choose_Your_Own_Adventure: long (nullable = true)
#  |-- tags_Cinematic: long (nullable = true)
#  |-- tags_City_Builder: long (nullable = true)
#  |-- tags_Class_Based: long (nullable = true)
#  |-- tags_Classic: long (nullable = true)
#  |-- tags_Clicker: long (nullable = true)
#  |-- tags_Co_op: long (nullable = true)
#  |-- tags_Co_op_Campaign: long (nullable = true)
#  |-- tags_Coding: long (nullable = true)
#  |-- tags_Cold_War: long (nullable = true)
#  |-- tags_Collectathon: long (nullable = true)
#  |-- tags_Colony_Sim: long (nullable = true)
#  |-- tags_Colorful: long (nullable = true)
#  |-- tags_Combat: long (nullable = true)
#  |-- tags_Combat_Racing: long (nullable = true)
#  |-- tags_Comedy: long (nullable = true)
#  |-- tags_Comic_Book: long (nullable = true)
#  |-- tags_Competitive: long (nullable = true)
#  |-- tags_Conspiracy: long (nullable = true)
#  |-- tags_Controller: long (nullable = true)
#  |-- tags_Conversation: long (nullable = true)
#  |-- tags_Cooking: long (nullable = true)
#  |-- tags_Cozy: long (nullable = true)
#  |-- tags_Crafting: long (nullable = true)
#  |-- tags_Creature_Collector: long (nullable = true)
#  |-- tags_Cricket: long (nullable = true)
#  |-- tags_Crime: long (nullable = true)
#  |-- tags_Crowdfunded: long (nullable = true)
#  |-- tags_Cult_Classic: long (nullable = true)
#  |-- tags_Cute: long (nullable = true)
#  |-- tags_Cyberpunk: long (nullable = true)
#  |-- tags_Cycling: long (nullable = true)
#  |-- tags_Dark: long (nullable = true)
#  |-- tags_Dark_Comedy: long (nullable = true)
#  |-- tags_Dark_Fantasy: long (nullable = true)
#  |-- tags_Dark_Humor: long (nullable = true)
#  |-- tags_Dating_Sim: long (nullable = true)
#  |-- tags_Deckbuilding: long (nullable = true)
#  |-- tags_Demons: long (nullable = true)
#  |-- tags_Design_And_Illustration: long (nullable = true)
#  |-- tags_Destruction: long (nullable = true)
#  |-- tags_Detective: long (nullable = true)
#  |-- tags_Difficult: long (nullable = true)
#  |-- tags_Dinosaurs: long (nullable = true)
#  |-- tags_Diplomacy: long (nullable = true)
#  |-- tags_Documentary: long (nullable = true)
#  |-- tags_Dog: long (nullable = true)
#  |-- tags_Dragons: long (nullable = true)
#  |-- tags_Drama: long (nullable = true)
#  |-- tags_Driving: long (nullable = true)
#  |-- tags_Dungeon_Crawler: long (nullable = true)
#  |-- tags_Dungeons_And_Dragons: long (nullable = true)
#  |-- tags_Dynamic_Narration: long (nullable = true)
#  |-- tags_Dystopian_: long (nullable = true)
#  |-- tags_Early_Access: long (nullable = true)
#  |-- tags_Economy: long (nullable = true)
#  |-- tags_Education: long (nullable = true)
#  |-- tags_Electronic: long (nullable = true)
#  |-- tags_Electronic_Music: long (nullable = true)
#  |-- tags_Emotional: long (nullable = true)
#  |-- tags_Epic: long (nullable = true)
#  |-- tags_Episodic: long (nullable = true)
#  |-- tags_Escape_Room: long (nullable = true)
#  |-- tags_Experience: long (nullable = true)
#  |-- tags_Experimental: long (nullable = true)
#  |-- tags_Exploration: long (nullable = true)
#  |-- tags_FMV: long (nullable = true)
#  |-- tags_FPS: long (nullable = true)
#  |-- tags_Faith: long (nullable = true)
#  |-- tags_Family_Friendly: long (nullable = true)
#  |-- tags_Fantasy: long (nullable = true)
#  |-- tags_Farming: long (nullable = true)
#  |-- tags_Farming_Sim: long (nullable = true)
#  |-- tags_Fast_Paced: long (nullable = true)
#  |-- tags_Feature_Film: long (nullable = true)
#  |-- tags_Female_Protagonist: long (nullable = true)
#  |-- tags_Fighting: long (nullable = true)
#  |-- tags_First_Person: long (nullable = true)
#  |-- tags_Fishing: long (nullable = true)
#  |-- tags_Flight: long (nullable = true)
#  |-- tags_Football: long (nullable = true)
#  |-- tags_Foreign: long (nullable = true)
#  |-- tags_Free_to_Play: long (nullable = true)
#  |-- tags_Funny: long (nullable = true)
#  |-- tags_Futuristic: long (nullable = true)
#  |-- tags_Gambling: long (nullable = true)
#  |-- tags_Game_Development: long (nullable = true)
#  |-- tags_GameMaker: long (nullable = true)
#  |-- tags_Games_Workshop: long (nullable = true)
#  |-- tags_Gaming: long (nullable = true)
#  |-- tags_God_Game: long (nullable = true)
#  |-- tags_Golf: long (nullable = true)
#  |-- tags_Gore: long (nullable = true)
#  |-- tags_Gothic: long (nullable = true)
#  |-- tags_Grand_Strategy: long (nullable = true)
#  |-- tags_Great_Soundtrack: long (nullable = true)
#  |-- tags_Grid_Based_Movement: long (nullable = true)
#  |-- tags_Gun_Customization: long (nullable = true)
#  |-- tags_Hack_and_Slash: long (nullable = true)
#  |-- tags_Hacking: long (nullable = true)
#  |-- tags_Hand_drawn: long (nullable = true)
#  |-- tags_Hardware: long (nullable = true)
#  |-- tags_Heist: long (nullable = true)
#  |-- tags_Hentai: long (nullable = true)
#  |-- tags_Hero_Shooter: long (nullable = true)
#  |-- tags_Hex_Grid: long (nullable = true)
#  |-- tags_Hidden_Object: long (nullable = true)
#  |-- tags_Historical: long (nullable = true)
#  |-- tags_Hockey: long (nullable = true)
#  |-- tags_Horror: long (nullable = true)
#  |-- tags_Horses: long (nullable = true)
#  |-- tags_Hunting: long (nullable = true)
#  |-- tags_Idler: long (nullable = true)
#  |-- tags_Illuminati: long (nullable = true)
#  |-- tags_Immersive: long (nullable = true)
#  |-- tags_Immersive_Sim: long (nullable = true)
#  |-- tags_Indie: long (nullable = true)
#  |-- tags_Instrumental_Music: long (nullable = true)
#  |-- tags_Intentionally_Awkward_Controls: long (nullable = true)
#  |-- tags_Interactive_Fiction: long (nullable = true)
#  |-- tags_Inventory_Management: long (nullable = true)
#  |-- tags_Investigation: long (nullable = true)
#  |-- tags_Isometric: long (nullable = true)
#  |-- tags_JRPG: long (nullable = true)
#  |-- tags_Jet: long (nullable = true)
#  |-- tags_Job_Simulator: long (nullable = true)
#  |-- tags_Jump_Scare: long (nullable = true)
#  |-- tags_Kickstarter: long (nullable = true)
#  |-- tags_LEGO: long (nullable = true)
#  |-- tags_LGBTQ+: long (nullable = true)
#  |-- tags_Lemmings: long (nullable = true)
#  |-- tags_Level_Editor: long (nullable = true)
#  |-- tags_Life_Sim: long (nullable = true)
#  |-- tags_Linear: long (nullable = true)
#  |-- tags_Local_Co_Op: long (nullable = true)
#  |-- tags_Local_Multiplayer: long (nullable = true)
#  |-- tags_Logic: long (nullable = true)
#  |-- tags_Loot: long (nullable = true)
#  |-- tags_Looter_Shooter: long (nullable = true)
#  |-- tags_Lore_Rich: long (nullable = true)
#  |-- tags_Lovecraftian: long (nullable = true)
#  |-- tags_MMORPG: long (nullable = true)
#  |-- tags_MOBA: long (nullable = true)
#  |-- tags_Magic: long (nullable = true)
#  |-- tags_Mahjong: long (nullable = true)
#  |-- tags_Management: long (nullable = true)
#  |-- tags_Mars: long (nullable = true)
#  |-- tags_Martial_Arts: long (nullable = true)
#  |-- tags_Massively_Multiplayer: long (nullable = true)
#  |-- tags_Masterpiece: long (nullable = true)
#  |-- tags_Match_3: long (nullable = true)
#  |-- tags_Mature: long (nullable = true)
#  |-- tags_Mechs: long (nullable = true)
#  |-- tags_Medical_Sim: long (nullable = true)
#  |-- tags_Medieval: long (nullable = true)
#  |-- tags_Memes: long (nullable = true)
#  |-- tags_Metroidvania: long (nullable = true)
#  |-- tags_Military: long (nullable = true)
#  |-- tags_Mini_Golf: long (nullable = true)
#  |-- tags_Minigames: long (nullable = true)
#  |-- tags_Minimalist: long (nullable = true)
#  |-- tags_Mining: long (nullable = true)
#  |-- tags_Mod: long (nullable = true)
#  |-- tags_Moddable: long (nullable = true)
#  |-- tags_Modern: long (nullable = true)
#  |-- tags_Motocross: long (nullable = true)
#  |-- tags_Motorbike: long (nullable = true)
#  |-- tags_Mouse_only: long (nullable = true)
#  |-- tags_Movie: long (nullable = true)
#  |-- tags_Multiplayer: long (nullable = true)
#  |-- tags_Multiple_Endings: long (nullable = true)
#  |-- tags_Music: long (nullable = true)
#  |-- tags_Music_Based_Procedural_Generation: long (nullable = true)
#  |-- tags_Musou: long (nullable = true)
#  |-- tags_Mystery: long (nullable = true)
#  |-- tags_Mystery_Dungeon: long (nullable = true)
#  |-- tags_Mythology: long (nullable = true)
#  |-- tags_NSFW: long (nullable = true)
#  |-- tags_Narration: long (nullable = true)
#  |-- tags_Narrative: long (nullable = true)
#  |-- tags_Nature: long (nullable = true)
#  |-- tags_Naval: long (nullable = true)
#  |-- tags_Naval_Combat: long (nullable = true)
#  |-- tags_Ninja: long (nullable = true)
#  |-- tags_Noir: long (nullable = true)
#  |-- tags_Nonlinear: long (nullable = true)
#  |-- tags_Nostalgia: long (nullable = true)
#  |-- tags_Nudity: long (nullable = true)
#  |-- tags_Offroad: long (nullable = true)
#  |-- tags_Old_School: long (nullable = true)
#  |-- tags_On_Rails_Shooter: long (nullable = true)
#  |-- tags_Online_Co_Op: long (nullable = true)
#  |-- tags_Open_World: long (nullable = true)
#  |-- tags_Open_World_Survival_Craft: long (nullable = true)
#  |-- tags_Otome: long (nullable = true)
#  |-- tags_Outbreak_Sim: long (nullable = true)
#  |-- tags_Parkour: long (nullable = true)
#  |-- tags_Parody_: long (nullable = true)
#  |-- tags_Party: long (nullable = true)
#  |-- tags_Party_Game: long (nullable = true)
#  |-- tags_Party_Based_RPG: long (nullable = true)
#  |-- tags_Perma_Death: long (nullable = true)
#  |-- tags_Philosophical: long (nullable = true)
#  |-- tags_Photo_Editing: long (nullable = true)
#  |-- tags_Physics: long (nullable = true)
#  |-- tags_Pinball: long (nullable = true)
#  |-- tags_Pirates: long (nullable = true)
#  |-- tags_Pixel_Graphics: long (nullable = true)
#  |-- tags_Platformer: long (nullable = true)
#  |-- tags_Point_And_Click: long (nullable = true)
#  |-- tags_Political: long (nullable = true)
#  |-- tags_Political_Sim: long (nullable = true)
#  |-- tags_Politics: long (nullable = true)
#  |-- tags_Pool: long (nullable = true)
#  |-- tags_Post_apocalyptic: long (nullable = true)
#  |-- tags_Precision_Platformer: long (nullable = true)
#  |-- tags_Procedural_Generation: long (nullable = true)
#  |-- tags_Programming: long (nullable = true)
#  |-- tags_Psychedelic: long (nullable = true)
#  |-- tags_Psychological: long (nullable = true)
#  |-- tags_Psychological_Horror: long (nullable = true)
#  |-- tags_Puzzle: long (nullable = true)
#  |-- tags_Puzzle_Platformer: long (nullable = true)
#  |-- tags_PvE: long (nullable = true)
#  |-- tags_PvP: long (nullable = true)
#  |-- tags_Quick_Time_Events: long (nullable = true)
#  |-- tags_RPG: long (nullable = true)
#  |-- tags_RPGMaker: long (nullable = true)
#  |-- tags_RTS: long (nullable = true)
#  |-- tags_Racing: long (nullable = true)
#  |-- tags_Real_Time_Tactics: long (nullable = true)
#  |-- tags_Real_Time: long (nullable = true)
#  |-- tags_Real_Time_with_Pause: long (nullable = true)
#  |-- tags_Realistic: long (nullable = true)
#  |-- tags_Reboot: long (nullable = true)
#  |-- tags_Relaxing: long (nullable = true)
#  |-- tags_Remake: long (nullable = true)
#  |-- tags_Replay_Value: long (nullable = true)
#  |-- tags_Resource_Management: long (nullable = true)
#  |-- tags_Retro: long (nullable = true)
#  |-- tags_Rhythm: long (nullable = true)
#  |-- tags_Robots: long (nullable = true)
#  |-- tags_Rock_Music: long (nullable = true)
#  |-- tags_Rogue_like: long (nullable = true)
#  |-- tags_Rogue_lite: long (nullable = true)
#  |-- tags_Roguelike_Deckbuilder: long (nullable = true)
#  |-- tags_Roguevania: long (nullable = true)
#  |-- tags_Romance: long (nullable = true)
#  |-- tags_Rome: long (nullable = true)
#  |-- tags_Rugby: long (nullable = true)
#  |-- tags_Runner: long (nullable = true)
#  |-- tags_Sailing: long (nullable = true)
#  |-- tags_Sandbox: long (nullable = true)
#  |-- tags_Satire: long (nullable = true)
#  |-- tags_Sci_fi: long (nullable = true)
#  |-- tags_Science: long (nullable = true)
#  |-- tags_Score_Attack: long (nullable = true)
#  |-- tags_Sequel: long (nullable = true)
#  |-- tags_Sexual_Content: long (nullable = true)
#  |-- tags_Shoot_Em_Up: long (nullable = true)
#  |-- tags_Shooter: long (nullable = true)
#  |-- tags_Shop_Keeper: long (nullable = true)
#  |-- tags_Short: long (nullable = true)
#  |-- tags_Side_Scroller: long (nullable = true)
#  |-- tags_Silent_Protagonist: long (nullable = true)
#  |-- tags_Simulation: long (nullable = true)
#  |-- tags_Singleplayer: long (nullable = true)
#  |-- tags_Skateboarding: long (nullable = true)
#  |-- tags_Skating: long (nullable = true)
#  |-- tags_Skiing: long (nullable = true)
#  |-- tags_Sniper: long (nullable = true)
#  |-- tags_Snooker: long (nullable = true)
#  |-- tags_Snow: long (nullable = true)
#  |-- tags_Snowboarding: long (nullable = true)
#  |-- tags_Soccer: long (nullable = true)
#  |-- tags_Social_Deduction: long (nullable = true)
#  |-- tags_Software: long (nullable = true)
#  |-- tags_Software_Training: long (nullable = true)
#  |-- tags_Sokoban: long (nullable = true)
#  |-- tags_Solitaire: long (nullable = true)
#  |-- tags_Souls_like: long (nullable = true)
#  |-- tags_Soundtrack: long (nullable = true)
#  |-- tags_Space: long (nullable = true)
#  |-- tags_Space_Sim: long (nullable = true)
#  |-- tags_Spaceships: long (nullable = true)
#  |-- tags_Spectacle_fighter: long (nullable = true)
#  |-- tags_Spelling: long (nullable = true)
#  |-- tags_Split_Screen: long (nullable = true)
#  |-- tags_Sports: long (nullable = true)
#  |-- tags_Stealth: long (nullable = true)
#  |-- tags_Steam_Machine: long (nullable = true)
#  |-- tags_Steampunk: long (nullable = true)
#  |-- tags_Story_Rich: long (nullable = true)
#  |-- tags_Strategy: long (nullable = true)
#  |-- tags_Strategy_RPG: long (nullable = true)
#  |-- tags_Stylized: long (nullable = true)
#  |-- tags_Submarine: long (nullable = true)
#  |-- tags_Superhero: long (nullable = true)
#  |-- tags_Supernatural: long (nullable = true)
#  |-- tags_Surreal: long (nullable = true)
#  |-- tags_Survival: long (nullable = true)
#  |-- tags_Survival_Horror: long (nullable = true)
#  |-- tags_Swordplay: long (nullable = true)
#  |-- tags_Tabletop: long (nullable = true)
#  |-- tags_Tactical: long (nullable = true)
#  |-- tags_Tactical_RPG: long (nullable = true)
#  |-- tags_Tanks: long (nullable = true)
#  |-- tags_Team_Based: long (nullable = true)
#  |-- tags_Tennis: long (nullable = true)
#  |-- tags_Text_Based: long (nullable = true)
#  |-- tags_Third_Person: long (nullable = true)
#  |-- tags_Third_Person_Shooter: long (nullable = true)
#  |-- tags_Thriller: long (nullable = true)
#  |-- tags_Tile_Matching: long (nullable = true)
#  |-- tags_Time_Attack: long (nullable = true)
#  |-- tags_Time_Management: long (nullable = true)
#  |-- tags_Time_Manipulation: long (nullable = true)
#  |-- tags_Time_Travel: long (nullable = true)
#  |-- tags_Top_Down: long (nullable = true)
#  |-- tags_Top_Down_Shooter: long (nullable = true)
#  |-- tags_Touch_Friendly: long (nullable = true)
#  |-- tags_Tower_Defense: long (nullable = true)
#  |-- tags_TrackIR: long (nullable = true)
#  |-- tags_Trading: long (nullable = true)
#  |-- tags_Trading_Card_Game: long (nullable = true)
#  |-- tags_Traditional_Roguelike: long (nullable = true)
#  |-- tags_Trains: long (nullable = true)
#  |-- tags_Transhumanism: long (nullable = true)
#  |-- tags_Transportation: long (nullable = true)
#  |-- tags_Trivia: long (nullable = true)
#  |-- tags_Turn_Based: long (nullable = true)
#  |-- tags_Turn_Based_Combat: long (nullable = true)
#  |-- tags_Turn_Based_Strategy: long (nullable = true)
#  |-- tags_Turn_Based_Tactics: long (nullable = true)
#  |-- tags_Tutorial: long (nullable = true)
#  |-- tags_Twin_Stick_Shooter: long (nullable = true)
#  |-- tags_Typing: long (nullable = true)
#  |-- tags_Underground: long (nullable = true)
#  |-- tags_Underwater: long (nullable = true)
#  |-- tags_Unforgiving: long (nullable = true)
#  |-- tags_Utilities: long (nullable = true)
#  |-- tags_VR: long (nullable = true)
#  |-- tags_VR_Only: long (nullable = true)
#  |-- tags_Vampire: long (nullable = true)
#  |-- tags_Vehicular_Combat: long (nullable = true)
#  |-- tags_Video_Production: long (nullable = true)
#  |-- tags_Vikings: long (nullable = true)
#  |-- tags_Villain_Protagonist: long (nullable = true)
#  |-- tags_Violent: long (nullable = true)
#  |-- tags_Visual_Novel: long (nullable = true)
#  |-- tags_Voice_Control: long (nullable = true)
#  |-- tags_Volleyball: long (nullable = true)
#  |-- tags_Voxel: long (nullable = true)
#  |-- tags_Walking_Simulator: long (nullable = true)
#  |-- tags_War: long (nullable = true)
#  |-- tags_Wargame: long (nullable = true)
#  |-- tags_Warhammer_40K: long (nullable = true)
#  |-- tags_Web_Publishing: long (nullable = true)
#  |-- tags_Well_Written: long (nullable = true)
#  |-- tags_Werewolves: long (nullable = true)
#  |-- tags_Western: long (nullable = true)
#  |-- tags_Wholesome: long (nullable = true)
#  |-- tags_Word_Game: long (nullable = true)
#  |-- tags_World_War_I: long (nullable = true)
#  |-- tags_World_War_II: long (nullable = true)
#  |-- tags_Wrestling: long (nullable = true)
#  |-- tags_Zombies: long (nullable = true)
#  |-- tags_e_sports: long (nullable = true)
#  |-- type: string (nullable = true)
#  |-- website: string (nullable = true)

# %%
df_renamed.columns
# Out:
# Out[41]: ['appid',
#  'ccu',
#  'developer',
#  'discount',
#  'genre',
#  'header_image',
#  'initialprice',
#  'languages',
#  'name',
#  'negative',
#  'owners',
#  'platforms_linux',
#  'platforms_mac',
#  'platforms_windows',
#  'positive',
#  'price',
#  'publisher',
#  'release_date',
#  'required_age',
#  'short_description',
#  'tags_1980s',
#  'tags_1990s',
#  'tags_2_5D',
#  'tags_2D',
#  'tags_2D_Fighter',
#  'tags_2D_Platformer',
#  'tags_360_Video',
#  'tags_3D',
#  'tags_3D_Fighter',
#  'tags_3D_Platformer',
#  'tags_3D_Vision',
#  'tags_4_Player_Local',
#  'tags_4X',
#  'tags_6DOF',
#  'tags_8_bit_Music',
#  'tags_ATV',
#  'tags_Abstract',
#  'tags_Action',
#  'tags_Action_RPG',
#  'tags_Action_RTS',
#  'tags_Action_Roguelike',
#  'tags_Action_Adventure',
#  'tags_Addictive',
#  'tags_Adventure',
#  'tags_Agriculture',
#  'tags_Aliens',
#  'tags_Alternate_History',
#  'tags_Ambient',
#  'tags_America',
#  'tags_Animation_And_Modeling',
#  'tags_Anime',
#  'tags_Arcade',
#  'tags_Archery',
#  'tags_Arena_Shooter',
#  'tags_Artificial_Intelligence',
#  'tags_Assassin',
#  'tags_Asymmetric_VR',
#  'tags_Asynchronous_Multiplayer',
#  'tags_Atmospheric',
#  'tags_Audio_Production',
#  'tags_Auto_Battler',
#  'tags_Automation',
#  'tags_Automobile_Sim',
#  'tags_BMX',
#  'tags_Base_Building',
#  'tags_Baseball',
#  'tags_Based_On_A_Novel',
#  'tags_Basketball',
#  'tags_Battle_Royale',
#  'tags_Beat_em_up',
#  'tags_Beautiful',
#  'tags_Benchmark',
#  'tags_Bikes',
#  'tags_Blood',
#  'tags_Board_Game',
#  'tags_Boss_Rush',
#  'tags_Bowling',
#  'tags_Boxing',
#  'tags_Building',
#  'tags_Bullet_Hell',
#  'tags_Bullet_Time',
#  'tags_CRPG',
#  'tags_Capitalism',
#  'tags_Card_Battler',
#  'tags_Card_Game',
#  'tags_Cartoon',
#  'tags_Cartoony',
#  'tags_Casual',
#  'tags_Cats',
#  'tags_Character_Action_Game',
#  'tags_Character_Customization',
#  'tags_Chess',
#  'tags_Choices_Matter',
#  'tags_Choose_Your_Own_Adventure',
#  'tags_Cinematic',
#  'tags_City_Builder',
#  'tags_Class_Based',
#  'tags_Classic',
#  'tags_Clicker',
#  'tags_Co_op',
#  'tags_Co_op_Campaign',
#  'tags_Coding',
#  'tags_Cold_War',
#  'tags_Collectathon',
#  'tags_Colony_Sim',
#  'tags_Colorful',
#  'tags_Combat',
#  'tags_Combat_Racing',
#  'tags_Comedy',
#  'tags_Comic_Book',
#  'tags_Competitive',
#  'tags_Conspiracy',
#  'tags_Controller',
#  'tags_Conversation',
#  'tags_Cooking',
#  'tags_Cozy',
#  'tags_Crafting',
#  'tags_Creature_Collector',
#  'tags_Cricket',
#  'tags_Crime',
#  'tags_Crowdfunded',
#  'tags_Cult_Classic',
#  'tags_Cute',
#  'tags_Cyberpunk',
#  'tags_Cycling',
#  'tags_Dark',
#  'tags_Dark_Comedy',
#  'tags_Dark_Fantasy',
#  'tags_Dark_Humor',
#  'tags_Dating_Sim',
#  'tags_Deckbuilding',
#  'tags_Demons',
#  'tags_Design_And_Illustration',
#  'tags_Destruction',
#  'tags_Detective',
#  'tags_Difficult',
#  'tags_Dinosaurs',
#  'tags_Diplomacy',
#  'tags_Documentary',
#  'tags_Dog',
#  'tags_Dragons',
#  'tags_Drama',
#  'tags_Driving',
#  'tags_Dungeon_Crawler',
#  'tags_Dungeons_And_Dragons',
#  'tags_Dynamic_Narration',
#  'tags_Dystopian_',
#  'tags_Early_Access',
#  'tags_Economy',
#  'tags_Education',
#  'tags_Electronic',
#  'tags_Electronic_Music',
#  'tags_Emotional',
#  'tags_Epic',
#  'tags_Episodic',
#  'tags_Escape_Room',
#  'tags_Experience',
#  'tags_Experimental',
#  'tags_Exploration',
#  'tags_FMV',
#  'tags_FPS',
#  'tags_Faith',
#  'tags_Family_Friendly',
#  'tags_Fantasy',
#  'tags_Farming',
#  'tags_Farming_Sim',
#  'tags_Fast_Paced',
#  'tags_Feature_Film',
#  'tags_Female_Protagonist',
#  'tags_Fighting',
#  'tags_First_Person',
#  'tags_Fishing',
#  'tags_Flight',
#  'tags_Football',
#  'tags_Foreign',
#  'tags_Free_to_Play',
#  'tags_Funny',
#  'tags_Futuristic',
#  'tags_Gambling',
#  'tags_Game_Development',
#  'tags_GameMaker',
#  'tags_Games_Workshop',
#  'tags_Gaming',
#  'tags_God_Game',
#  'tags_Golf',
#  'tags_Gore',
#  'tags_Gothic',
#  'tags_Grand_Strategy',
#  'tags_Great_Soundtrack',
#  'tags_Grid_Based_Movement',
#  'tags_Gun_Customization',
#  'tags_Hack_and_Slash',
#  'tags_Hacking',
#  'tags_Hand_drawn',
#  'tags_Hardware',
#  'tags_Heist',
#  'tags_Hentai',
#  'tags_Hero_Shooter',
#  'tags_Hex_Grid',
#  'tags_Hidden_Object',
#  'tags_Historical',
#  'tags_Hockey',
#  'tags_Horror',
#  'tags_Horses',
#  'tags_Hunting',
#  'tags_Idler',
#  'tags_Illuminati',
#  'tags_Immersive',
#  'tags_Immersive_Sim',
#  'tags_Indie',
#  'tags_Instrumental_Music',
#  'tags_Intentionally_Awkward_Controls',
#  'tags_Interactive_Fiction',
#  'tags_Inventory_Management',
#  'tags_Investigation',
#  'tags_Isometric',
#  'tags_JRPG',
#  'tags_Jet',
#  'tags_Job_Simulator',
#  'tags_Jump_Scare',
#  'tags_Kickstarter',
#  'tags_LEGO',
#  'tags_LGBTQ+',
#  'tags_Lemmings',
#  'tags_Level_Editor',
#  'tags_Life_Sim',
#  'tags_Linear',
#  'tags_Local_Co_Op',
#  'tags_Local_Multiplayer',
#  'tags_Logic',
#  'tags_Loot',
#  'tags_Looter_Shooter',
#  'tags_Lore_Rich',
#  'tags_Lovecraftian',
#  'tags_MMORPG',
#  'tags_MOBA',
#  'tags_Magic',
#  'tags_Mahjong',
#  'tags_Management',
#  'tags_Mars',
#  'tags_Martial_Arts',
#  'tags_Massively_Multiplayer',
#  'tags_Masterpiece',
#  'tags_Match_3',
#  'tags_Mature',
#  'tags_Mechs',
#  'tags_Medical_Sim',
#  'tags_Medieval',
#  'tags_Memes',
#  'tags_Metroidvania',
#  'tags_Military',
#  'tags_Mini_Golf',
#  'tags_Minigames',
#  'tags_Minimalist',
#  'tags_Mining',
#  'tags_Mod',
#  'tags_Moddable',
#  'tags_Modern',
#  'tags_Motocross',
#  'tags_Motorbike',
#  'tags_Mouse_only',
#  'tags_Movie',
#  'tags_Multiplayer',
#  'tags_Multiple_Endings',
#  'tags_Music',
#  'tags_Music_Based_Procedural_Generation',
#  'tags_Musou',
#  'tags_Mystery',
#  'tags_Mystery_Dungeon',
#  'tags_Mythology',
#  'tags_NSFW',
#  'tags_Narration',
#  'tags_Narrative',
#  'tags_Nature',
#  'tags_Naval',
#  'tags_Naval_Combat',
#  'tags_Ninja',
#  'tags_Noir',
#  'tags_Nonlinear',
#  'tags_Nostalgia',
#  'tags_Nudity',
#  'tags_Offroad',
#  'tags_Old_School',
#  'tags_On_Rails_Shooter',
#  'tags_Online_Co_Op',
#  'tags_Open_World',
#  'tags_Open_World_Survival_Craft',
#  'tags_Otome',
#  'tags_Outbreak_Sim',
#  'tags_Parkour',
#  'tags_Parody_',
#  'tags_Party',
#  'tags_Party_Game',
#  'tags_Party_Based_RPG',
#  'tags_Perma_Death',
#  'tags_Philosophical',
#  'tags_Photo_Editing',
#  'tags_Physics',
#  'tags_Pinball',
#  'tags_Pirates',
#  'tags_Pixel_Graphics',
#  'tags_Platformer',
#  'tags_Point_And_Click',
#  'tags_Political',
#  'tags_Political_Sim',
#  'tags_Politics',
#  'tags_Pool',
#  'tags_Post_apocalyptic',
#  'tags_Precision_Platformer',
#  'tags_Procedural_Generation',
#  'tags_Programming',
#  'tags_Psychedelic',
#  'tags_Psychological',
#  'tags_Psychological_Horror',
#  'tags_Puzzle',
#  'tags_Puzzle_Platformer',
#  'tags_PvE',
#  'tags_PvP',
#  'tags_Quick_Time_Events',
#  'tags_RPG',
#  'tags_RPGMaker',
#  'tags_RTS',
#  'tags_Racing',
#  'tags_Real_Time_Tactics',
#  'tags_Real_Time',
#  'tags_Real_Time_with_Pause',
#  'tags_Realistic',
#  'tags_Reboot',
#  'tags_Relaxing',
#  'tags_Remake',
#  'tags_Replay_Value',
#  'tags_Resource_Management',
#  'tags_Retro',
#  'tags_Rhythm',
#  'tags_Robots',
#  'tags_Rock_Music',
#  'tags_Rogue_like',
#  'tags_Rogue_lite',
#  'tags_Roguelike_Deckbuilder',
#  'tags_Roguevania',
#  'tags_Romance',
#  'tags_Rome',
#  'tags_Rugby',
#  'tags_Runner',
#  'tags_Sailing',
#  'tags_Sandbox',
#  'tags_Satire',
#  'tags_Sci_fi',
#  'tags_Science',
#  'tags_Score_Attack',
#  'tags_Sequel',
#  'tags_Sexual_Content',
#  'tags_Shoot_Em_Up',
#  'tags_Shooter',
#  'tags_Shop_Keeper',
#  'tags_Short',
#  'tags_Side_Scroller',
#  'tags_Silent_Protagonist',
#  'tags_Simulation',
#  'tags_Singleplayer',
#  'tags_Skateboarding',
#  'tags_Skating',
#  'tags_Skiing',
#  'tags_Sniper',
#  'tags_Snooker',
#  'tags_Snow',
#  'tags_Snowboarding',
#  'tags_Soccer',
#  'tags_Social_Deduction',
#  'tags_Software',
#  'tags_Software_Training',
#  'tags_Sokoban',
#  'tags_Solitaire',
#  'tags_Souls_like',
#  'tags_Soundtrack',
#  'tags_Space',
#  'tags_Space_Sim',
#  'tags_Spaceships',
#  'tags_Spectacle_fighter',
#  'tags_Spelling',
#  'tags_Split_Screen',
#  'tags_Sports',
#  'tags_Stealth',
#  'tags_Steam_Machine',
#  'tags_Steampunk',
#  'tags_Story_Rich',
#  'tags_Strategy',
#  'tags_Strategy_RPG',
#  'tags_Stylized',
#  'tags_Submarine',
#  'tags_Superhero',
#  'tags_Supernatural',
#  'tags_Surreal',
#  'tags_Survival',
#  'tags_Survival_Horror',
#  'tags_Swordplay',
#  'tags_Tabletop',
#  'tags_Tactical',
#  'tags_Tactical_RPG',
#  'tags_Tanks',
#  'tags_Team_Based',
#  'tags_Tennis',
#  'tags_Text_Based',
#  'tags_Third_Person',
#  'tags_Third_Person_Shooter',
#  'tags_Thriller',
#  'tags_Tile_Matching',
#  'tags_Time_Attack',
#  'tags_Time_Management',
#  'tags_Time_Manipulation',
#  'tags_Time_Travel',
#  'tags_Top_Down',
#  'tags_Top_Down_Shooter',
#  'tags_Touch_Friendly',
#  'tags_Tower_Defense',
#  'tags_TrackIR',
#  'tags_Trading',
#  'tags_Trading_Card_Game',
#  'tags_Traditional_Roguelike',
#  'tags_Trains',
#  'tags_Transhumanism',
#  'tags_Transportation',
#  'tags_Trivia',
#  'tags_Turn_Based',
#  'tags_Turn_Based_Combat',
#  'tags_Turn_Based_Strategy',
#  'tags_Turn_Based_Tactics',
#  'tags_Tutorial',
#  'tags_Twin_Stick_Shooter',
#  'tags_Typing',
#  'tags_Underground',
#  'tags_Underwater',
#  'tags_Unforgiving',
#  'tags_Utilities',
#  'tags_VR',
#  'tags_VR_Only',
#  'tags_Vampire',
#  'tags_Vehicular_Combat',
#  'tags_Video_Production',
#  'tags_Vikings',
#  'tags_Villain_Protagonist',
#  'tags_Violent',
#  'tags_Visual_Novel',
#  'tags_Voice_Control',
#  'tags_Volleyball',
#  'tags_Voxel',
#  'tags_Walking_Simulator',
#  'tags_War',
#  'tags_Wargame',
#  'tags_Warhammer_40K',
#  'tags_Web_Publishing',
#  'tags_Well_Written',
#  'tags_Werewolves',
#  'tags_Western',
#  'tags_Wholesome',
#  'tags_Word_Game',
#  'tags_World_War_I',
#  'tags_World_War_II',
#  'tags_Wrestling',
#  'tags_Zombies',
#  'tags_e_sports',
#  'type',
#  'website']

# %%
len(df_renamed.columns)
# Out:
# Out[42]: 463

# %% [markdown]
# ## Suppression des colonnes inutiles
#
# Le dataframe contient plus de 460 colonnes. Nous identifions les colonnes inutiles pour notre étude.

# %%
df_renamed.select('type').groupBy('type').count().orderBy(F.desc('count')).show()
# Out:
# +--------+-----+
# |    type|count|
# +--------+-----+
# |    game|55690|
# |hardware|    1|
# +--------+-----+

# %% [markdown]
# Nous remarquons que toutes les valeurs de la colonne *type* sont *game* excepté pour l'application Steam Link qui est un *hardware*.
# Nous pouvons supprimer cette application de notre jeu de données.

# %%
df_renamed.createOrReplaceTempView('steam_games_table')
display(spark.sql("""
    SELECT * FROM steam_games_table
    WHERE type = 'hardware'
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appid</th><th>ccu</th><th>developer</th><th>discount</th><th>genre</th><th>header_image</th><th>initialprice</th><th>languages</th><th>name</th><th>negative</th><th>owners</th><th>platforms_linux</th><th>platforms_mac</th><th>platforms_windows</th><th>positive</th><th>price</th><th>publisher</th><th>release_date</th><th>required_age</th><th>short_description</th><th>tags_1980s</th><th>tags_1990s</th><th>tags_2_5D</th><th>tags_2D</th><th>tags_2D_Fighter</th><th>tags_2D_Platformer</th><th>tags_360_Video</th><th>tags_3D</th><th>tags_3D_Fighter</th><th>tags_3D_Platformer</th><th>tags_3D_Vision</th><th>tags_4_Player_Local</th><th>tags_4X</th><th>tags_6DOF</th><th>tags_8_bit_Music</th><th>tags_ATV</th><th>tags_Abstract</th><th>tags_Action</th><th>tags_Action_RPG</th><th>tags_Action_RTS</th><th>tags_Action_Roguelike</th><th>tags_Action_Adventure</th><th>tags_Addictive</th><th>tags_Adventure</th><th>tags_Agriculture</th><th>tags_Aliens</th><th>tags_Alternate_History</th><th>tags_Ambient</th><th>tags_America</th><th>tags_Animation_And_Modeling</th><th>tags_Anime</th><th>tags_Arcade</th><th>tags_Archery</th><th>tags_Arena_Shooter</th><th>tags_Artificial_Intelligence</th><th>tags_Assassin</th><th>tags_Asymmetric_VR</th><th>tags_Asynchronous_Multiplayer</th><th>tags_Atmospheric</th><th>tags_Audio_Production</th><th>tags_Auto_Battler</th><th>tags_Automation</th><th>tags_Automobile_Sim</th><th>tags_BMX</th><th>tags_Base_Building</th><th>tags_Baseball</th><th>tags_Based_On_A_Novel</th><th>tags_Basketball</th><th>tags_Battle_Royale</th><th>tags_Beat_em_up</th><th>tags_Beautiful</th><th>tags_Benchmark</th><th>tags_Bikes</th><th>tags_Blood</th><th>tags_Board_Game</th><th>tags_Boss_Rush</th><th>tags_Bowling</th><th>tags_Boxing</th><th>tags_Building</th><th>tags_Bullet_Hell</th><th>tags_Bullet_Time</th><th>tags_CRPG</th><th>tags_Capitalism</th><th>tags_Card_Battler</th><th>tags_Card_Game</th><th>tags_Cartoon</th><th>tags_Cartoony</th><th>tags_Casual</th><th>tags_Cats</th><th>tags_Character_Action_Game</th><th>tags_Character_Customization</th><th>tags_Chess</th><th>tags_Choices_Matter</th><th>tags_Choose_Your_Own_Adventure</th><th>tags_Cinematic</th><th>tags_City_Builder</th><th>tags_Class_Based</th><th>tags_Classic</th><th>tags_Clicker</th><th>tags_Co_op</th><th>tags_Co_op_Campaign</th><th>tags_Coding</th><th>tags_Cold_War</th><th>tags_Collectathon</th><th>tags_Colony_Sim</th><th>tags_Colorful</th><th>tags_Combat</th><th>tags_Combat_Racing</th><th>tags_Comedy</th><th>tags_Comic_Book</th><th>tags_Competitive</th><th>tags_Conspiracy</th><th>tags_Controller</th><th>tags_Conversation</th><th>tags_Cooking</th><th>tags_Cozy</th><th>tags_Crafting</th><th>tags_Creature_Collector</th><th>tags_Cricket</th><th>tags_Crime</th><th>tags_Crowdfunded</th><th>tags_Cult_Classic</th><th>tags_Cute</th><th>tags_Cyberpunk</th><th>tags_Cycling</th><th>tags_Dark</th><th>tags_Dark_Comedy</th><th>tags_Dark_Fantasy</th><th>tags_Dark_Humor</th><th>tags_Dating_Sim</th><th>tags_Deckbuilding</th><th>tags_Demons</th><th>tags_Design_And_Illustration</th><th>tags_Destruction</th><th>tags_Detective</th><th>tags_Difficult</th><th>tags_Dinosaurs</th><th>tags_Diplomacy</th><th>tags_Documentary</th><th>tags_Dog</th><th>tags_Dragons</th><th>tags_Drama</th><th>tags_Driving</th><th>tags_Dungeon_Crawler</th><th>tags_Dungeons_And_Dragons</th><th>tags_Dynamic_Narration</th><th>tags_Dystopian_</th><th>tags_Early_Access</th><th>tags_Economy</th><th>tags_Education</th><th>tags_Electronic</th><th>tags_Electronic_Music</th><th>tags_Emotional</th><th>tags_Epic</th><th>tags_Episodic</th><th>tags_Escape_Room</th><th>tags_Experience</th><th>tags_Experimental</th><th>tags_Exploration</th><th>tags_FMV</th><th>tags_FPS</th><th>tags_Faith</th><th>tags_Family_Friendly</th><th>tags_Fantasy</th><th>tags_Farming</th><th>tags_Farming_Sim</th><th>tags_Fast_Paced</th><th>tags_Feature_Film</th> ...

# %%
useless_cols = ['header_image', 'short_description', 'type', 'website']
df_clean = df_renamed.alias('df_clean')
df_clean = df_clean.filter(df_clean['type'] != 'hardware')
df_clean = df_clean.drop(*useless_cols)

# %% [markdown]
# ## Mettre le prix au bon format
#
# Nous mettons les colonnes *price*, *initialprice* et *discount* au format float et integer.
# Nous divisons les colonnes *price* et *initalprice* par 100.

# %%
from pyspark.sql.types import IntegerType
df_clean = df_clean \
    .withColumn('price', df_renamed['price'].cast('float')) \
    .withColumn('initialprice', df_renamed['initialprice'].cast('float')) \
    .withColumn('discount', df_renamed['discount'].cast(IntegerType()))

# %%
df_clean = df_clean \
    .withColumn('price', F.col('price')/100) \
    .withColumn('initialprice', F.col('initialprice')/100)

# %% [markdown]
# # PARTIE 2 : Analyse des données

# %% [markdown]
# ## Analyse au niveau macro

# %% [markdown]
# #### 1. Quel éditeur a sorti le plus de jeux sur Steam ?
# --> Sega est l'éditeur qui a sorti le plus de jeux sur Steam (165)

# %%
df_clean.createOrReplaceTempView('steam_games_table')

spark.sql("""
          SELECT publisher, COUNT(publisher) AS cnt
          FROM steam_games_table
          GROUP BY publisher
          ORDER BY cnt DESC 
""").show()
# Out:
# +--------------------+---+
# |           publisher|cnt|
# +--------------------+---+
# |      Big Fish Games|422|
# |              8floor|202|
# |                SEGA|165|
# |      Strategy First|151|
# |         Square Enix|141|
# |     Choice of Games|140|
# |       Sekai Project|132|
# |            HH-Games|132|
# |                    |132|
# |             Ubisoft|127|
# |        Laush Studio|126|
# |          THQ Nordic|125|
# |Alawar Entertainment|107|
# |  Fulqrum Publishing|104|
# |     Plug In Digital|101|
# |            Ziggurat|100|
# |     Slitherine Ltd.| 99|
# |   Sokpop Collective| 99|
# |    Devolver Digital| 98|
# |KOEI TECMO GAMES ...| 90|
# +--------------------+---+
# only showing top 20 rows

# %% [markdown]
# #### 2. Quels sont les jeux les mieux notés ?
# --> Counter-Strike 2 avec 5.9 millions de notes positives

# %%
spark.sql("""
          SELECT appid, name, positive
          FROM steam_games_table
          ORDER BY positive DESC
""").show()
# Out:
# +-------+--------------------+--------+
# |  appid|                name|positive|
# +-------+--------------------+--------+
# |    730|Counter-Strike: G...| 5943345|
# |    570|              Dota 2| 1534895|
# | 271590|  Grand Theft Auto V| 1229265|
# | 578080| PUBG: BATTLEGROUNDS| 1185361|
# | 105600|            Terraria| 1014711|
# | 359550|Tom Clancy's Rain...|  942910|
# |   4000|         Garry's Mod|  861240|
# |    440|     Team Fortress 2|  846407|
# | 252490|                Rust|  732513|
# |    550|       Left 4 Dead 2|  643836|
# | 292030|The Witcher 3: Wi...|  632627|
# | 945360|            Among Us|  586302|
# | 227300|Euro Truck Simula...|  572368|
# | 431960|    Wallpaper Engine|  561096|
# | 218620|            PAYDAY 2|  532013|
# | 381210|    Dead by Daylight|  509637|
# | 413150|      Stardew Valley|  497558|
# | 252950|       Rocket League|  496499|
# |1245620|          ELDEN RING|  490203|
# | 346110|ARK: Survival Evo...|  481318|
# +-------+--------------------+--------+
# only showing top 20 rows

# %% [markdown]
# #### 3. Y a-t-il des années avec plus de sorties ? Y a-t-il eu plus ou moins de sorties de jeux pendant le Covid par exemple ?
# --> 2021, 2020, 2018 et 2022 sont les années où il y a eu le plus de jeux sortis (plus de 7000)
# --> Le record est atteint en 2021 durant le Covid : 8823 jeux sortis

# %%
df_release_date = df_renamed.select('release_date', F.substring('release_date',1,4).alias('year'))
df_release_date.printSchema()
# Out:
# root
#  |-- release_date: string (nullable = true)
#  |-- year: string (nullable = true)

# %%
df_release_date.createOrReplaceTempView('release_year_table')
spark.sql("""
          SELECT year, COUNT(year) AS cnt
          FROM release_year_table
          GROUP BY year
          ORDER BY cnt DESC
""").show()
# Out:
# +----+----+
# |year| cnt|
# +----+----+
# |2021|8823|
# |2020|8305|
# |2018|7678|
# |2022|7455|
# |2019|6968|
# |2017|6017|
# |2016|4185|
# |2015|2576|
# |2014|1557|
# |2013| 471|
# |2012| 345|
# |2009| 311|
# |2010| 288|
# |2011| 267|
# |2008| 159|
# |    |  99|
# |2007|  98|
# |2006|  61|
# |2005|   6|
# |2004|   6|
# +----+----+
# only showing top 20 rows

# %% [markdown]
# #### 4. Comment sont distribués les prix ? Y a-t-il beaucoup de jeux avec une réduction ?
# --> Les prix vont de 0 à 999 dollars
# --> Environ 2500 jeux sont en promotion soit 4% des jeux

# %%
df_price = df_clean.select(['initialprice', 'discount', 'price'])
df_price.printSchema()
# Out:
# root
#  |-- initialprice: double (nullable = true)
#  |-- discount: integer (nullable = true)
#  |-- price: double (nullable = true)

# %%
from pyspark.sql.functions import col, log
df_price = df_price.withColumn("logprice", log(10.0, col("price")))

# %%
df_price.createOrReplaceTempView('price_table')

spark.sql("""
          SELECT initialprice
          FROM price_table
          GROUP BY initialprice
          ORDER BY initialprice DESC
""").show()
# Out:
# +------------+
# |initialprice|
# +------------+
# |       999.0|
# |       299.9|
# |      269.99|
# |       249.0|
# |      199.99|
# |      149.99|
# |       149.0|
# |      129.99|
# |      124.99|
# |      119.99|
# |       99.99|
# |        99.0|
# |       94.99|
# |       89.99|
# |       84.99|
# |       79.99|
# |       74.99|
# |       69.99|
# |       69.95|
# |       69.03|
# +------------+
# only showing top 20 rows

# %%
# Ouvrez le notebook dans Databricks pour voir la visualisation :
display(df_price.select('logprice'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>logprice</th></tr></thead><tbody><tr><td>0.9995654882259822</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>0.7774268223893113</td></tr><tr><td>1.300812794118117</td></tr><tr><td>0.2988530764097066</td></tr><tr><td>0.9025467793139913</td></tr><tr><td>1.113609151073028</td></tr><tr><td>null</td></tr><tr><td>0.4756711883244296</td></tr><tr><td>1.1458177144918276</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>1.2301933788690456</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>1.39776625612645</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>0.8444771757456813</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>null</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>0.4756711883244296</td></tr><tr><td>1.300812794118117</td></tr><tr><td>1.0788191830988485</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>1.1758016328482794</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>0.9025467793139913</td></tr><tr><td>0.6009728956867482</td></tr><tr><td>0.29666519026153104</td></tr><tr><td>0.8444771757456813</td></tr><tr><td>0.8444771757456813</td></tr><tr><td>0.2988530764097066</td></tr><tr><td>1.300812794118117</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>1.2038484637462346</td></tr><tr><td>1.1758016328482794</td></tr><tr><td>null</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>1.113609151073028</td></tr><tr><td>1.300812794118117</td></tr><tr><td>null</td></tr><tr><td>1.0409976924234905</td></tr><tr><td>0.8444771757456813</td></tr><tr><td>0.2988530764097066</td></tr><tr><td>0.8444771757456813</td></tr><tr><td>0.7774268223893113</td></tr><tr><td>null</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>null</td></tr><tr><td>0.4756711883244296</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>null</td></tr><tr><td>1.2301933788690456</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>0.2988530764097066</td></tr><tr><td>0.2988530764097066</td></tr><tr><td>null</td></tr><tr><td>0.9025467793139913</td></tr><tr><td>0.9537596917332287</td></tr><tr><td>1.113609151073028</td></tr><tr><td>0.6009728956867482</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>1.1758016328482794</td></tr><tr><td>null</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>1.1758016328482794</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>0.9537596917332287</td></tr><tr><td>0.4756711883244296</td></tr><tr><td>null</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>0.5428254269591799</td></tr><tr><td>null</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>1.2301933788690456</td></tr><tr><td>0.9025467793139913</td></tr><tr><td>1.300812794118117</td></tr><tr><td>0.9025467793139913</td></tr><tr><td>null</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>0.7774268223893113</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>0.4756711883244296</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>0.6009728956867482</td></tr><tr><td>0.6009728956867482</td></tr><tr><td>0.6009728956867482</td></tr><tr><td>null</td></tr><tr><td>0.2988530764097066</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>null</td></tr><tr><td>1.0788191830988485</td></tr><tr><td>0.2988530764097066</td></tr><tr><td>0.6009728956867482</td></tr><tr><td>null</td></tr><tr><td>0.9025467793139913</td></tr><tr><td>null</td></tr><tr><td>0.9995654882259822</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>0.6981005456233899</td></tr><tr><td>-0.004364805402450088</td></tr><tr><td>0.4756711883244296</td></tr><tr><td>0.2988 ...
# Databricks visualization. Run in Databricks to view.

# %%
df_price.filter(df_price['discount'] > 0).count()
# Out:
# Out[57]: 2518

# %%
nb_discount = df_price.filter(df_clean['discount'] > 0).count()
proportion = nb_discount/df_price.count()*100
print('proportion de discount:', proportion)
# Out:
# proportion de discount: 4.52145807146705

# %% [markdown]
# #### 5. Quelles sont les langues les plus représentées ?
# --> Sur un total de 55690 jeux la langue la plus fréquente est :
# 1. Anglais 54646
# 2. Allemand 13996
# 3. Français 13406

# %%
from pyspark.sql.functions import split, col
df_languages = df_clean.select(split(col("languages"),",").alias("languages_list"))
df_languages.distinct().show(truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |languages_list                                                                                                                                                                                                                                                                                                                                                          |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[English,  Russian,  French,  German,  Spanish - Spain]                                                                                                                                                                                                                                                                                                                 |
# |[English,  Korean,  Simplified Chinese]                                                                                                                                                                                                                                                                                                                                 |
# |[English,  Spanish - Spain]                                                                                                                                                                                                                                                                                                                                             |
# |[Simplified Chinese,  English,  Traditional Chinese,  Japanese,  Korean]                                                                                                                                                                                                                                                                                                |
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                                                                                                                                                                                                                                                             |
# |[English,  Polish,  Portuguese - Brazil]                                                                                                                                                                                                                                                                                                                                |
# |[English,  Not supported,  Simplified Chinese]                                                                                                                                                                                                                                                                                                                          |
# |[English]                                                                                                                                                                                                                                                                                                                                                               |
# |[English,  French,  Italian,  German,  Spanish - Spain,  Arabic,  Bulgarian,  Czech,  Danish,  Dutch,  Finnish,  Greek,  Hungarian,  Japanese,  Korean,  Norwegian,  Polish,  Portuguese - Portugal,  Portuguese - Brazil,  Romanian,  Russian,  Simplified Chinese,  Spanish - Latin America,  Swedish,  Thai,  Traditional Chinese,  Turkish,  Ukrainian,  Vietnamese]|
# |[English,  French,  Italian,  German,  Spanish - Spain,  Portuguese - Brazil,  Russian,  Japanese]                                                                                                                                                                                                                                                                      |
# |[Simplified Chinese]                                                                                                                                                                                                                                                                                                                                                    |
# |[English,  Simplified Chinese]                                                                                                                                                                                                                                                                                                                                          |
# |[English,  German,  Vietnamese,  Traditional Chinese,  Simplified Chinese,  Korean,  Russian,  Ukrainian,  Japanese]                                                                                                                                                                                                                                                    |
# |[English,  Japanese]                                                                                                                                                                                                                                                                                                                                                    |
# |[English,  French,  German,  Japanese,  Korean,  Spanish - Latin America]                                                                                                                                                                                                                                                                                               |
# |[English,  Simplified Chinese,  Traditional Chinese]                                                                                                                                                                                                                                                                                                                    |
# |[English,  French,  German,  Spanish - Spain,  Russian,  Simplified Chinese,  Ukrainian,  Dutch,  Japanese,  Korean,  Polish,  Spanish - Latin America]                                                                                                                                                                                                                 |
# |[Japanese,  Simplified Chinese,  Traditional Chinese]                                                                                                                                                                                                                                                                                                                   |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]                                                                                                                                                                                                                                     |
# |[English,  Simplified Chinese,  Korean]                                                                                                                                                                                                                                                                                                                                 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
print(df_languages.distinct().count())
# Out:
# 8623

# %%
df_languages.printSchema()
# Out:
# root
#  |-- languages_list: array (nullable = true)
#  |    |-- element: string (containsNull = false)

# %%
from pyspark.sql.functions import explode
df_languages_list = df_languages.select(df_languages.languages_list, explode(df_languages.languages_list).alias('language'))
df_languages_list.show(truncate=False)
df_languages_list.count()
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------+--------------------+
# |languages_list                                                                                                                     |language            |
# +-----------------------------------------------------------------------------------------------------------------------------------+--------------------+
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        |English             |
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        | French             |
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        | German             |
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        | Italian            |
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        | Spanish - Spain    |
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        | Simplified Chinese |
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        | Traditional Chinese|
# |[English,  French,  German,  Italian,  Spanish - Spain,  Simplified Chinese,  Traditional Chinese,  Korean]                        | Korean             |
# |[English,  Korean,  Simplified Chinese]                                                                                            |English             |
# |[English,  Korean,  Simplified Chinese]                                                                                            | Korean             |
# |[English,  Korean,  Simplified Chinese]                                                                                            | Simplified Chinese |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]|Simplified Chinese  |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| English            |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| Japanese           |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| Traditional Chinese|
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| French             |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| German             |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| Spanish - Spain    |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| Russian            |
# |[Simplified Chinese,  English,  Japanese,  Traditional Chinese,  French,  German,  Spanish - Spain,  Russian,  Portuguese - Brazil]| Portuguese - Brazil|
# +-----------------------------------------------------------------------------------------------------------------------------------+--------------------+
# only showing top 20 rows
#
# Out[62]: 202303

# %%
df_languages_list.printSchema()
# Out:
# root
#  |-- languages_list: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- language: string (nullable = false)

# %%
df_languages_list.createOrReplaceTempView('languages_table')
spark.sql("""
          SELECT language, COUNT(language) AS cnt
          FROM languages_table
          GROUP BY language
          ORDER BY cnt DESC
""").show(21, truncate=False)
# Out:
# +------------------------+-----+
# |language                |cnt  |
# +------------------------+-----+
# |English                 |54646|
# | German                 |13996|
# | French                 |13406|
# | Russian                |12839|
# | Spanish - Spain        |12224|
# | Simplified Chinese     |12213|
# | Japanese               |10170|
# | Italian                |9297 |
# | Portuguese - Brazil    |6739 |
# | Korean                 |6575 |
# | Traditional Chinese    |6263 |
# | Polish                 |5369 |
# | Portuguese - Portugal  |4011 |
# | Turkish                |3601 |
# | Dutch                  |3076 |
# | Spanish - Latin America|2729 |
# | Czech                  |2340 |
# | Swedish                |2047 |
# | Ukrainian              |1928 |
# | Hungarian              |1923 |
# | Arabic                 |1794 |
# +------------------------+-----+
# only showing top 21 rows

# %% [markdown]
# #### 6. Existe-t-il de nombreux jeux interdits aux moins de 16/18 ans ?
# --> Il y a 571 jeux interdits aux moins de 16 ans
# --> Sur un total de 55690 jeux cela ne représente que 1%

# %%
df_required_age = df_clean.select(df_clean['name'], df_clean['required_age'])
df_required_age.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- required_age: string (nullable = true)

# %%
print(df_required_age.select('required_age').distinct().count())
# Out:
# 21

# %%
df_required_age.createOrReplaceTempView('required_age_table')
spark.sql("""
          SELECT required_age, COUNT(required_age) as cnt
          FROM required_age_table
          GROUP BY required_age
          ORDER BY cnt DESC
""").show(21)
# Out:
# +------------+-----+
# |required_age|  cnt|
# +------------+-----+
# |           0|55029|
# |          15|  264|
# |          18|  223|
# |          16|   38|
# |          17|   38|
# |          12|   32|
# |          13|   26|
# |          14|   10|
# |          10|    7|
# |           6|    4|
# |         180|    4|
# |           3|    3|
# |           8|    3|
# |           7|    2|
# |          35|    1|
# |         21+|    1|
# |           5|    1|
# |           9|    1|
# |          7+|    1|
# |          20|    1|
# |      MA 15+|    1|
# +------------+-----+

# %% [markdown]
# Les données de la colonne *required_age* ne sont pas au format de nombre entier. Nous rectifions cela :

# %%
def sanitize_required_age(str):
    ''' Fonction pour remplacer les valeurs par des nombres entiers '''
    if str == 'MA 15+':
        return int(16)
    elif str == '7+':
        return int(7)
    elif str == '21+':
        return int(21)
    else:
        return int(str)

# %%
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType
to_int_udf = udf(lambda x:sanitize_required_age(x),IntegerType())
df_age = df_required_age.withColumn('required_age', to_int_udf(col('required_age')))

# %%
df_age.createOrReplaceTempView('required_age_table')
spark.sql("""
          SELECT DISTINCT required_age
          FROM required_age_table
          ORDER BY required_age DESC
""").show(21)
# Out:
# +------------+
# |required_age|
# +------------+
# |         180|
# |          35|
# |          21|
# |          20|
# |          18|
# |          17|
# |          16|
# |          15|
# |          14|
# |          13|
# |          12|
# |          10|
# |           9|
# |           8|
# |           7|
# |           6|
# |           5|
# |           3|
# |           0|
# +------------+

# %%
spark.sql("""
          SELECT required_age, COUNT(required_age) as cnt
          FROM required_age_table
          WHERE required_age > 15
          GROUP BY required_age
          ORDER BY cnt DESC
""").show()
# Out:
# +------------+---+
# |required_age|cnt|
# +------------+---+
# |          18|223|
# |          16| 39|
# |          17| 38|
# |         180|  4|
# |          20|  1|
# |          35|  1|
# |          21|  1|
# +------------+---+

# %%
spark.sql("""
          SELECT COUNT(*) as total_prohibited_under_16
          FROM required_age_table
          WHERE required_age >= 15
""").show()
# Out:
# +-------------------------+
# |total_prohibited_under_16|
# +-------------------------+
# |                      571|
# +-------------------------+

# %%
spark.sql("""
          SELECT * FROM required_age_table
          WHERE required_age == 180
""").show()
# Out:
# +------------------+------------+
# |              name|required_age|
# +------------------+------------+
# | Kissing Simulator|         180|
# |Internet Simulator|         180|
# |   Piano Simulator|         180|
# |    ЕСТЬ ДВА СТУЛА|         180|
# +------------------+------------+

# %% [markdown]
# ## Analyse des genres

# %% [markdown]
# #### 7. Quels sont les genres les plus représentés ?
# --> Le genre Indie est le plus représenté avec 39681 jeux soit plus de 60%

# %%
selected_columns = ['name', 'publisher', 'genre', 'positive', 'negative', 'initialprice', 'discount', 'price', 'owners']
df_genre_initial = df_clean.select(selected_columns)
df_genre_initial.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- positive: long (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- initialprice: double (nullable = true)
#  |-- discount: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- owners: string (nullable = true)

# %%
from pyspark.sql.functions import split, col
df_genre_list = df_genre_initial.withColumn("genre", split(col("genre"),","))
df_genre_list.show()
# Out:
# +------------------------------------+----------------------------+--------------------+--------+--------+------------+--------+-----+--------------------+
# |                                name|                   publisher|               genre|positive|negative|initialprice|discount|price|              owners|
# +------------------------------------+----------------------------+--------------------+--------+--------+------------+--------+-----+--------------------+
# |                      Counter-Strike|                       Valve|            [Action]|  201215|    5199|        9.99|       0| 9.99|10,000,000 .. 20,...|
# |                           ASCENXION|        PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|
# |                         Crown Trick|        Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|
# |                Cook, Serve, Deli...|         Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|
# |                            细胞战争|               DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|
# |                             Zengeon|                    2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|
# |干支セトラ　陽ノ卷｜干支etc.　陽之卷|             Starship Studio|[Adventure,  Indi...|      18|       6|       12.99|       0|12.99|         0 .. 20,000|
# |            Jumping Master(跳跳大咖)|          重庆环游者网络科技|[Action,  Adventu...|      50|      34|         0.0|       0|  0.0|    20,000 .. 50,000|
# |                       Cube Defender|            Simon Codrington|    [Casual,  Indie]|       6|       0|        2.99|       0| 2.99|         0 .. 20,000|
# |                Tower of Origin2-...|                Villain Role|       [Indie,  RPG]|      32|      12|       13.99|       0|13.99|         0 .. 20,000|
# |                      人气动漫大乱斗|海南众铖互娱网络科技有限公司|[Action,  RPG,  S...|       1|       5|        0.99|       0| 0.99|         0 .. 20,000|
# |                       Hellish Quart|                      Kubold|[Action,  Early A...|    4031|     315|       16.99|       0|16.99|  200,000 .. 500,000|
# |                      SurReal Subway|                 LFiO Studio|             [Indie]|       0|       1|         0.0|       0|  0.0|         0 .. 20,000|
# |                        Rogue Reaper|            Fireroot Studios|[Action,  Adventu...|     309|      87|         0.0|       0|  0.0|  100,000 .. 200,000|
# |                 WRATH: Aeon of Ruin|        3D Realms, Fulqru...|[Action,  Early A...|    1212|     328|       24.99|       0|24.99|    20,000 .. 50,000|
# |                Drawngeon: Dungeo...|                DarkDes Labs|[Adventure,  Indi...|      55|      13|        4.99|       0| 4.99|    20,000 .. 50,000|
# |                       Battle Motion|                Meadow Games|[Action,  Indie, ...|       9|       6|        9.99|       0| 9.99|         0 .. 20,000|
# |                The Undisputables...|                    Amonga99|[Action,  Casual,...|       9|       3|        6.99|       0| 6.99|  100,000 .. 200,000|
# |                The Marvellous Ma...|            1337 Game Design|         [Education]|     104|      21|         0.0|       0|  0.0|    20,000 .. 50,000|
# |                    Tactical Control|              Hellride Games|[Casual,  Free to...|      53|      12|         0.0|       0|  0.0|    20,000 .. 50,000|
# +------------------------------------+----------------------------+--------------------+--------+--------+------------+--------+-----+--------------------+
# only showing top 20 rows

# %%
df_genre_list.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- genre: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- positive: long (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- initialprice: double (nullable = true)
#  |-- discount: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- owners: string (nullable = true)

# %%
from pyspark.sql.functions import explode
df_genre = df_genre_list.withColumn('genre_exploded', explode(df_genre_list.genre))
df_genre.show()
# Out:
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+
# |                name|           publisher|               genre|positive|negative|initialprice|discount|price|              owners|genre_exploded|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+
# |      Counter-Strike|               Valve|            [Action]|  201215|    5199|        9.99|       0| 9.99|10,000,000 .. 20,...|        Action|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|        Action|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|     Adventure|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|         Indie|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|     Adventure|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|         Indie|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|           RPG|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|      Strategy|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|        Action|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|         Indie|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|    Simulation|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|      Strategy|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|        Action|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|        Casual|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|         Indie|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|    Simulation|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|        Action|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|     Adventure|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|         Indie|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|           RPG|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+
# only showing top 20 rows

# %%
def sanitizeGenre(s: str) -> str:
        return s.replace(" ", "")

# %%
from pyspark.sql.functions import col, udf
sanitize_udf = udf(lambda x:sanitizeGenre(x))
df_genre_clean = df_genre.withColumn('genre_exploded', sanitize_udf(col('genre_exploded')))
df_genre_clean.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- genre: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- positive: long (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- initialprice: double (nullable = true)
#  |-- discount: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- owners: string (nullable = true)
#  |-- genre_exploded: string (nullable = true)

# %%
df_genre_clean.createOrReplaceTempView('genre_table')

# %%
df_genre_clean.select('genre_exploded').distinct().count()
# Out:
# Out[81]: 29

# %%
df_genre_clean.select('genre_exploded').distinct().sort('genre_exploded', ascending=True).show(29)
# Out:
# +--------------------+
# |      genre_exploded|
# +--------------------+
# |                    |
# |          Accounting|
# |              Action|
# |           Adventure|
# |  Animation&Modeling|
# |     AudioProduction|
# |              Casual|
# | Design&Illustration|
# |         EarlyAccess|
# |           Education|
# |          FreetoPlay|
# |     GameDevelopment|
# |                Gore|
# |               Indie|
# |MassivelyMultiplayer|
# |               Movie|
# |              Nudity|
# |        PhotoEditing|
# |                 RPG|
# |              Racing|
# |       SexualContent|
# |          Simulation|
# |    SoftwareTraining|
# |              Sports|
# |            Strategy|
# |           Utilities|
# |     VideoProduction|
# |             Violent|
# |       WebPublishing|
# +--------------------+

# %%
spark.sql("""
          SELECT genre_exploded, COUNT(genre_exploded) AS cnt
          FROM genre_table
          GROUP BY genre_exploded
          ORDER BY cnt DESC
""").show()
# Out:
# +--------------------+-----+
# |      genre_exploded|  cnt|
# +--------------------+-----+
# |               Indie|39681|
# |              Action|23759|
# |              Casual|22086|
# |           Adventure|21431|
# |            Strategy|10895|
# |          Simulation|10836|
# |                 RPG| 9534|
# |         EarlyAccess| 6145|
# |          FreetoPlay| 3393|
# |              Sports| 2666|
# |              Racing| 2155|
# |MassivelyMultiplayer| 1460|
# |           Utilities|  682|
# | Design&Illustration|  406|
# |  Animation&Modeling|  322|
# |           Education|  317|
# |     VideoProduction|  247|
# |     AudioProduction|  195|
# |             Violent|  168|
# |    SoftwareTraining|  164|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# #### 8. Existe-t-il des genres qui ont un meilleur ratio d'avis positifs/négatifs ?
# --> Les genres Game Development, Adventure, Casual et RPG possèdent le meilleur ratio moyen de 6

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import round
df_genre_review = df_genre_clean.withColumn('review_ratio', round(col('positive')/col('negative'),2))
df_genre_review.show()
df_genre_review.printSchema()
# Out:
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+------------+
# |                name|           publisher|               genre|positive|negative|initialprice|discount|price|              owners|genre_exploded|review_ratio|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+------------+
# |      Counter-Strike|               Valve|            [Action]|  201215|    5199|        9.99|       0| 9.99|10,000,000 .. 20,...|        Action|        38.7|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|        Action|         5.4|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|     Adventure|         5.4|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|         Indie|         5.4|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|     Adventure|        6.24|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|         Indie|        6.24|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|           RPG|        6.24|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|      Strategy|        6.24|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|        Action|        13.7|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|         Indie|        13.7|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|    Simulation|        13.7|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|      Strategy|        13.7|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|        Action|         0.0|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|        Casual|         0.0|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|         Indie|         0.0|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|    Simulation|         0.0|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|        Action|         2.2|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|     Adventure|         2.2|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|         Indie|         2.2|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|           RPG|         2.2|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+------------+
# only showing top 20 rows
#
# root
#  |-- name: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- genre: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- positive: long (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- initialprice: double (nullable = true)
#  |-- discount: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- owners: string (nullable = true)
#  |-- genre_exploded: string (nullable = true)
#  |-- review_ratio: double (nullable = true)

# %%
df_genre_review.createOrReplaceTempView('genre_review_table')
spark.sql("""
          SELECT genre_exploded, SUM(positive) AS sum_positive, SUM(negative) AS sum_negative, ROUND(sum_positive/sum_negative,2) AS ratio
          FROM genre_review_table
          GROUP BY genre_exploded
          ORDER BY ratio DESC
""").show(truncate=False)
# Out:
# +-------------------+------------+------------+-----+
# |genre_exploded     |sum_positive|sum_negative|ratio|
# +-------------------+------------+------------+-----+
# |PhotoEditing       |577751      |13745       |42.03|
# |Animation&Modeling |690765      |26392       |26.17|
# |Design&Illustration|674057      |27007       |24.96|
# |Utilities          |739335      |43503       |17.0 |
# |GameDevelopment    |27461       |3274        |8.39 |
# |Indie              |32531023    |4241234     |7.67 |
# |AudioProduction    |69118       |9428        |7.33 |
# |                   |183846      |25973       |7.08 |
# |VideoProduction    |111514      |16362       |6.82 |
# |Casual             |10034967    |1537296     |6.53 |
# |WebPublishing      |33984       |5238        |6.49 |
# |Simulation         |15572390    |2400512     |6.49 |
# |Racing             |2340353     |383691      |6.1  |
# |RPG                |19425528    |3274328     |5.93 |
# |Action             |54858618    |9687659     |5.66 |
# |Strategy           |13402870    |2393425     |5.6  |
# |Adventure          |29689445    |5653153     |5.25 |
# |EarlyAccess        |4334595     |936191      |4.63 |
# |Gore               |28618       |6451        |4.44 |
# |FreetoPlay         |18722246    |4280807     |4.37 |
# +-------------------+------------+------------+-----+
# only showing top 20 rows

# %%
spark.sql("""
          SELECT genre_exploded, ROUND(AVG(review_ratio),2) as avg_ratio
          FROM genre_review_table
          GROUP BY genre_exploded
          ORDER BY avg_ratio DESC
""").show(truncate=False)
# Out:
# +-------------------+---------+
# |genre_exploded     |avg_ratio|
# +-------------------+---------+
# |GameDevelopment    |6.58     |
# |Adventure          |6.24     |
# |Casual             |6.05     |
# |Indie              |5.96     |
# |RPG                |5.64     |
# |Animation&Modeling |5.51     |
# |Design&Illustration|5.39     |
# |Action             |5.38     |
# |FreetoPlay         |5.29     |
# |Simulation         |4.86     |
# |PhotoEditing       |4.85     |
# |                   |4.79     |
# |Strategy           |4.78     |
# |EarlyAccess        |4.69     |
# |WebPublishing      |4.65     |
# |Racing             |4.4      |
# |Sports             |4.33     |
# |Utilities          |4.28     |
# |VideoProduction    |3.99     |
# |Nudity             |3.92     |
# +-------------------+---------+
# only showing top 20 rows

# %% [markdown]
# #### 9. Certains éditeurs ont-ils des genres favoris ?
#
# --> Voici les genres favoris des plus grands éditeurs :
#
# - Big Fish : Casual, Adventure
# - 8Floor : Casual
# - SEGA : Action
# - Square Enix : Action
# - Choice of Games : RPG, Indie, Adventure
# - Sekai Project : Casual, Indie, Adventure
# - HH-Games : Casual

# %%
df_genre_clean.createOrReplaceTempView("genre_table")

spark.sql("""
          SELECT publisher, genre_exploded, COUNT(publisher) as cnt
          FROM genre_table
          GROUP BY publisher, genre_exploded
          ORDER BY cnt DESC, publisher
""").show(20, truncate=False)
# Out:
# +--------------------+--------------+---+
# |publisher           |genre_exploded|cnt|
# +--------------------+--------------+---+
# |Big Fish Games      |Casual        |418|
# |Big Fish Games      |Adventure     |392|
# |8floor              |Casual        |202|
# |Choice of Games     |RPG           |139|
# |Choice of Games     |Indie         |136|
# |HH-Games            |Casual        |132|
# |Laush Studio        |Indie         |124|
# |Choice of Games     |Adventure     |112|
# |                    |Indie         |106|
# |Alawar Entertainment|Casual        |105|
# |Sekai Project       |Casual        |99 |
# |Sokpop Collective   |Indie         |97 |
# |Slitherine Ltd.     |Strategy      |96 |
# |Alawar Entertainment|Adventure     |95 |
# |Reforged Group      |Indie         |88 |
# |Sekai Project       |Indie         |88 |
# |Devolver Digital    |Indie         |87 |
# |Laush Studio        |Casual        |87 |
# |PLAYISM             |Indie         |81 |
# |SEGA                |Action        |80 |
# +--------------------+--------------+---+
# only showing top 20 rows

# %% [markdown]
# #### 10. Quels sont les genres les plus lucratifs ?
#
# --> Les genres Action, Adventure et Indie sont les plus lucratifs, ils génèrent respectivement :
#   - un chiffre d'affaires minimum de 35 milliard, 22 millard et 19 milliard de dollars (fourchette basse)
#   - un chiffre d'affaires maximum de 80 milliard, 51 milliard et 45 milliard de dollars (fourchette haute)

# %%
df_genre_clean.select('owners').distinct().count()
# Out:
# Out[88]: 13

# %%
df_genre_clean.select('owners').distinct().sort('owners', ascending=False).show(13,truncate=False)
# Out:
# +--------------------------+
# |owners                    |
# +--------------------------+
# |500,000 .. 1,000,000      |
# |50,000,000 .. 100,000,000 |
# |50,000 .. 100,000         |
# |5,000,000 .. 10,000,000   |
# |200,000,000 .. 500,000,000|
# |200,000 .. 500,000        |
# |20,000,000 .. 50,000,000  |
# |20,000 .. 50,000          |
# |2,000,000 .. 5,000,000    |
# |100,000 .. 200,000        |
# |10,000,000 .. 20,000,000  |
# |1,000,000 .. 2,000,000    |
# |0 .. 20,000               |
# +--------------------------+

# %%
def extractMinOwners(str):
    result = str.split(" .. ")
    return int(''.join(result[0].split(",")))

def extractMaxOwners(str):
    result = str.split(" .. ")
    return int(''.join(result[1].split(",")))

# %%
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType

to_int_udf_1 = udf(lambda x:extractMinOwners(x),IntegerType())
to_int_udf_2 = udf(lambda x:extractMaxOwners(x),IntegerType())

df_genre_revenue = df_genre_clean \
                    .withColumn('min_owners', to_int_udf_1(col('owners'))) \
                    .withColumn('max_owners', to_int_udf_2(col('owners')))

# %%
df_genre_revenue.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- genre: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- positive: long (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- initialprice: double (nullable = true)
#  |-- discount: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- owners: string (nullable = true)
#  |-- genre_exploded: string (nullable = true)
#  |-- min_owners: integer (nullable = true)
#  |-- max_owners: integer (nullable = true)

# %%
df_genre_revenue.show()
# Out:
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+----------+----------+
# |                name|           publisher|               genre|positive|negative|initialprice|discount|price|              owners|genre_exploded|min_owners|max_owners|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+----------+----------+
# |      Counter-Strike|               Valve|            [Action]|  201215|    5199|        9.99|       0| 9.99|10,000,000 .. 20,...|        Action|  10000000|  20000000|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|        Action|         0|     20000|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|     Adventure|         0|     20000|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         0 .. 20,000|         Indie|         0|     20000|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|     Adventure|    200000|    500000|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|         Indie|    200000|    500000|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|           RPG|    200000|    500000|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|  200,000 .. 500,000|      Strategy|    200000|    500000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|        Action|    100000|    200000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|         Indie|    100000|    200000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|    Simulation|    100000|    200000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|  100,000 .. 200,000|      Strategy|    100000|    200000|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|        Action|         0|     20000|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|        Casual|         0|     20000|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|         Indie|         0|     20000|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         0 .. 20,000|    Simulation|         0|     20000|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|        Action|    100000|    200000|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|     Adventure|    100000|    200000|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|         Indie|    100000|    200000|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|  100,000 .. 200,000|           RPG|    100000|    200000|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------------+--------------+----------+----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import IntegerType

df_genre_revenue = df_genre_revenue \
                        .withColumn('min_revenue', col('min_owners')*col('price').cast('float')) \
                        .withColumn('max_revenue', col('max_owners')*col('price').cast('float')) \
                        .drop('owners')
                        
df_genre_revenue.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- publisher: string (nullable = true)
#  |-- genre: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- positive: long (nullable = true)
#  |-- negative: long (nullable = true)
#  |-- initialprice: double (nullable = true)
#  |-- discount: integer (nullable = true)
#  |-- price: double (nullable = true)
#  |-- genre_exploded: string (nullable = true)
#  |-- min_owners: integer (nullable = true)
#  |-- max_owners: integer (nullable = true)
#  |-- min_revenue: float (nullable = true)
#  |-- max_revenue: float (nullable = true)

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import IntegerType

df_revenue = df_genre_revenue \
                        .withColumn('min_revenue', col('min_revenue').cast(IntegerType())) \
                        .withColumn('max_revenue', col('max_revenue').cast(IntegerType()))

df_revenue.show()
# Out:
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------+----------+----------+-----------+-----------+
# |                name|           publisher|               genre|positive|negative|initialprice|discount|price|genre_exploded|min_owners|max_owners|min_revenue|max_revenue|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------+----------+----------+-----------+-----------+
# |      Counter-Strike|               Valve|            [Action]|  201215|    5199|        9.99|       0| 9.99|        Action|  10000000|  20000000|   99900000|  199800000|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|        Action|         0|     20000|          0|     199800|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|     Adventure|         0|     20000|          0|     199800|
# |           ASCENXION|PsychoFlux Entert...|[Action,  Adventu...|      27|       5|        9.99|       0| 9.99|         Indie|         0|     20000|          0|     199800|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|     Adventure|    200000|    500000|    1198000|    2995000|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|         Indie|    200000|    500000|    1198000|    2995000|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|           RPG|    200000|    500000|    1198000|    2995000|
# |         Crown Trick|Team17, NEXT Studios|[Adventure,  Indi...|    4032|     646|       19.99|      70| 5.99|      Strategy|    200000|    500000|    1198000|    2995000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|        Action|    100000|    200000|    1999000|    3998000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|         Indie|    100000|    200000|    1999000|    3998000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|    Simulation|    100000|    200000|    1999000|    3998000|
# |Cook, Serve, Deli...| Vertigo Gaming Inc.|[Action,  Indie, ...|    1575|     115|       19.99|       0|19.99|      Strategy|    100000|    200000|    1999000|    3998000|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|        Action|         0|     20000|          0|      39800|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|        Casual|         0|     20000|          0|      39800|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|         Indie|         0|     20000|          0|      39800|
# |            细胞战争|       DoubleC Games|[Action,  Casual,...|       0|       1|        1.99|       0| 1.99|    Simulation|         0|     20000|          0|      39800|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|        Action|    100000|    200000|     799000|    1598000|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|     Adventure|    100000|    200000|     799000|    1598000|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|         Indie|    100000|    200000|     799000|    1598000|
# |             Zengeon|            2P Games|[Action,  Adventu...|    1018|     462|       19.99|      60| 7.99|           RPG|    100000|    200000|     799000|    1598000|
# +--------------------+--------------------+--------------------+--------+--------+------------+--------+-----+--------------+----------+----------+-----------+-----------+
# only showing top 20 rows

# %%
df_revenue.createOrReplaceTempView('revenue_table')
spark.sql("""
          SELECT genre_exploded, 
            SUM(min_revenue) AS total_min_revenue, 
            SUM(max_revenue) AS total_max_revenue
          FROM revenue_table
          GROUP BY genre_exploded
          ORDER BY total_min_revenue DESC, total_max_revenue DESC
""").show(30, truncate=False)
# Out:
# +--------------------+-----------------+-----------------+
# |genre_exploded      |total_min_revenue|total_max_revenue|
# +--------------------+-----------------+-----------------+
# |Action              |35929269657      |80731619140      |
# |Adventure           |22618905951      |51872567919      |
# |Indie               |19134715838      |45558431538      |
# |RPG                 |16675128197      |36819140786      |
# |Strategy            |12362391808      |27937689117      |
# |Simulation          |11422233094      |26117264826      |
# |Casual              |4476567857       |11685341454      |
# |MassivelyMultiplayer|3692721317       |8167594157       |
# |EarlyAccess         |3147066715       |7770255341       |
# |Sports              |1816053347       |4483740991       |
# |Racing              |1579747645       |3867214039       |
# |Utilities           |190300698        |567310353        |
# |Design&Illustration |154659699        |499962076        |
# |                    |148135094        |306695689        |
# |Animation&Modeling  |125939299        |404435886        |
# |PhotoEditing        |90248999         |259282693        |
# |FreetoPlay          |57122494         |145829283        |
# |WebPublishing       |57034599         |152506895        |
# |AudioProduction     |47513500         |180093092        |
# |VideoProduction     |46105800         |192678990        |
# |Education           |28439100         |142524581        |
# |GameDevelopment     |19539600         |104256987        |
# |SoftwareTraining    |18909600         |96796395         |
# |Violent             |14337093         |45050069         |
# |Gore                |11042696         |32319384         |
# |Nudity              |4850799          |14776393         |
# |SexualContent       |3456098          |12928891         |
# |Accounting          |1499000          |7316599          |
# |Movie               |0                |0                |
# +--------------------+-----------------+-----------------+

# %% [markdown]
# ## Analyse des plateformes

# %% [markdown]
# #### 11. La plupart des jeux sont-ils plutôt disponibles sur Windows/Mac/Linux ?
#
# --> Presque tous les jeux tournent sur Windows (55676 soit 99,97% des jeux)

# %%
selected_columns = ['name', 'platforms_linux', 'platforms_mac', 'platforms_windows']
df_platform = df_clean.select(selected_columns)
df_platform.printSchema()
df_platform.show()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- platforms_linux: boolean (nullable = true)
#  |-- platforms_mac: boolean (nullable = true)
#  |-- platforms_windows: boolean (nullable = true)
#
# +------------------------------------+---------------+-------------+-----------------+
# |                                name|platforms_linux|platforms_mac|platforms_windows|
# +------------------------------------+---------------+-------------+-----------------+
# |                      Counter-Strike|           true|         true|             true|
# |                           ASCENXION|          false|        false|             true|
# |                         Crown Trick|          false|        false|             true|
# |                Cook, Serve, Deli...|          false|         true|             true|
# |                            细胞战争|          false|        false|             true|
# |                             Zengeon|          false|         true|             true|
# |干支セトラ　陽ノ卷｜干支etc.　陽之卷|          false|        false|             true|
# |            Jumping Master(跳跳大咖)|          false|        false|             true|
# |                       Cube Defender|          false|         true|             true|
# |                Tower of Origin2-...|          false|        false|             true|
# |                      人气动漫大乱斗|          false|        false|             true|
# |                       Hellish Quart|          false|        false|             true|
# |                      SurReal Subway|          false|        false|             true|
# |                        Rogue Reaper|          false|        false|             true|
# |                 WRATH: Aeon of Ruin|          false|        false|             true|
# |                Drawngeon: Dungeo...|          false|        false|             true|
# |                       Battle Motion|           true|         true|             true|
# |                The Undisputables...|           true|         true|             true|
# |                The Marvellous Ma...|          false|        false|             true|
# |                    Tactical Control|          false|        false|             true|
# +------------------------------------+---------------+-------------+-----------------+
# only showing top 20 rows

# %%
linux = df_platform.select('platforms_linux').where(df_platform['platforms_linux'] == True).count()
mac = df_platform.select('platforms_mac').where(df_platform['platforms_mac'] == True).count()
windows = df_platform.select('platforms_windows').where(df_platform['platforms_windows'] == True).count()

print(f'linux: {linux}, mac: {mac}, windows: {windows}')
# Out:
# linux: 8457, mac: 12769, windows: 55675

# %% [markdown]
# #### 12. Certains genres ont-ils tendance à être disponibles préférentiellement sur certaines plateformes ?
#
# --> La distribution des plateformes est plutôt uniforme pour tous les genres, sauf pour :
# - Les jeux en lien avec les films / le cinéma : seulement sur Windows
# - Les jeux en lien avec la comptabilité : sur Windows et Mac, absent sur Linux
# - Les jeux en lien avec la création photo, vidéo et audio : majoritairement sur Windows et Mac, très peu sur Linux
# - Les jeux en lien avec l'éducation et la formation : majoritairement sur Windows et Mac, très peu sur Linux

# %%
selected_columns = ['name', 'genre', 'platforms_linux', 'platforms_mac', 'platforms_windows']
df_genre_and_platforms = df_clean.select(selected_columns)
df_genre_and_platforms.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- platforms_linux: boolean (nullable = true)
#  |-- platforms_mac: boolean (nullable = true)
#  |-- platforms_windows: boolean (nullable = true)

# %%
from pyspark.sql.functions import split, col
df_genre_liste = df_genre_and_platforms.withColumn("genre", split(col("genre"),","))
df_genre_liste.show()
# Out:
# +------------------------------------+--------------------+---------------+-------------+-----------------+
# |                                name|               genre|platforms_linux|platforms_mac|platforms_windows|
# +------------------------------------+--------------------+---------------+-------------+-----------------+
# |                      Counter-Strike|            [Action]|           true|         true|             true|
# |                           ASCENXION|[Action,  Adventu...|          false|        false|             true|
# |                         Crown Trick|[Adventure,  Indi...|          false|        false|             true|
# |                Cook, Serve, Deli...|[Action,  Indie, ...|          false|         true|             true|
# |                            细胞战争|[Action,  Casual,...|          false|        false|             true|
# |                             Zengeon|[Action,  Adventu...|          false|         true|             true|
# |干支セトラ　陽ノ卷｜干支etc.　陽之卷|[Adventure,  Indi...|          false|        false|             true|
# |            Jumping Master(跳跳大咖)|[Action,  Adventu...|          false|        false|             true|
# |                       Cube Defender|    [Casual,  Indie]|          false|         true|             true|
# |                Tower of Origin2-...|       [Indie,  RPG]|          false|        false|             true|
# |                      人气动漫大乱斗|[Action,  RPG,  S...|          false|        false|             true|
# |                       Hellish Quart|[Action,  Early A...|          false|        false|             true|
# |                      SurReal Subway|             [Indie]|          false|        false|             true|
# |                        Rogue Reaper|[Action,  Adventu...|          false|        false|             true|
# |                 WRATH: Aeon of Ruin|[Action,  Early A...|          false|        false|             true|
# |                Drawngeon: Dungeo...|[Adventure,  Indi...|          false|        false|             true|
# |                       Battle Motion|[Action,  Indie, ...|           true|         true|             true|
# |                The Undisputables...|[Action,  Casual,...|           true|         true|             true|
# |                The Marvellous Ma...|         [Education]|          false|        false|             true|
# |                    Tactical Control|[Casual,  Free to...|          false|        false|             true|
# +------------------------------------+--------------------+---------------+-------------+-----------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import explode
df_genre_final = df_genre_liste.withColumn('genre_exploded', explode(df_genre_liste.genre))
df_genre_final.show()
# Out:
# +--------------------+--------------------+---------------+-------------+-----------------+--------------+
# |                name|               genre|platforms_linux|platforms_mac|platforms_windows|genre_exploded|
# +--------------------+--------------------+---------------+-------------+-----------------+--------------+
# |      Counter-Strike|            [Action]|           true|         true|             true|        Action|
# |           ASCENXION|[Action,  Adventu...|          false|        false|             true|        Action|
# |           ASCENXION|[Action,  Adventu...|          false|        false|             true|     Adventure|
# |           ASCENXION|[Action,  Adventu...|          false|        false|             true|         Indie|
# |         Crown Trick|[Adventure,  Indi...|          false|        false|             true|     Adventure|
# |         Crown Trick|[Adventure,  Indi...|          false|        false|             true|         Indie|
# |         Crown Trick|[Adventure,  Indi...|          false|        false|             true|           RPG|
# |         Crown Trick|[Adventure,  Indi...|          false|        false|             true|      Strategy|
# |Cook, Serve, Deli...|[Action,  Indie, ...|          false|         true|             true|        Action|
# |Cook, Serve, Deli...|[Action,  Indie, ...|          false|         true|             true|         Indie|
# |Cook, Serve, Deli...|[Action,  Indie, ...|          false|         true|             true|    Simulation|
# |Cook, Serve, Deli...|[Action,  Indie, ...|          false|         true|             true|      Strategy|
# |            细胞战争|[Action,  Casual,...|          false|        false|             true|        Action|
# |            细胞战争|[Action,  Casual,...|          false|        false|             true|        Casual|
# |            细胞战争|[Action,  Casual,...|          false|        false|             true|         Indie|
# |            细胞战争|[Action,  Casual,...|          false|        false|             true|    Simulation|
# |             Zengeon|[Action,  Adventu...|          false|         true|             true|        Action|
# |             Zengeon|[Action,  Adventu...|          false|         true|             true|     Adventure|
# |             Zengeon|[Action,  Adventu...|          false|         true|             true|         Indie|
# |             Zengeon|[Action,  Adventu...|          false|         true|             true|           RPG|
# +--------------------+--------------------+---------------+-------------+-----------------+--------------+
# only showing top 20 rows

# %%
def sanitizeGenre(s: str) -> str:
        return s.replace(" ", "")
    
from pyspark.sql.functions import col, udf
sanitize_udf = udf(lambda x:sanitizeGenre(x))
df_genre_final_clean = df_genre_final.withColumn('genre_exploded', sanitize_udf(col('genre_exploded')))

# %%
df_genre_final_clean.createOrReplaceTempView('genre_and_platforms_table')
spark.sql("""
          SELECT genre_exploded, 
            COUNT(CASE WHEN platforms_linux = true THEN 1 END) AS linux,
            COUNT(CASE WHEN platforms_mac = true THEN 1 END) AS mac,
            COUNT(CASE WHEN platforms_windows = true THEN 1 END) AS windows
          FROM genre_and_platforms_table
          GROUP BY genre_exploded
          ORDER BY windows DESC, mac DESC, linux DESC
""").show(30)
# Out:
# +--------------------+-----+----+-------+
# |      genre_exploded|linux| mac|windows|
# +--------------------+-----+----+-------+
# |               Indie| 6978|9935|  39676|
# |              Action| 3379|4564|  23755|
# |              Casual| 3305|5130|  22082|
# |           Adventure| 3302|5039|  21427|
# |            Strategy| 1826|3005|  10892|
# |          Simulation| 1532|2439|  10832|
# |                 RPG| 1524|2248|   9533|
# |         EarlyAccess|  632| 900|   6145|
# |          FreetoPlay|  474| 845|   3391|
# |              Sports|  287| 506|   2665|
# |              Racing|  304| 424|   2154|
# |MassivelyMultiplayer|  164| 270|   1459|
# |           Utilities|   49| 102|    681|
# | Design&Illustration|   54| 100|    405|
# |  Animation&Modeling|   38|  74|    322|
# |           Education|   19|  56|    317|
# |     VideoProduction|    6|  29|    247|
# |     AudioProduction|    7|  41|    193|
# |             Violent|   22|  33|    168|
# |    SoftwareTraining|   12|  27|    164|
# |     GameDevelopment|   35|  52|    159|
# |                    |   41|  54|    158|
# |        PhotoEditing|    4|  16|    105|
# |                Gore|   14|  20|     99|
# |       WebPublishing|    8|  20|     89|
# |       SexualContent|    7|  13|     54|
# |              Nudity|    7|  10|     45|
# |          Accounting|    0|   4|     16|
# |               Movie|    0|   0|      1|
# +--------------------+-----+----+-------+

# %%
data = spark.sql("""
          SELECT genre_exploded, 
            COUNT(CASE WHEN platforms_linux = true THEN 1 END) AS linux,
            COUNT(CASE WHEN platforms_mac = true THEN 1 END) AS mac,
            COUNT(CASE WHEN platforms_windows = true THEN 1 END) AS windows
          FROM genre_and_platforms_table
          GROUP BY genre_exploded
          ORDER BY windows DESC, mac DESC, linux DESC
""")

# %%
# Ouvrez le notebook dans Databrick pour voir la visualisation :
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre_exploded</th><th>linux</th><th>mac</th><th>windows</th></tr></thead><tbody><tr><td>Indie</td><td>6978</td><td>9935</td><td>39676</td></tr><tr><td>Action</td><td>3379</td><td>4564</td><td>23755</td></tr><tr><td>Casual</td><td>3305</td><td>5130</td><td>22082</td></tr><tr><td>Adventure</td><td>3302</td><td>5039</td><td>21427</td></tr><tr><td>Strategy</td><td>1826</td><td>3005</td><td>10892</td></tr><tr><td>Simulation</td><td>1532</td><td>2439</td><td>10832</td></tr><tr><td>RPG</td><td>1524</td><td>2248</td><td>9533</td></tr><tr><td>EarlyAccess</td><td>632</td><td>900</td><td>6145</td></tr><tr><td>FreetoPlay</td><td>474</td><td>845</td><td>3391</td></tr><tr><td>Sports</td><td>287</td><td>506</td><td>2665</td></tr><tr><td>Racing</td><td>304</td><td>424</td><td>2154</td></tr><tr><td>MassivelyMultiplayer</td><td>164</td><td>270</td><td>1459</td></tr><tr><td>Utilities</td><td>49</td><td>102</td><td>681</td></tr><tr><td>Design&Illustration</td><td>54</td><td>100</td><td>405</td></tr><tr><td>Animation&Modeling</td><td>38</td><td>74</td><td>322</td></tr><tr><td>Education</td><td>19</td><td>56</td><td>317</td></tr><tr><td>VideoProduction</td><td>6</td><td>29</td><td>247</td></tr><tr><td>AudioProduction</td><td>7</td><td>41</td><td>193</td></tr><tr><td>Violent</td><td>22</td><td>33</td><td>168</td></tr><tr><td>SoftwareTraining</td><td>12</td><td>27</td><td>164</td></tr><tr><td>GameDevelopment</td><td>35</td><td>52</td><td>159</td></tr><tr><td></td><td>41</td><td>54</td><td>158</td></tr><tr><td>PhotoEditing</td><td>4</td><td>16</td><td>105</td></tr><tr><td>Gore</td><td>14</td><td>20</td><td>99</td></tr><tr><td>WebPublishing</td><td>8</td><td>20</td><td>89</td></tr><tr><td>SexualContent</td><td>7</td><td>13</td><td>54</td></tr><tr><td>Nudity</td><td>7</td><td>10</td><td>45</td></tr><tr><td>Accounting</td><td>0</td><td>4</td><td>16</td></tr><tr><td>Movie</td><td>0</td><td>0</td><td>1</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ## Analyse des jeux les plus populaires

# %% [markdown]
# #### 13. Quelles sont les caractéristiques des jeux les plus joués ?

# %% [markdown]
# - Il y a un seul jeu qui cumule plus de 200 millions de téléchargements et il est gratuit
# - Il y a 4 jeux qui cumulent plus de 50 millions de téléchargements et ils sont au prix moyen de 4,99$
# - Il y a 21 jeux qui cumulent plus de 20 millions de téléchargements et ils sont au prix moyen de 10$
# - La majorité des jeux (38072) ont été téléchargé moins de 20000 fois et ils sont au prix moyen de 7$
# - Si on veut performer en nombre de téléchargement on devrait pas mettre un prix de plus de 4,99$

# %%
df_genre_list.createOrReplaceTempView('price_and_owners_table')

spark.sql("""
          SELECT owners, COUNT(owners) AS owners_group, AVG(price)
          FROM price_and_owners_table
          GROUP BY owners
          ORDER BY owners_group DESC
""").show()
# Out:
# +--------------------+------------+------------------+
# |              owners|owners_group|        avg(price)|
# +--------------------+------------+------------------+
# |         0 .. 20,000|       38072| 7.097593507035998|
# |    20,000 .. 50,000|        7285| 7.300844200411549|
# |   50,000 .. 100,000|        3695| 8.340476319350978|
# |  100,000 .. 200,000|        2519|  9.32903930131028|
# |  200,000 .. 500,000|        2162|10.661660499537653|
# |500,000 .. 1,000,000|         932| 13.94149141630887|
# |1,000,000 .. 2,00...|         526|15.781977186311666|
# |2,000,000 .. 5,00...|         335|18.133731343283475|
# |5,000,000 .. 10,0...|          97|18.260618556701036|
# |10,000,000 .. 20,...|          41| 12.09146341463415|
# |20,000,000 .. 50,...|          21|10.422857142857145|
# |50,000,000 .. 100...|           4|            4.9975|
# |200,000,000 .. 50...|           1|               0.0|
# +--------------------+------------+------------------+

# %% [markdown]
# - Les gens sont prêts à payer jusqu'à 59$ pour un bon jeu
# - Dans les 4 jeux à plus de 50 milliers de téléchargements il y en a un à 39$, le reste sont gratuits
# - Dans les 21 jeux à plus de 20 millions de téléchargement, la plupart sont gratuits
# - Il y a quelques jeux à 4, 5, 10, 20, 30, 40 et 60$

# %%
df_clean.createOrReplaceTempView("clean_table")
spark.sql("""
          SELECT name, publisher, genre, owners, initialprice, discount, price, release_date, required_age
          FROM clean_table
          WHERE (owners = '200,000,000 .. 500,000,000' OR owners = '50,000,000 .. 100,000,000' OR owners = '20,000,000 .. 50,000,000')
          ORDER BY owners DESC
""").show(30)
# Out:
# +--------------------+--------------------+--------------------+--------------------+------------+--------+-----+------------+------------+
# |                name|           publisher|               genre|              owners|initialprice|discount|price|release_date|required_age|
# +--------------------+--------------------+--------------------+--------------------+------------+--------+-----+------------+------------+
# |           New World|        Amazon Games|Action, Adventure...|50,000,000 .. 100...|       39.99|      50|19.99|  2021/09/28|           0|
# |     Team Fortress 2|               Valve|Action, Free to Play|50,000,000 .. 100...|         0.0|       0|  0.0|  2007/10/10|           0|
# | PUBG: BATTLEGROUNDS|       KRAFTON, Inc.|Action, Adventure...|50,000,000 .. 100...|         0.0|       0|  0.0|  2017/12/21|           0|
# |Counter-Strike: G...|               Valve|Action, Free to Play|50,000,000 .. 100...|         0.0|       0|  0.0|  2012/08/21|           0|
# |              Dota 2|               Valve|Action, Free to P...|200,000,000 .. 50...|         0.0|       0|  0.0|   2013/07/9|           0|
# |            Terraria|            Re-Logic|Action, Adventure...|20,000,000 .. 50,...|        9.99|       0| 9.99|  2011/05/16|           0|
# |           Destiny 2|              Bungie|Action, Adventure...|20,000,000 .. 50,...|         0.0|       0|  0.0|   2019/10/1|           0|
# |Fall Guys: Ultima...|         Ravenscourt|Action, Casual, I...|20,000,000 .. 50,...|         0.0|       0|  0.0|   2020/08/3|           0|
# |        Apex Legends|     Electronic Arts|Action, Adventure...|20,000,000 .. 50,...|         0.0|       0|  0.0|   2020/11/4|           0|
# |          ELDEN RING|FromSoftware Inc....|         Action, RPG|20,000,000 .. 50,...|       59.99|       0|59.99|  2022/02/24|           0|
# |            Lost Ark|        Amazon Games|Action, Adventure...|20,000,000 .. 50,...|         0.0|       0|  0.0|  2022/02/11|          15|
# |            PAYDAY 2|Starbreeze Publis...|         Action, RPG|20,000,000 .. 50,...|        9.99|       0| 9.99|  2013/08/13|          18|
# |            Warframe|    Digital Extremes|Action, Free to P...|20,000,000 .. 50,...|         0.0|       0|  0.0|  2013/03/25|          13|
# |         War Thunder|Gaijin Distributi...|Action, Free to P...|20,000,000 .. 50,...|         0.0|       0|  0.0|  2013/08/15|           0|
# |       Path of Exile| Grinding Gear Games|Action, Adventure...|20,000,000 .. 50,...|         0.0|       0|  0.0|  2013/10/23|           0|
# |                Rust|   Facepunch Studios|Action, Adventure...|20,000,000 .. 50,...|       39.99|       0|39.99|   2018/02/8|          17|
# |  Grand Theft Auto V|      Rockstar Games|   Action, Adventure|20,000,000 .. 50,...|       29.98|       0|29.98|  2015/04/13|           0|
# |          Brawlhalla|             Ubisoft|Action, Free to P...|20,000,000 .. 50,...|         0.0|       0|  0.0|  2017/10/17|           0|
# |            Unturned|Smartly Dressed G...|Action, Adventure...|20,000,000 .. 50,...|         0.0|       0|  0.0|   2017/07/7|           0|
# |Half-Life 2: Lost...|               Valve|              Action|20,000,000 .. 50,...|         0.0|       0|  0.0|  2005/10/27|           0|
# |Tom Clancy's Rain...|             Ubisoft|              Action|20,000,000 .. 50,...|       19.99|       0|19.99|   2015/12/1|           0|
# |         Garry's Mod|               Valve|   Indie, Simulation|20,000,000 .. 50,...|        9.99|       0| 9.99|  2006/11/29|           0|
# |    Wallpaper Engine|Wallpaper Engine ...|Casual, Indie, An...|20,000,000 .. 50,...|        3.99|       0| 3.99|     2018/11|           0|
# |       Left 4 Dead 2|               Valve|              Action|20,000,000 .. 50,...|        9.99|       0| 9.99|  2009/11/16|          17|
# |             Valheim|Coffee Stain Publ...|Action, Adventure...|20,000,000 .. 50,...|       19.99|       0|19.99|   2021/02/2|           0|
# |            Among Us|          Innersloth|              Casual|20,000,000 .. 50,...|        4.99|       0| 4.99|  2018/11/16|           0|
# +--------------------+--------------------+--------------------+--------------------+------------+--------+-----+------------+------------+

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Les jeux qui marchent bien sont principalement sur Windows et Mac
# - Les genres les plus joués sont dans l'ordre : Indie, Action, Casual, Adventure
# - La fourchette de prix moyenne : de 0 à 10 dollars
# - Pour vendre plus il vaut mieux proposer un prix entre 0 et 4,99 dollars
# - Il faut absolument avoir une version anglaise
# - Et proposer un jeu tout public sans restriction d'âge
